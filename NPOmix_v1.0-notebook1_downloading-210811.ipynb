# %% [markdown]
# `Last update at 2021-08-11`
#
# # Outline
#
# ```
#     1) Downloading (meta)genomes and metagenome-assembled genomes (MAGs) that contain a paired untargeted
#     metabolomics (LC-MS/MS and in the future GC-MS/MS)(metabolomic files also going to be downloaded):
#     1.1) Downloading all JSON files from PoDP;
#     1.2) Parsing JSON files and creating podp_merged_df;
#     1.3) Obtaining uniform Genbank code from BioSample ID; (estimated runtime of 02:46:30)
#     1.4) Adding new column with the downloaded NCBI IDs;
#     1.5) Downloading and unzipping the NCBI genomes;
#     1.6) Copying previously downloaded genomes;
#     1.7) Downloading metagenomic reads;
#     1.8) Downloading JGI (meta)genomes;
#     1.9) Separating Genomes without antiSMASH;
#     1.10) Running antiSMASH;
#     1.11) Filtering links for (meta)genomes with antiSMASH and downloading LC-MS/MS;
#     1.12) Download missing Gerwick cyanoibacterial MS/MS and selecting Gerwick mgf files.
# ```

# %%
import pandas as pd
import time
import glob
import numpy as np
import csv
import subprocess
import glob
import os
import re
import networkx
from networkx.algorithms.components.connected import connected_components
from collections import defaultdict
import matplotlib.pyplot as plt
from Bio import SeqIO
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestNeighbors
import pickle
import json
from pyteomics import mgf, auxiliary
import csv

# %%
# !mkdir ./inputs
# !mkdir ./outputs/
# !mkdir ./temp_files/

# %% [markdown]
# # 1. Downloading genomes from the Paired omics Data Platform (PoDP)
#
# ## 1.1. Downloading all JSON files from PoDP
#
# ```
# Go to PoDP (https://pairedomicsdata.bioinformatics.nl) and download the database JSON files, move files to
# input folder (path/to/NPOmix/inputs/databases/).
# ```

# %% [markdown]
# ## 1.2. Parsing JSON files and creating podp_merged_df

# %%
def get_strain_dicts(filename):
    strain_gbk_dict = {}
    strain_biosample_dict = {}
    strain_db_dict = {}
    strain_to_shotgun = {}
    with open(filename) as f:
        data1 = json.load(f)
        if 'message' not in data1.keys():
            data1 = data1['genomes']
            json_df1 = pd.DataFrame(data1)
            for i,r in json_df1.iterrows():
                genome_line = dict(json_df1['genome_ID'].loc[i])
                if 'ENA_NCBI_accession' in genome_line.keys():
                    genomeID = genome_line['ENA_NCBI_accession']
                    db_id = 'ENA_NCBI_accession'
                if 'GenBank_accession' in genome_line.keys():
                    genomeID = genome_line['GenBank_accession']
                    db_id = 'GenBank_accession'
                if 'RefSeq_accession' in genome_line.keys():
                    genomeID = genome_line['RefSeq_accession']
                    db_id = 'RefSeq_accession'
                if 'JGI_Genome_ID' in genome_line.keys():
                    genomeID = genome_line['JGI_Genome_ID']
                    db_id = 'JGI_Genome_ID'
                if 'JGI_ID' in genome_line.keys():
                    genomeID = genome_line['JGI_ID']
                    db_id = 'JGI_ID'
                if 'JGI_IMG_genome_ID'in genome_line.keys():
                    genomeID = genome_line['JGI_IMG_genome_ID']
                    db_id = 'JGI_IMG_genome_ID'
                strain_to_shotgun[json_df1['genome_label'].loc[i]] = genome_line['genome_type']
                strain_gbk_dict[json_df1['genome_label'].loc[i]] = genomeID
                strain_db_dict[json_df1['genome_label'].loc[i]] = db_id
                if 'BioSample_accession' in json_df1.columns:
                    strain_biosample_dict[json_df1['genome_label'].loc[i]] = json_df1['BioSample_accession'].loc[i]
                else:
                    strain_biosample_dict[json_df1['genome_label'].loc[i]] = 'No BioSample'
    return strain_gbk_dict,strain_biosample_dict,strain_db_dict,strain_to_shotgun

def get_paired_df(filename,strain_gbk_dict,strain_biosample_dict,strain_db_dict,strain_to_shotgun):
    col1,col2,col3,col4,col5,col6 = [],[],[],[],[],[]
    with open(filename) as f:
        data2 = json.load(f)['genome_metabolome_links']
        json_df2 = pd.DataFrame(data2)
        for i,r in json_df2.iterrows():
            col1.append(strain_gbk_dict[json_df2['genome_label'].loc[i]])
            col2.append(strain_db_dict[json_df2['genome_label'].loc[i]])
            col3.append(strain_biosample_dict[json_df2['genome_label'].loc[i]])
            col4.append(json_df2['metabolomics_file'].loc[i])
            col5.append(json_df2['genome_label'].loc[i])
            col6.append(strain_to_shotgun[json_df2['genome_label'].loc[i]])
    frames = {'NCBI_ID':col1, 'Database':col2, 'BioSample':col3, 
              'LCMS_file':col4, 'Genome_label':col5, 'Method':col6}
    paired_df = pd.DataFrame(frames)
    return paired_df

# %%
table_list = glob.glob('./inputs/PoDP_datasets/*.json')

for filename in table_list:
    strain_gbk_dict,strain_biosample_dict,strain_db_dict,strain_to_shotgun = get_strain_dicts(filename)
    if strain_gbk_dict:
        if filename == table_list[0]:
            podp_merged_df = get_paired_df(filename,strain_gbk_dict,strain_biosample_dict,strain_db_dict,strain_to_shotgun)
        else:
            paired_df = get_paired_df(filename,strain_gbk_dict,strain_biosample_dict,strain_db_dict,strain_to_shotgun)
            frames = [podp_merged_df,paired_df]
            podp_merged_df = pd.concat(frames)
        
podp_merged_df = podp_merged_df.reset_index(drop=True)

podp_merged_df
# Out:
#               NCBI_ID           Database     BioSample  \
# 0     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 1     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 2     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 3     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 4     GCA_000240165.1   RefSeq_accession  SAMN02603879
# ...               ...                ...           ...
# 4891  GCA_000286575.1  GenBank_accession  SAMN00255227
# 4892  GCA_000959505.1  GenBank_accession  SAMN03144971
# 4893  GCA_000959505.1  GenBank_accession  SAMN03144971
# 4894  GCA_003568605.1  GenBank_accession  SAMN02866398
# 4895  GCA_003568605.1  GenBank_accession  SAMN02866398
#
#                                               LCMS_file  \
# 0     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 1     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 2     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 3     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 4     ftp://massive.ucsd.edu/MSV000078850/results/S....
# ...                                                 ...
# 4891  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 4892  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 4893  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 4894  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 4895  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
#
#                          Genome_label  Method
# 0                         S. cattleya  genome
# 1                         S. cattleya  genome
# 2                         S. cattleya  genome
# 3                         S. cattleya  genome
# 4                         S. cattleya  genome
# ...                               ...     ...
# 4891     Burkholderia multivorans CF2  genome
# 4892       Burkholderia dolosa AU0158  genome
# 4893       Burkholderia dolosa AU0158  genome
# 4894  Burkholderia thailandensis E264  genome
# 4895  Burkholderia thailandensis E264  genome
#
# [4896 rows x 6 columns]

# %%
len(table_list) ### contain all online datasets
# Out:
# 71

# %%
online_massive = ['MTBLS1606','MSV000086050','MSV000085589','MSV000085586','MSV000085376','MSV000085214','MSV000085210','MSV000085192','MSV000085180','MSV000085179','MSV000085159','MSV000085158','MSV000085141','MSV000085123','MSV000085085','MSV000085038','MSV000085032','MSV000085031','MSV000085027','MSV000085026','MSV000085023','MSV000085021','MSV000085018','MSV000085003','MSV000085000','MSV000084989','MSV000084954','MSV000084950','MSV000084950','MSV000084945','MSV000084884','MSV000084781','MSV000084771','MSV000084723','MSV000084674','MSV000084475','MSV000084475','MSV000084117','MSV000083835','MSV000083734','MSV000083648','MSV000083387','MSV000083302','MSV000083295','MSV000083268','MSV000083081','MSV000082988','MSV000082969','MSV000082891','MSV000082831','MSV000082285','MSV000082045','MSV000081832','MSV000081504','MSV000081318','MSV000081063','MSV000080427','MSV000080251','MSV000080179','MSV000079519','MSV000079284','MSV000079139','MSV000079015','MSV000078995','MSV000078891','MSV000078850','MSV000078847','MSV000078839','MSV000078836','MSV000078667','MSV000078556']

# %%
downloaded_massive = []

for item in podp_merged_df['LCMS_file']:
    if 'MSV' in item:
        if 'ftp://maftp' in item:
            downloaded_massive.append(item[31:43])
        else:
            downloaded_massive.append(item[23:35])
    if 'MTBLS' in item:
        downloaded_massive.append(item[35:])
    
downloaded_massive = list(np.unique(downloaded_massive))

for item in online_massive:
    if item not in downloaded_massive:
        print(item)
### we downloaded and processed all datasets (69 unique and 71 total MassIVE/Metabolights IDs)

# %%
len(np.unique(podp_merged_df['NCBI_ID'])),len(podp_merged_df)
### unique genomes and total number of links (the second matches the online record)
# Out:
# (2289, 4896)

# %%
len(podp_merged_df[podp_merged_df['BioSample'] == 'No BioSample'])
# Out:
# 799

# %%
len(np.unique(podp_merged_df[podp_merged_df['BioSample'] != 'No BioSample']['BioSample']))
# Out:
# 1677

# %%
799+1677
# Out:
# 2476

# %%
for item in np.unique(podp_merged_df['Database']):
    print(item, len(podp_merged_df[podp_merged_df['Database'] == item]['NCBI_ID']))
# Out:
# ENA_NCBI_accession 1298
# GenBank_accession 2107
# JGI_Genome_ID 765
# JGI_ID 2
# JGI_IMG_genome_ID 612
# RefSeq_accession 112

# %%
for item in np.unique(podp_merged_df['Method']):
    print(item, len(podp_merged_df[podp_merged_df['Method'] == item]['NCBI_ID']))
# Out:
# genome 3456
# metagenome 1306
# metagenome-assembled genome 134

# %% [markdown]
# ## 1.3. Obtaining uniform Genbank code from BioSample ID
#
# ```
# Separating JGI/ENA IDs from NCBI genomes, these will be downloaded in another step, for now we'll focus on NCBI genomes
# ```

# %%
filtered_df = podp_merged_df[podp_merged_df['Database'] != 'JGI_IMG_genome_ID']
filtered_df = filtered_df[filtered_df['Database'] != 'JGI_Genome_ID']
filtered_df = filtered_df[filtered_df['Database'] != 'JGI_ID']
filtered_df = filtered_df[filtered_df['Database'] != 'ENA_NCBI_accession']
filtered_df = filtered_df[filtered_df['BioSample'] != 'No BioSample']
filtered_df = filtered_df.reset_index(drop=True)

filtered_df
# Out:
#               NCBI_ID           Database     BioSample  \
# 0     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 1     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 2     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 3     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 4     GCA_000240165.1   RefSeq_accession  SAMN02603879
# ...               ...                ...           ...
# 2115  GCA_000286575.1  GenBank_accession  SAMN00255227
# 2116  GCA_000959505.1  GenBank_accession  SAMN03144971
# 2117  GCA_000959505.1  GenBank_accession  SAMN03144971
# 2118  GCA_003568605.1  GenBank_accession  SAMN02866398
# 2119  GCA_003568605.1  GenBank_accession  SAMN02866398
#
#                                               LCMS_file  \
# 0     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 1     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 2     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 3     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 4     ftp://massive.ucsd.edu/MSV000078850/results/S....
# ...                                                 ...
# 2115  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 2116  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 2117  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 2118  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 2119  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
#
#                          Genome_label  Method
# 0                         S. cattleya  genome
# 1                         S. cattleya  genome
# 2                         S. cattleya  genome
# 3                         S. cattleya  genome
# 4                         S. cattleya  genome
# ...                               ...     ...
# 2115     Burkholderia multivorans CF2  genome
# 2116       Burkholderia dolosa AU0158  genome
# 2117       Burkholderia dolosa AU0158  genome
# 2118  Burkholderia thailandensis E264  genome
# 2119  Burkholderia thailandensis E264  genome
#
# [2120 rows x 6 columns]

# %%
### only run once

# with open('./temp_files/genome_list_temp.txt', "w") as output:
#     writer = csv.writer(output, lineterminator='\n')
#     for val in list(filtered_df['NCBI_ID']):
#         writer.writerow([val])
        
# with open('./temp_files/biosample_list_temp.txt', "w") as output:
#     writer = csv.writer(output, lineterminator='\n')
#     for val in list(filtered_df['BioSample']):
#         writer.writerow([val])

# %%
### only run once

# start = time.time()

# subprocess.call('python NCBI_getGenBankID.py --input ./temp_files/biosample_list_temp.txt --output ./outputs/biosample_list-round3-210220.out.csv', shell=True)

# end = time.time()
# hours, rem = divmod(end-start, 3600)
# minutes, seconds = divmod(rem, 60)
# print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
### 02:46:30.68

# %%
biosample_df = pd.read_csv('./outputs/biosample_list-round3-210220.out.csv',sep='\t')
biosample_df = biosample_df[biosample_df['GenBank_id'] != '-']
biosample_df = biosample_df.reset_index(drop=True)


biosample_df
# Out:
#      Accession_id Assembly_id       GenBank_id        Refseq_id
# 0    SAMN02603879      376848  GCA_000240165.1  GCF_000240165.1
# 1    SAMN14411170     6465981  GCA_011765705.1              NaN
# 2    SAMN14411171     6466001  GCA_011765735.1              NaN
# 3    SAMD00106498     2168011  GCA_003945305.1  GCF_003945305.1
# 4    SAMN05710194     1533101  GCA_002897315.1  GCF_002897315.1
# ..            ...         ...              ...              ...
# 232  SAMN03144971      315111  GCA_000959505.1  GCF_000959505.1
# 233  SAMN00623032       39588  GCA_000018505.1  GCF_000018505.1
# 234  SAMN03140189      315121  GCA_000959525.1  GCF_000959525.1
# 235  SAMN00255227      492528  GCA_000286575.1  GCF_000286575.1
# 236  SAMN02866398     1978921  GCA_003568605.1  GCF_003568605.1
#
# [237 rows x 4 columns]

# %% [markdown]
# ## 1.4. Adding new column with the downloaded NCBI IDs

# %%
len(podp_merged_df),len(filtered_df),len(np.unique(filtered_df['BioSample'])),len(np.unique(biosample_df['GenBank_id']))
### notice that we downloaded 237 out of the 259 unique BioSamples
# Out:
# (4896, 2120, 259, 237)

# %%
biosample_dict = dict(zip(biosample_df.Accession_id, biosample_df.GenBank_id))
new_col = []

for i,r in podp_merged_df.iterrows():
    biosample_id = podp_merged_df['BioSample'].loc[i]
    if biosample_id in biosample_dict.keys():
        new_col.append(biosample_dict[biosample_id])
    else:
        if 'GCA' in biosample_id or 'ERX' in biosample_id or 'ERS' in biosample_id:
            new_col.append(biosample_id)
        else:
            new_col.append('NaN')
        
podp_merged_df['New_NCBI_ID'] = new_col

podp_merged_df
# Out:
#               NCBI_ID           Database     BioSample  \
# 0     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 1     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 2     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 3     GCA_000240165.1   RefSeq_accession  SAMN02603879
# 4     GCA_000240165.1   RefSeq_accession  SAMN02603879
# ...               ...                ...           ...
# 4891  GCA_000286575.1  GenBank_accession  SAMN00255227
# 4892  GCA_000959505.1  GenBank_accession  SAMN03144971
# 4893  GCA_000959505.1  GenBank_accession  SAMN03144971
# 4894  GCA_003568605.1  GenBank_accession  SAMN02866398
# 4895  GCA_003568605.1  GenBank_accession  SAMN02866398
#
#                                               LCMS_file  \
# 0     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 1     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 2     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 3     ftp://massive.ucsd.edu/MSV000078850/results/S....
# 4     ftp://massive.ucsd.edu/MSV000078850/results/S....
# ...                                                 ...
# 4891  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 4892  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 4893  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 4894  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
# 4895  ftp://massive.ucsd.edu/MSV000084945/ccms_peak/...
#
#                          Genome_label  Method      New_NCBI_ID
# 0                         S. cattleya  genome  GCA_000240165.1
# 1                         S. cattleya  genome  GCA_000240165.1
# 2                         S. cattleya  genome  GCA_000240165.1
# 3                         S. cattleya  genome  GCA_000240165.1
# 4                         S. cattleya  genome  GCA_000240165.1
# ...                               ...     ...              ...
# 4891     Burkholderia multivorans CF2  genome  GCA_000286575.1
# 4892       Burkholderia dolosa AU0158  genome  GCA_000959505.1
# 4893       Burkholderia dolosa AU0158  genome  GCA_000959505.1
# 4894  Burkholderia thailandensis E264  genome  GCA_003568605.1
# 4895  Burkholderia thailandensis E264  genome  GCA_003568605.1
#
# [4896 rows x 7 columns]

# %%
count = 0
gca_list = []

for item in podp_merged_df.New_NCBI_ID:
    if 'GCA' in item:
        count += 1
        gca_list.append(item)
        
print(count,len(podp_merged_df[podp_merged_df['New_NCBI_ID'] == 'NaN']),
      len(np.unique(podp_merged_df[podp_merged_df['New_NCBI_ID'] == 'NaN']['NCBI_ID'])),len(podp_merged_df))
print(len(np.unique(gca_list)))
### notice that all 237 unique BioSamples generate a GCA code and there were 490/727 other genomes that can't be downloaded
# Out:
# 1383 2308 727 4896
# 237

# %% [markdown]
# ## 1.5. Downloading and unzipping the NCBI genomes

# %%
# !mkdir -p /Volumes/TFL190831/NPOmix_round4/podp_ncbi/

# %%
cmd_list,genomes_failed = [],[]

for i,r in podp_merged_df.iterrows():
    if type(r['New_NCBI_ID']) == float:
        n = re.match(r'^\D{4}\d{2}$',r['NCBI_ID'])
        if n:
            cmd = 'wget https://sra-download.ncbi.nlm.nih.gov/traces/wgs01/wgs_aux/%s/%s/%s/%s.1.fsa_nt.gz'%(r['NCBI_ID'][0:2],r['NCBI_ID'][2:4],r['NCBI_ID'],r['NCBI_ID'])
        if 'GCA' in str(r['NCBI_ID']):
            cmd = 'wget -nd -r --no-parent -A "genomic.fna.gz"  -R "*_from_genomic*" "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/%s/%s/%s/"'%(r['NCBI_ID'][4:7],r['NCBI_ID'][7:10],r['NCBI_ID'][10:13])
        if 'GCA' not in str(r['NCBI_ID']) and not n:
            cmd = None
    else:
        if 'GCA' in str(r['New_NCBI_ID']):
            cmd = 'wget -nd -r --no-parent -A "genomic.fna.gz"  -R "*_from_genomic*" "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/%s/%s/%s/"'%(r['New_NCBI_ID'][4:7],r['New_NCBI_ID'][7:10],r['New_NCBI_ID'][10:13])
        else:
            cmd = None
    if cmd != None:
        if cmd not in cmd_list:
            cmd_list.append(cmd)
#             try: #only run once
#                 subprocess.check_output(cmd, shell=True, cwd='/Volumes/TFL190831/NPOmix_round4/podp_ncbi/')
#             except subprocess.CalledProcessError as e:
#                 genomes_failed.append(cmd)

print(len(cmd_list),len(genomes_failed))
# Out:
# 237 0

# %%
# !ls /Volumes/TFL190831/NPOmix_round4_genomes/podp_ncbi/ | wc -l
# Out:
#      237

# %%
### only run once

# genome_list = glob.glob("/Volumes/TFL190831/podp_round4_ncbi/*.gz")

# for item in genome_list:
#     genome = os.path.basename(item).split('.')[0]
#     print(os.path.basename(item))
#     cmd = "gunzip -c %s > %s.fasta"%(os.path.basename(item),genome)
#     subprocess.check_output(cmd, shell=True, cwd='/Volumes/TFL190831/NPOmix_round4_genomes/podp_ncbi/')

# %%
# !rm /Volumes/TFL190831/NPOmix_round4_genomes/podp_ncbi/*.gz

# %% [markdown]
# ## 1.6. Copying previously downloaded genomes

# %%
glob_round3 = glob.glob('/Volumes/TFL190831/podp_round3_ncbi/*fasta')

for file_path in glob_round3:
    fasta_file = os.path.basename(file_path)
    if not os.path.exists('/Volumes/TFL190831/NPOmix_round4_genomes/podp_ncbi/%s'%fasta_file):
        cmd = 'cp %s /Volumes/TFL190831/NPOmix_round4/previous_genomes/'%file_path
#         subprocess.call(cmd, shell=True)

# %%
# !ls /Volumes/TFL190831/NPOmix_round4_genomes/podp_ncbi/*.fasta | wc -l
# Out:
#      237

# %%
# !ls /Volumes/TFL190831/NPOmix_round4_genomes/previous_genomes/*.fasta | wc -l
# Out:
#      174

# %%
AS_previous_list = glob.glob('/Volumes/TFL190831/nf_output-iomega/*')
count = 0

for file_path in AS_previous_list:
    AS_file = os.path.basename(file_path).split('_output')[0]
    if os.path.exists('/Volumes/TFL190831/NPOmix_round4_genomes/previous_genomes/%s'%AS_file):
        count += 1
    else:
        if os.path.exists('/Volumes/TFL190831/NPOmix_round4_genomes/podp_ncbi/%s'%AS_file):
            count += 1
            
count,len(AS_previous_list)
# Out:
# (279, 279)

# %%
previous_genomes = glob.glob('/Volumes/TFL190831/NPOmix_round4_genomes/previous_genomes/*fasta')
missing_from_podp = []

for item in previous_genomes:
    sum_item = os.path.basename(item).split('.')[0]
    temp_df = podp_merged_df[podp_merged_df['NCBI_ID'].str.contains(sum_item)]
    if len(temp_df) == 0:
        missing_from_podp.append(item)

len(missing_from_podp)        
### for now, eventhough we don't have these genomes in the current podp_list, we already have LCMS for those
# Out:
# 161

# %% [markdown]
# ## 1.7. Downloading metagenomic reads

# %%
# !mkdir /Volumes/TFL190831/NPOmix_round4/ERX_reads/
# !mkdir /Volumes/TFL190831/NPOmix_round4/ERS_reads/

# %%
len(np.unique(podp_merged_df[podp_merged_df['New_NCBI_ID'].str.contains('ERS')]['New_NCBI_ID']))
# Out:
# 724

# %%
len(np.unique(podp_merged_df[podp_merged_df['New_NCBI_ID'].str.contains('ERX')]['New_NCBI_ID']))
# Out:
# 481

# %%
### only run once
# !mkdir /Volumes/TFL190831/NPOmix_round4_genomes/ERX_fileroports/
# !mkdir /Volumes/TFL190831/NPOmix_round4_genomes/ERS_fileroports/

# %%
### only run once for ERS codes and one more time to ERX

# !mkdir /Volumes/TFL190831/NPOmix_round4_genomes/ERS_fileroports/

# for i,r in podp_merged_df.iterrows():
#     if 'ERS' in podp_merged_df['New_NCBI_ID'].loc[i]:
#         ena_code = podp_merged_df['New_NCBI_ID'].loc[i]
#         https_cmd = "wget \"https://www.ebi.ac.uk/ena/data/warehouse/filereport?accession=%s&result=read_run&fields=fastq_ftp\""%ena_code
#         subprocess.call(https_cmd, shell=True, cwd='/Volumes/TFL190831/NPOmix_round4_genomes/ERS_fileroports/')

# %%
https_list = glob.glob('/Volumes/TFL190831/NPOmix_round4_genomes/ERX_fileroports/filereport?accession=*')
cmd_list = []
ena_dict1 = {}

for item in https_list:
    https_df = pd.read_csv(item,sep='\t')
    read_1 = https_df['fastq_ftp'].loc[0].split(';')[0]
    cmd_list.append('wget ftp://%s'%read_1)
    ena_dict1[os.path.basename(read_1).split('.')[0]] = item[78:88]
    
# with open('./temp_files/ftp_ERX_list.txt', 'w') as filehandle:
#     filehandle.writelines("%s\n" % command for command in cmd_list)

# %%
ena_dict1['ERR2239508']
# Out:
# 'ERX2291668'

# %%
https_list = glob.glob('/Volumes/TFL190831/NPOmix_round4_genomes/ERS_fileroports/filereport?accession=*')
cmd_list = []
ena_dict2 = {}

for item in https_list:
    https_df = pd.read_csv(item,sep='\t')
    read_1 = https_df['fastq_ftp'].loc[0].split(';')[0]
    read_2 = https_df['fastq_ftp'].loc[0].split(';')[1]
    cmd_list.append('wget ftp://%s'%read_1)
    cmd_list.append('wget ftp://%s'%read_2)
    ena_dict2[os.path.basename(read_1).split('.')[0].split('_')[0]] = item[78:88]
    
# with open('./temp_files/ftp_ERS_list.txt', 'w') as filehandle:
#     filehandle.writelines("%s\n" % command for command in cmd_list)

# %%
ena_dict2['ERR3946693']
# Out:
# 'ERS4346398'

# %%
def Merge(dict1, dict2):
    res = {**dict1, **dict2}
    return res

ena_dict3 = Merge(ena_dict1, ena_dict2)

# with open('./temp_files/ena_dict-round3-210315.csv', 'w') as f:
#     for key in ena_dict3.keys():
#         f.write("%s,%s\n"%(key,ena_dict3[key]))

# %% [markdown]
# ```bash
# cd /Volumes/TFL190831/NPOmix_round4_genomes/ERX_reads/
#
# sh ./ftp_ERX_list.txt
# ```
# and alternatively
#
# ```bash
# cd /Volumes/TFL190831/NPOmix_round4_genomes/ERS_reads/
#
# sh ./ftp_ERS_list.txt
# ```

# %%
# !ls /Volumes/TFL190831/NPOmix_round4_genomes/ERS_reads/*fastq.gz | wc -l
# Out:
#     1448

# %%
# !ls /Volumes/TFL190831/NPOmix_round4_genomes/ERX_reads/*fastq.gz | wc -l
# Out:
#      481

# %% [markdown]
# ## 1.8. Downloading JGI (meta)genomes
#
# `Salinispora_genomes_faa` with 119 Salinisopra was provided by the Jensen lab

# %%
len(np.unique(podp_merged_df[podp_merged_df['Database'].str.contains('JGI')]['NCBI_ID']))
# Out:
# 309

# %%
# !mkdir /Volumes/TFL190831/NPOmix_round4_genomes/manual_genomes

# %%
download_col,download_list,sal_filt = [],[],[]
sal_glob = glob.glob('/Volumes/TFL190831/NPOmix_round4_genomes/Salinispora_genomes_faa/*.faa')

for item in sal_glob:
    sal_filt.append(os.path.basename(item).split('_')[0])

for i,r in podp_merged_df.iterrows():
    if 'JGI' in r['Database']:
        if 'Salinispora' in r['Genome_label']:
            sal_id = 'S' + r['Genome_label'][12] + r['Genome_label'].split(' ')[2]
            if sal_id in sal_filt:
                download_col.append('yes')
                download_list.append(sal_id)
            else:
                download_col.append('no')
        else:
            download_col.append('no')
    else:
        if r['New_NCBI_ID'] != 'NaN':
            download_col.append('yes')
        else:
            download_col.append('no')
            
podp_merged_df['Downloaded'] = download_col

# %%
len(np.unique(download_list)),len(download_col),len(podp_merged_df)
# Out:
# (112, 4896, 4896)

# %%
len(np.unique(podp_merged_df[podp_merged_df['Downloaded'] == 'yes']['New_NCBI_ID']))
# Out:
# 1443

# %%
podp_merged_df[podp_merged_df['Downloaded'] == 'no']
# Out:
#                    NCBI_ID           Database     BioSample  \
# 46              2821485673      JGI_Genome_ID  SAMN13061032
# 47              CP022686.1  GenBank_accession  No BioSample
# 48              CP022686.1  GenBank_accession  No BioSample
# 49              CP022686.1  GenBank_accession  No BioSample
# 50            MDRX01000000  GenBank_accession  No BioSample
# ...                    ...                ...           ...
# 3970  651717039, 651716642      JGI_Genome_ID  SAMN11997568
# 3971  651717039, 651716642      JGI_Genome_ID  SAMN11997568
# 3972  651717039, 651716642      JGI_Genome_ID  SAMN11997568
# 3973            2767802005      JGI_Genome_ID  SAMN02645517
# 4698                235463      JGI_Genome_ID   PRJNA639598
#
#                                               LCMS_file  \
# 46    ftp://massive.ucsd.edu/MSV000086050/updates/20...
# 47    ftp://massive.ucsd.edu/MSV000083387/peak/mzXML...
# 48    ftp://massive.ucsd.edu/MSV000083387/peak/mzXML...
# 49    ftp://massive.ucsd.edu/MSV000083387/peak/mzXML...
# 50    ftp://massive.ucsd.edu/MSV000085021/peak/DA2-8...
# ...                                                 ...
# 3970  ftp://massive.ucsd.edu/MSV000083648/raw/detoxi...
# 3971  ftp://massive.ucsd.edu/MSV000083648/raw/detoxi...
# 3972  ftp://massive.ucsd.edu/MSV000083648/raw/detoxi...
# 3973  ftp://massive.ucsd.edu/MSV000083648/raw/detoxi...
# 4698  ftp://massive.ucsd.edu/MSV000085586/peak/Actin...
#
#                                            Genome_label  \
# 46                                               GUM007
# 47                                  Ecoli_Nissle_genome
# 48                                  Ecoli_Nissle_genome
# 49                                  Ecoli_Nissle_genome
# 50                                              WMMB235
# ...                                                 ...
# 3970  Streptomyces spectabilis Dietz NRRL 2792 (ATCC...
# 3971  Streptomyces spectabilis Dietz NRRL 2792 (ATCC...
# 3972  Streptomyces spectabilis Dietz NRRL 2792 (ATCC...
# 3973                        Streptomyces sp. NRRL S-325
# 4698                       genome - Actinomadura BRA177
#
#                            Method New_NCBI_ID Downloaded
# 46    metagenome-assembled genome         NaN         no
# 47                         genome         NaN         no
# 48                         genome         NaN         no
# 49                         genome         NaN         no
# 50                         genome         NaN         no
# ...                           ...         ...        ...
# 3970                       genome         NaN         no
# 3971                       genome         NaN         no
# 3972                       genome         NaN         no
# 3973                       genome         NaN         no
# 4698                       genome         NaN         no
#
# [1849 rows x 8 columns]

# %% [markdown]
# Use the dataframe above to manually download these genomes searching at [NCBI database](https://www.ncbi.nlm.nih.gov/Traces/wgs/?page=1&view=all&search=GCF_000196155.1) and place them a the manual_genomes folder

# %%
manual_glob = glob.glob('/Volumes/TFL190831/NPOmix_round4_genomes/manual_genomes/*')

manual_list,indexes_to_keep = [],[]

for item in manual_glob:
    manual_list.append(os.path.basename(item).split('.fasta')[0])

for i,r in podp_merged_df.iterrows():
    if r['Downloaded'] == 'no':
        if r['NCBI_ID'] not in manual_list:
            indexes_to_keep.append(i)

# podp_merged_df.loc[indexes_to_keep].to_csv('./outputs/cant_download_podp_merged_df-round3-210315.tsv',sep='\t')

# %%
len(podp_merged_df[podp_merged_df['Downloaded'] == 'yes']),len(podp_merged_df[podp_merged_df['Downloaded'] == 'no']),len(podp_merged_df)
# Out:
# (3047, 1849, 4896)

# %%
len(np.unique(podp_merged_df.loc[indexes_to_keep]['NCBI_ID']))
# Out:
# 308

# %% [markdown]
# ## 1.9. Separating Genomes without antiSMASH (Optional)

# %%
# !mkdir /Volumes/TFL190831/genomes_to_antiSMASH/

# %%
AS_all_list = glob.glob('/Volumes/TFL190831/ming_output/antismash/*')
AS_list = []
count = 0

for file_path in AS_all_list:
    AS_file = file_path.split('/')[5].split('.')[0].split('_contigs')[0]
    if AS_file in ena_dict1:
        AS_list.append(ena_dict1[AS_file])
    if AS_file in ena_dict2:
        AS_list.append(ena_dict2[AS_file])
    if AS_file not in ena_dict1 and AS_file not in ena_dict2:
        AS_list.append(AS_file)

manual_genomes = glob.glob('/Volumes/TFL190831/NPOmix_round4_genomes/manual_genomes/*')
ncbi_genomes = glob.glob('/Volumes/TFL190831/NPOmix_round4_genomes/podp_ncbi/*')
sal_genomes = glob.glob('/Volumes/TFL190831/NPOmix_round4_genomes/Salinispora_genomes_faa/*')

for item in list(manual_genomes+ncbi_genomes+sal_genomes):
    if os.path.basename(item) not in AS_list:
        count += 1
        cmd = 'cp %s /Volumes/TFL190831/genomes_to_antiSMASH/'%item
#         subprocess.call(cmd,shell=True)
    
len(AS_list),count
# Out:
# (1766, 679)

# %% [markdown]
# ## 1.10. Running antiSMASH
#
# ```
# Ming will add code
# ```

# %% [markdown]
# ## 1.11. Filtering links for (meta)genomes with antiSMASH and downloading LC-MS/MS (need update)

# %%
# !ls /Volumes/TFL190831/ming_output/antismash/ | wc -l
# Out:
#     1766

# %%
updated_col = []

for i,r in podp_merged_df.iterrows():
    if r['New_NCBI_ID'] in AS_list:
        updated_col.append('yes')
    else:
        if r['NCBI_ID'] in AS_list:
            updated_col.append('yes')
        else:
            updated_col.append('no')
        
print(len(updated_col))
# Out:
# 4896

# %%
podp_merged_df['Downloaded'] = updated_col
podp_final_df = podp_merged_df[podp_merged_df['Downloaded'] == 'yes']
podp_final_df = podp_final_df.reset_index(drop=True)
# podp_final_df.to_csv('./outputs/podp_final_df-round4-210426.tsv',sep='\t')

# %%
podp_final_df
# Out:
#            NCBI_ID            Database     BioSample  \
# 0       2821485673       JGI_Genome_ID  SAMN13061032
# 1     MDRX01000000   GenBank_accession  No BioSample
# 2       2518285561       JGI_Genome_ID  No BioSample
# 3       2518285561       JGI_Genome_ID  No BioSample
# 4       2518285562       JGI_Genome_ID  No BioSample
# ...            ...                 ...           ...
# 2108    ERS4356320  ENA_NCBI_accession    ERS4356320
# 2109    ERS4356321  ENA_NCBI_accession    ERS4356321
# 2110    ERS4356322  ENA_NCBI_accession    ERS4356322
# 2111    ERS4356323  ENA_NCBI_accession    ERS4356323
# 2112    ERS4356324  ENA_NCBI_accession    ERS4356324
#
#                                               LCMS_file  \
# 0     ftp://massive.ucsd.edu/MSV000086050/updates/20...
# 1     ftp://massive.ucsd.edu/MSV000085021/peak/DA2-8...
# 2     ftp://massive.ucsd.edu/MSV000079284//raw/Dunca...
# 3     ftp://massive.ucsd.edu/MSV000079284//raw/Dunca...
# 4     ftp://massive.ucsd.edu/MSV000079284//raw/Dunca...
# ...                                                 ...
# 2108  ftp://massive.ucsd.edu/MSV000083302/peak/mzxml...
# 2109  ftp://massive.ucsd.edu/MSV000083302/peak/mzxml...
# 2110  ftp://massive.ucsd.edu/MSV000083302/peak/mzxml...
# 2111  ftp://massive.ucsd.edu/MSV000083302/peak/mzxml...
# 2112  ftp://massive.ucsd.edu/MSV000083302/peak/mzxml...
#
#                      Genome_label                       Method New_NCBI_ID  \
# 0                          GUM007  metagenome-assembled genome         NaN
# 1                         WMMB235                       genome         NaN
# 2     Salinispora pacifica CNR942                       genome         NaN
# 3     Salinispora pacifica CNR942                       genome         NaN
# 4     Salinispora pacifica CNS055                       genome         NaN
# ...                           ...                          ...         ...
# 2108                   ERS4356320                   metagenome  ERS4356320
# 2109                   ERS4356321                   metagenome  ERS4356321
# 2110                   ERS4356322                   metagenome  ERS4356322
# 2111                   ERS4356323                   metagenome  ERS4356323
# 2112                   ERS4356324                   metagenome  ERS4356324
#
#      Downloaded
# 0           yes
# 1           yes
# 2           yes
# 3           yes
# 4           yes
# ...         ...
# 2108        yes
# 2109        yes
# 2110        yes
# 2111        yes
# 2112        yes
#
# [2113 rows x 8 columns]

# %%
podp_merged_df.shape,podp_final_df.shape
# Out:
# ((4896, 8), (2113, 8))

# %%
lcms_list = []

lcms_glob = glob.glob('/Volumes/TFL210426/podp_LCMS/*')

for lcms_file in lcms_glob:
    lcms_list.append(os.path.basename(lcms_file.split('.')[0]))

lcms_list = list(np.unique(lcms_list))

len(lcms_list)
# Out:
# 1610

# %%
rows_wo_file,seen,commands = [],[],[]

for i,r in podp_final_df.iterrows():
    if podp_final_df['New_NCBI_ID'].loc[i] != 'NaN':
        genomeID = podp_final_df['New_NCBI_ID'].loc[i]
    else:
        genomeID = podp_final_df['NCBI_ID'].loc[i]
    seen.append(genomeID)
    file_count = seen.count(genomeID)
    extension = podp_final_df['LCMS_file'].loc[i].rsplit('.', 1)[1]
    if genomeID not in lcms_list:
        cmd = 'wget -O %s %s'%(genomeID+'.'+extension+'.'+str(file_count),podp_final_df['LCMS_file'].loc[i])
        commands.append(cmd)

len(commands)
# Out:
# 22

# %%
### only run once

# with open('./temp_files/PODP_LCMS_list_commands-round4.txt', "w") as output:
#     writer = csv.writer(output, lineterminator='\n')
#     for val in commands:
#         writer.writerow([val])

# %% [markdown]
# ```bash
# mkdir /Volumes/TFL190831/podp_LCMS
#
# cd /Volumes/TFL190831/podp_LCMS
#
# sh PODP_LCMS_list_commands-round3.txt
# ```

# %% [markdown]
# **Rename names containing ".1."**
#
# ```
# cd podp_LCMS/
#
# ls *.1.* | cat > rename.txt
#
# Edit rename.txt in a text editor
#
# sh rename.txt
# ```

# %% [markdown]
# ## 1.12 Download missing Gerwick cyanoibacterial MS/MS and selecting Gerwick mgf files

# %%
import re
import pandas as pd
import numpy as np
from pyteomics import mgf, auxiliary
import csv

# %% [markdown]
# ```
# Download all GNPS database from the link: https://gnps.ucsd.edu/ProteoSAFe/gnpslibrary.jsp?library=all
# ```

# %%
count = 0
colA = []
colB = []

with open('/Users/tiagoferreiraleao/Dropbox/tiago-NAS/NPOmix/inputs/ALL_GNPS.mgf') as fp:
    for line in fp:
        count += 1
        a = re.match(r'BEGIN IONS',line)
        if a:
            colA.append(count)
        b = re.match(r'END IONS',line)
        if b:
            colB.append(count)

print(len(colA),len(colB))
# Out:
# 448698 448698

# %%
col1 = []
col2 = []
col3 = []
col4 = []
col5 = []

with open('/Users/tiagoferreiraleao/Dropbox/tiago-NAS/NPOmix/inputs/ALL_GNPS.mgf') as fp:
    lines=fp.readlines()
    for index,item in enumerate(colA):
        pepmass = "N/A"
        name = "N/A"
        pi = "N/A"
        smiles = "N/A"
        gnps_id = "N/A"
        chunk = lines[item:colB[index]]
        for line in chunk:
            a = re.match(r'PEPMASS=(.*)',line)
            if a:
                pepmass = a.group(1)
            b = re.match(r'NAME=(.*)',line)
            if b:
                name = b.group(1)
            c = re.match(r'PI=(.*)',line)
            if c:
                pi = c.group(1)
            d = re.match(r'SMILES=(.*)',line)
            if d:
                smiles = d.group(1)
            e = re.match(r'SPECTRUMID=(.*)',line)
            if e:
                gnps_id = e.group(1)
        col1.append(pepmass)
        col2.append(name)
        col3.append(pi)
        col4.append(smiles)
        col5.append(gnps_id)
                
len(col1),len(col2),len(col3),len(col4),len(col5)
# Out:
# (448698, 448698, 448698, 448698, 448698)

# %%
gnps_df = pd.DataFrame(
    {'PEPMASS': col1,
     'NAME': col2,
     'PI': col3,
     'SMILES': col4,
     'SPECTRUMID': col5
    })

gnps_df
# Out:
#         PEPMASS                              NAME                    PI  \
# 0        981.54         3-Des-Microcystein_LR M+H               Gerwick
# 1        940.25                    Hoiamide B M+H               Gerwick
# 2         456.1                 Malyngamide C M+H               Gerwick
# 3         545.0                    Scytonemin M+H               Gerwick
# 4       314.116             Salinisporamide A M+H  Fenical-Jensen-Moore
# ...         ...                               ...                   ...
# 448693  277.218         Pinolenic acid - 20eV M-H                Sumner
# 448694  277.218         Pinolenic acid - 30eV M-H                Sumner
# 448695  279.234  9Z, 11E-Linoleic acid - 10eV M-H                Sumner
# 448696  279.232  9Z, 11E-Linoleic acid - 30eV M-H                Sumner
# 448697  279.233  9Z, 11E-Linoleic acid - 20eV M-H                Sumner
#
#                                                    SMILES          SPECTRUMID
# 0       CC(C)CC1NC(=O)C(C)NC(=O)C(=C)N(C)C(=O)CCC(NC(=...  CCMSLIB00000001547
# 1       CCC[C@@H](C)[C@@H]([C@H](C)[C@@H]1[C@H]([C@H](...  CCMSLIB00000001548
# 2       CCCCCCC[C@@H](C/C=C/CCC(=O)NC/C(=C/Cl)/[C@@]12...  CCMSLIB00000001549
# 3       OC1=CC=C(\C=C2\C(=O)C(C3=C4C5=C(C=CC=C5)N=C4\C...  CCMSLIB00000001550
# 4                                                     N/A  CCMSLIB00000001551
# ...                                                   ...                 ...
# 448693                   CCCCC/C=C\C/C=C\CC/C=C\CCCC(=O)O  CCMSLIB00004684135
# 448694                   CCCCC/C=C\C/C=C\CC/C=C\CCCC(=O)O  CCMSLIB00004684136
# 448695                       CCCCCC/C=C/C=C\CCCCCCCC(=O)O  CCMSLIB00004684137
# 448696                       CCCCCC/C=C/C=C\CCCCCCCC(=O)O  CCMSLIB00004684138
# 448697                       CCCCCC/C=C/C=C\CCCCCCCC(=O)O  CCMSLIB00004684139
#
# [448698 rows x 5 columns]

# %%
gerwick_df = gnps_df[gnps_df["PI"].isin(["Gerwick","Dr. Gerwick","W. Gerwick","Dorrestein/Gerwick","Pieter Dorrestein &amp; Lena Gerwick","William Gerwick"])]

gerwick_df
# Out:
#       PEPMASS                         NAME          PI  \
# 0      981.54    3-Des-Microcystein_LR M+H     Gerwick
# 1      940.25               Hoiamide B M+H     Gerwick
# 2       456.1            Malyngamide C M+H     Gerwick
# 3       545.0               Scytonemin M+H     Gerwick
# 5     667.115             Hectochlorin M+H     Gerwick
# ...       ...                          ...         ...
# 6142   1201.5           Kurahamide B M+NH4     Gerwick
# 6702  1156.59  Rivulariapeptolide 1155 M+H     Gerwick
# 6714   400.25          Cryptomaldamice M+H     Gerwick
# 6726  400.257          Cryptomaldamide M+H     Gerwick
# 6771  1141.47               yessotoxin M-H  W. Gerwick
#
#                                                  SMILES          SPECTRUMID
# 0     CC(C)CC1NC(=O)C(C)NC(=O)C(=C)N(C)C(=O)CCC(NC(=...  CCMSLIB00000001547
# 1     CCC[C@@H](C)[C@@H]([C@H](C)[C@@H]1[C@H]([C@H](...  CCMSLIB00000001548
# 2     CCCCCCC[C@@H](C/C=C/CCC(=O)NC/C(=C/Cl)/[C@@]12...  CCMSLIB00000001549
# 3     OC1=CC=C(\C=C2\C(=O)C(C3=C4C5=C(C=CC=C5)N=C4\C...  CCMSLIB00000001550
# 5     C[C@H]1[C@@H](OC(C2=CSC([C@H](C(C)(OC(C3=CSC([...  CCMSLIB00000001552
# ...                                                 ...                 ...
# 6142  CCCC(N[C@H](C(N[C@H](C(N[C@H]1[C@@H](C)OC([C@H...  CCMSLIB00005723420
# 6702  CC(C)[C@@H](NC([C@@H](CC1=CC=C(O)C=C1)N(C)C([C...  CCMSLIB00005723986
# 6714  NC(N[C@@H](CO)C(N[C@@H](C(C)C)C(N(C)[C@@H](C(C...  CCMSLIB00005724004
# 6726  CC(C)[C@@H](/C=C(\C)/C(=O)O)N(C)C(=O)[C@H](C(C...  CCMSLIB00005724017
# 6771  C[C@H]1CC[C@]2([C@@H](C[C@H]3[C@](O2)(CC[C@H]4...  CCMSLIB00005724062
#
# [629 rows x 5 columns]

# %%
gnps_df2 = gerwick_df[gerwick_df["SMILES"] != "N/A"]
gnps_df2 = gnps_df2[gnps_df2["SMILES"] != ' ']
gnps_df2 = gnps_df2[gnps_df2["SMILES"] != 'NaN']
gnps_df2 = gnps_df2.fillna(0)
gnps_df2 = gnps_df2[gnps_df2["SMILES"] != 0]
gnps_df2 = gnps_df2[gnps_df2["SMILES"] != 'c']
gnps_df2 = gnps_df2[gnps_df2["SMILES"] != 'no data']

gnps_df2.reset_index(inplace=True,drop=True)

gnps_df2
# Out:
#      PEPMASS                         NAME          PI  \
# 0     981.54    3-Des-Microcystein_LR M+H     Gerwick
# 1     940.25               Hoiamide B M+H     Gerwick
# 2      456.1            Malyngamide C M+H     Gerwick
# 3      545.0               Scytonemin M+H     Gerwick
# 4    667.115             Hectochlorin M+H     Gerwick
# ..       ...                          ...         ...
# 401   1201.5           Kurahamide B M+NH4     Gerwick
# 402  1156.59  Rivulariapeptolide 1155 M+H     Gerwick
# 403   400.25          Cryptomaldamice M+H     Gerwick
# 404  400.257          Cryptomaldamide M+H     Gerwick
# 405  1141.47               yessotoxin M-H  W. Gerwick
#
#                                                 SMILES          SPECTRUMID
# 0    CC(C)CC1NC(=O)C(C)NC(=O)C(=C)N(C)C(=O)CCC(NC(=...  CCMSLIB00000001547
# 1    CCC[C@@H](C)[C@@H]([C@H](C)[C@@H]1[C@H]([C@H](...  CCMSLIB00000001548
# 2    CCCCCCC[C@@H](C/C=C/CCC(=O)NC/C(=C/Cl)/[C@@]12...  CCMSLIB00000001549
# 3    OC1=CC=C(\C=C2\C(=O)C(C3=C4C5=C(C=CC=C5)N=C4\C...  CCMSLIB00000001550
# 4    C[C@H]1[C@@H](OC(C2=CSC([C@H](C(C)(OC(C3=CSC([...  CCMSLIB00000001552
# ..                                                 ...                 ...
# 401  CCCC(N[C@H](C(N[C@H](C(N[C@H]1[C@@H](C)OC([C@H...  CCMSLIB00005723420
# 402  CC(C)[C@@H](NC([C@@H](CC1=CC=C(O)C=C1)N(C)C([C...  CCMSLIB00005723986
# 403  NC(N[C@@H](CO)C(N[C@@H](C(C)C)C(N(C)[C@@H](C(C...  CCMSLIB00005724004
# 404  CC(C)[C@@H](/C=C(\C)/C(=O)O)N(C)C(=O)[C@H](C(C...  CCMSLIB00005724017
# 405  C[C@H]1CC[C@]2([C@@H](C[C@H]3[C@](O2)(CC[C@H]4...  CCMSLIB00005724062
#
# [406 rows x 5 columns]

# %%
select_list = []

for item in gnps_df2['SPECTRUMID']:
    select_list.append(item)

select_list
# Out:
# ['CCMSLIB00000001547',
#  'CCMSLIB00000001548',
#  'CCMSLIB00000001549',
#  'CCMSLIB00000001550',
#  'CCMSLIB00000001552',
#  'CCMSLIB00000001553',
#  'CCMSLIB00000001555',
#  'CCMSLIB00000001558',
#  'CCMSLIB00000001560',
#  'CCMSLIB00000001562',
#  'CCMSLIB00000001564',
#  'CCMSLIB00000001565',
#  'CCMSLIB00000001567',
#  'CCMSLIB00000001569',
#  'CCMSLIB00000001571',
#  'CCMSLIB00000001573',
#  'CCMSLIB00000001575',
#  'CCMSLIB00000001577',
#  'CCMSLIB00000001579',
#  'CCMSLIB00000001581',
#  'CCMSLIB00000001583',
#  'CCMSLIB00000001585',
#  'CCMSLIB00000001587',
#  'CCMSLIB00000001589',
#  'CCMSLIB00000001591',
#  'CCMSLIB00000001595',
#  'CCMSLIB00000001597',
#  'CCMSLIB00000001601',
#  'CCMSLIB00000001603',
#  'CCMSLIB00000001605',
#  'CCMSLIB00000001608',
#  'CCMSLIB00000001626',
#  'CCMSLIB00000001628',
#  'CCMSLIB00000001630',
#  'CCMSLIB00000001632',
#  'CCMSLIB00000001634',
#  'CCMSLIB00000001636',
#  'CCMSLIB00000001638',
#  'CCMSLIB00000001640',
#  'CCMSLIB00000001642',
#  'CCMSLIB00000001644',
#  'CCMSLIB00000001646',
#  'CCMSLIB00000001648',
#  'CCMSLIB00000001650',
#  'CCMSLIB00000001652',
#  'CCMSLIB00000001654',
#  'CCMSLIB00000001656',
#  'CCMSLIB00000001658',
#  'CCMSLIB00000001660',
#  'CCMSLIB00000001662',
#  'CCMSLIB00000001664',
#  'CCMSLIB00000001666',
#  'CCMSLIB00000001674',
#  'CCMSLIB00000001675',
#  'CCMSLIB00000001677',
#  'CCMSLIB00000001679',
#  'CCMSLIB00000001683',
#  'CCMSLIB00000001685',
#  'CCMSLIB00000001687',
#  'CCMSLIB00000001688',
#  'CCMSLIB00000001689',
#  'CCMSLIB00000001690',
#  'CCMSLIB00000001691',
#  'CCMSLIB00000001692',
#  'CCMSLIB00000001693',
#  'CCMSLIB00000001694',
#  'CCMSLIB00000001695',
#  'CCMSLIB00000001697',
#  'CCMSLIB00000001698',
#  'CCMSLIB00000001699',
#  'CCMSLIB00000001700',
#  'CCMSLIB00000001701',
#  'CCMSLIB00000001702',
#  'CCMSLIB00000001703',
#  'CCMSLIB00000001704',
#  'CCMSLIB00000001705',
#  'CCMSLIB00000001706',
#  'CCMSLIB00000001707',
#  'CCMSLIB00000001708',
#  'CCMSLIB00000001711',
#  'CCMSLIB00000001712',
#  'CCMSLIB00000001713',
#  'CCMSLIB00000001714',
#  'CCMSLIB00000001715',
#  'CCMSLIB00000001716',
#  'CCMSLIB00000001717',
#  'CCMSLIB00000001718',
#  'CCMSLIB00000001719',
#  'CCMSLIB00000001720',
#  'CCMSLIB00000001721',
#  'CCMSLIB00000001722',
#  'CCMSLIB00000001723',
#  'CCMSLIB00000001724',
#  'CCMSLIB00000001727',
#  'CCMSLIB00000001728',
#  'CCMSLIB00000001729',
#  'CCMSLIB00000001730',
#  'CCMSLIB00000001731',
#  'CCMSLIB00000001732',
#  'CCMSLIB00000001733',
#  'CCMSLIB00000001742',
#  'CCMSLIB00000001743',
#  'CCMSLIB00000001744',
#  'CCMSLIB00000001747',
#  'CCMSLIB00000001751',
#  'CCMSLIB00000001756',
#  'CCMSLIB00000001757',
#  'CCMSLIB00000001758',
#  'CCMSLIB00000001759',
#  'CCMSLIB00000001760',
#  'CCMSLIB00000001761',
#  'CCMSLIB00000001762',
#  'CCMSLIB00000001763',
#  'CCMSLIB00000001768',
#  'CCMSLIB00000001769',
#  'CCMSLIB00000001770',
#  'CCMSLIB00000001771',
#  'CCMSLIB00000001772',
#  'CCMSLIB00000001773',
#  'CCMSLIB00000001774',
#  'CCMSLIB00000001776',
#  'CCMSLIB00000001777',
#  'CCMSLIB00000001778',
#  'CCMSLIB00000001783',
#  'CCMSLIB00000001784',
#  'CCMSLIB00000001785',
#  'CCMSLIB00000001786',
#  'CCMSLIB00000001787',
#  'CCMSLIB00000001788',
#  'CCMSLIB00000001789',
#  'CCMSLIB00000001790',
#  'CCMSLIB00000001791',
#  'CCMSLIB00000001792',
#  'CCMSLIB00000001793',
#  'CCMSLIB00000001797',
#  'CCMSLIB00000001798',
#  'CCMSLIB00000001799',
#  'CCMSLIB00000001800',
#  'CCMSLIB00000001803',
#  'CCMSLIB00000001804',
#  'CCMSLIB00000001805',
#  'CCMSLIB00000001806',
#  'CCMSLIB00000001809',
#  'CCMSLIB00000001810',
#  'CCMSLIB00000001811',
#  'CCMSLIB00000001812',
#  'CCMSLIB00000001813',
#  'CCMSLIB00000001814',
#  'CCMSLIB00000001815',
#  'CCMSLIB00000001817',
#  'CCMSLIB00000006872',
#  'CCMSLIB00000006873',
#  'CCMSLIB00000006874',
#  'CCMSLIB00000006875',
#  'CCMSLIB00000006883',
#  'CCMSLIB00000006900',
#  'CCMSLIB00000068215',
#  'CCMSLIB00000068216',
#  'CCMSLIB00000068217',
#  'CCMSLIB00000068218',
#  'CCMSLIB00000068219',
#  'CCMSLIB00000068221',
#  'CCMSLIB00000068223',
#  'CCMSLIB00000068226',
#  'CCMSLIB00000068229',
#  'CCMSLIB00000068232',
#  'CCMSLIB00000070245',
#  'CCMSLIB00000070246',
#  'CCMSLIB00000070247',
#  'CCMSLIB00000070255',
#  'CCMSLIB00000070256',
#  'CCMSLIB00000070257',
#  'CCMSLIB00000070258',
#  'CCMSLIB00000070259',
#  'CCMSLIB00000070260',
#  'CCMSLIB00000070261',
#  'CCMSLIB00000070263',
#  'CCMSLIB00000070265',
#  'CCMSLIB00000070266',
#  'CCMSLIB00000070282',
#  'CCMSLIB00000070287',
#  'CCMSLIB00000070288',
#  'CCMSLIB00000070289',
#  'CCMSLIB00000070290',
#  'CCMSLIB00000070293',
#  'CCMSLIB00000070294',
#  'CCMSLIB00000070295',
#  'CCMSLIB00000070296',
#  'CCMSLIB00000070301',
#  'CCMSLIB00000070302',
#  'CCMSLIB00000070304',
#  'CCMSLIB00000071748',
#  'CCMSLIB00000071750',
#  'CCMSLIB00000071751',
#  'CCMSLIB00000071752',
#  'CCMSLIB00000071754',
#  'CCMSLIB00000071755',
#  'CCMSLIB00000071756',
#  'CCMSLIB00000071757',
#  'CCMSLIB00000071761',
#  'CCMSLIB00000071762',
#  'CCMSLIB00000072478',
#  'CCMSLIB00000072479',
#  'CCMSLIB00000072480',
#  'CCMSLIB00000072481',
#  'CCMSLIB00000072489',
#  'CCMSLIB00000072490',
#  'CCMSLIB00000072491',
#  'CCMSLIB00000072492',
#  'CCMSLIB00000072493',
#  'CCMSLIB00000072494',
#  'CCMSLIB00000072501',
#  'CCMSLIB00000072502',
#  'CCMSLIB00000072503',
#  'CCMSLIB00000072504',
#  'CCMSLIB00000072507',
#  'CCMSLIB00000072508',
#  'CCMSLIB00000072509',
#  'CCMSLIB00000072510',
#  'CCMSLIB00000072511',
#  'CCMSLIB00000072512',
#  'CCMSLIB00000072521',
#  'CCMSLIB00000072522',
#  'CCMSLIB00000072529',
#  'CCMSLIB00000072530',
#  'CCMSLIB00000078897',
#  'CCMSLIB00000078898',
#  'CCMSLIB00000424800',
#  'CCMSLIB00000424822',
#  'CCMSLIB00000424823',
#  'CCMSLIB00000424827',
#  'CCMSLIB00000424828',
#  'CCMSLIB00000477991',
#  'CCMSLIB00000477995',
#  'CCMSLIB00000478597',
#  'CCMSLIB00000478598',
#  'CCMSLIB00000478599',
#  'CCMSLIB00000478600',
#  'CCMSLIB00000478601',
#  'CCMSLIB00000478602',
#  'CCMSLIB00000478603',
#  'CCMSLIB00000531496',
#  'CCMSLIB00000531500',
#  'CCMSLIB00000531501',
#  'CCMSLIB00000531502',
#  'CCMSLIB00000840559',
#  'CCMSLIB00000840560',
#  'CCMSLIB00000840561',
#  'CCMSLIB00004682331',
#  'CCMSLIB00004722207',
#  'CCMSLIB00004722208',
#  'CCMSLIB00004722209',
#  'CCMSLIB00004722210',
#  'CCMSLIB00004722211',
#  'CCMSLIB00004722212',
#  'CCMSLIB00004722213',
#  'CCMSLIB00004722214',
#  'CCMSLIB00004722215',
#  'CCMSLIB00004722216',
#  'CCMSLIB00004722217',
#  'CCMSLIB00004722218',
#  'CCMSLIB00004722219',
#  'CCMSLIB00004722220',
#  'CCMSLIB00004722221',
#  'CCMSLIB00004722222',
#  'CCMSLIB00004722223',
#  'CCMSLIB00004752995',
#  'CCMSLIB00004752996',
#  'CCMSLIB00004753000',
#  'CCMSLIB00004753001',
#  'CCMSLIB00004753002',
#  'CCMSLIB00004753003',
#  'CCMSLIB00004753004',
#  'CCMSLIB00005435621',
#  'CCMSLIB00005435622',
#  'CCMSLIB00005435792',
#  'CCMSLIB00005436029',
#  'CCMSLIB00005436030',
#  'CCMSLIB00005436031',
#  'CCMSLIB00005436032',
#  'CCMSLIB00005436033',
#  'CCMSLIB00005436034',
#  'CCMSLIB00005436071',
#  'CCMSLIB00005436072',
#  'CCMSLIB00005436074',
#  'CCMSLIB00005436075',
#  'CCMSLIB00005436076',
#  'CCMSLIB00005436077',
#  'CCMSLIB00005436085',
#  'CCMSLIB00005436086',
#  'CCMSLIB00005436459',
#  'CCMSLIB00005436460',
#  'CCMSLIB00005436463',
#  'CCMSLIB00005436466',
#  'CCMSLIB00005436470',
#  'CCMSLIB00005436494',
#  'CCMSLIB00005436496',
#  'CCMSLIB00005436497',
#  'CCMSLIB00005463461',
#  'CCMSLIB00005463462',
#  'CCMSLIB00005463464',
#  'CCMSLIB00005463465',
#  'CCMSLIB00005463466',
#  'CCMSLIB00005463467',
#  'CCMSLIB00005463468',
#  'CCMSLIB00005463469',
#  'CCMSLIB00005463470',
#  'CCMSLIB00005463471',
#  'CCMSLIB00005463472',
#  'CCMSLIB00005463473',
#  'CCMSLIB00005463474',
#  'CCMSLIB00005463475',
#  'CCMSLIB00005463477',
#  'CCMSLIB00005463853',
#  'CCMSLIB00005463854',
#  'CCMSLIB00005463855',
#  'CCMSLIB00005463857',
#  'CCMSLIB00005463858',
#  'CCMSLIB00005463859',
#  'CCMSLIB00005464636',
#  'CCMSLIB00005464637',
#  'CCMSLIB00005464638',
#  'CCMSLIB00005464639',
#  'CCMSLIB00005464640',
#  'CCMSLIB00005464641',
#  'CCMSLIB00005464642',
#  'CCMSLIB00005464643',
#  'CCMSLIB00005466096',
#  'CCMSLIB00005466097',
#  'CCMSLIB00005467777',
#  'CCMSLIB00005467778',
#  'CCMSLIB00005467779',
#  'CCMSLIB00005467780',
#  'CCMSLIB00005467781',
#  'CCMSLIB00005467782',
#  'CCMSLIB00005467783',
#  'CCMSLIB00005467784',
#  'CCMSLIB00005467785',
#  'CCMSLIB00005467786',
#  'CCMSLIB00005467787',
#  'CCMSLIB00005467788',
#  'CCMSLIB00005467789',
#  'CCMSLIB00005467790',
#  'CCMSLIB00005467791',
#  'CCMSLIB00005467792',
#  'CCMSLIB00005467793',
#  'CCMSLIB00005467794',
#  'CCMSLIB00005467795',
#  'CCMSLIB00005467796',
#  'CCMSLIB00005467800',
#  'CCMSLIB00005467801',
#  'CCMSLIB00005467802',
#  'CCMSLIB00005467803',
#  'CCMSLIB00005720212',
#  'CCMSLIB00005720213',
#  'CCMSLIB00005720214',
#  'CCMSLIB00005720215',
#  'CCMSLIB00005720216',
#  'CCMSLIB00005720217',
#  'CCMSLIB00005720230',
#  'CCMSLIB00005720231',
#  'CCMSLIB00005720233',
#  'CCMSLIB00005720234',
#  'CCMSLIB00005720235',
#  'CCMSLIB00005720236',
#  'CCMSLIB00005721064',
#  'CCMSLIB00005721065',
#  'CCMSLIB00005723386',
#  'CCMSLIB00005723387',
#  'CCMSLIB00005723388',
#  'CCMSLIB00005723389',
#  'CCMSLIB00005723390',
#  'CCMSLIB00005723391',
#  'CCMSLIB00005723392',
#  'CCMSLIB00005723393',
#  'CCMSLIB00005723394',
#  'CCMSLIB00005723395',
#  'CCMSLIB00005723396',
#  'CCMSLIB00005723397',
#  'CCMSLIB00005723398',
#  'CCMSLIB00005723399',
#  'CCMSLIB00005723400',
#  'CCMSLIB00005723401',
#  'CCMSLIB00005723402',
#  'CCMSLIB00005723403',
#  'CCMSLIB00005723404',
#  'CCMSLIB00005723405',
#  'CCMSLIB00005723406',
#  'CCMSLIB00005723407',
#  'CCMSLIB00005723408',
#  'CCMSLIB00005723409',
#  'CCMSLIB00005723410',
#  'CCMSLIB00005723411',
#  'CCMSLIB00005723412',
#  'CCMSLIB00005723413',
#  'CCMSLIB00005723414',
#  'CCMSLIB00005723415',
#  'CCMSLIB00005723416',
#  'CCMSLIB00005723417',
#  'CCMSLIB00005723418',
#  'CCMSLIB00005723419',
#  'CCMSLIB00005723420',
#  'CCMSLIB00005723986',
#  'CCMSLIB00005724004',
#  'CCMSLIB00005724017',
#  'CCMSLIB00005724062']

# %%
with mgf.MGF('/Users/tiagoferreiraleao/Dropbox/tiago-NAS/NPOmix/inputs/ALL_GNPS.mgf') as reader:
    for spectrum in reader:
        if spectrum['params']['spectrumid'] in select_list:
            individual_spec = []
            individual_spec.append(spectrum)
            output_file = '/Users/tiagoferreiraleao/Dropbox/tiago-NAS/NPOmix/NPOmix_mgf_spectra/%s.mgf'%(spectrum['params']['spectrumid'])
#             mgf.write(spectra=individual_spec, header='', output=output_file)

# %%
# !ls /Users/tiagoferreiraleao/Dropbox/tiago-NAS/NPOmix/NPOmix_mgf_spectra/ | wc -l
# Out:
#      406

# %%
#downloaded file from the Gerwick dataset with 
podp_lena_df = pd.read_csv('/Users/tiagoferreiraleao/Dropbox/tiago-NAS/NPOmix/inputs/paired-864909ec-e716-4c5a-bfe3-ce3a169b8844.2-genome-metabolome.csv',sep=',')

podp_lena_df
# Out:
#             Genome/Metagenome  \
# 0         Symploca sp. SIO1B1
# 1       Cyanothece sp. SIO1E1
# 2           Moorea sp. SIO1F2
# 3          Okeania sp. SIO1F9
# 4          Okeania sp. SIO1F9
# ..                        ...
# 109   Leptolyngbya sp. SIO4C5
# 110         Moorea sp. SIO4G2
# 111         Moorea sp. SIO4G3
# 112        Moorea sp. SIOASIH
# 113  Leptolyngbya sp. SIOISBB
#
#                     Location of metabolomics data file        NCBI ID  \
# 0    ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010672945
# 1    ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010672835
# 2    ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010672755
# 3    ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010672745
# 4    ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010672745
# ..                                                 ...            ...
# 109  ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010671965
# 110  ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010692345
# 111  ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010692305
# 112  ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010671925
# 113  ftp://massive.ucsd.edu/MSV000085210/raw/iomega...  GCA_010671905
#
#     Sample Growth Conditions Extraction Method Instrumentation Method
# 0                   SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# 1                   SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# 2                   SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# 3                   SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# 4                   SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# ..                       ...               ...                    ...
# 109                 SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# 110                 SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# 111                 SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# 112                 SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
# 113                 SW-BG-11      2:1 DCM:MeOH             Maxis LCMS
#
# [114 rows x 6 columns]

# %%
rows_wo_file,seen,commands = [],[],[]

for i,r in podp_lena_df.iterrows():
    genomeID = podp_lena_df['NCBI ID'].loc[i]
    seen.append(genomeID)
    file_count = seen.count(genomeID)
    extension = podp_lena_df['Location of metabolomics data file'].loc[i].rsplit('.', 1)[1]
    cmd = 'wget -O %s %s'%(genomeID+'.'+extension+'.'+str(file_count),podp_lena_df['Location of metabolomics data file'].loc[i])
    commands.append(cmd)

len(commands)
# Out:
# 114

# %%
commands
# Out:
# ['wget -O GCA_010672945.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2248%20cr_GC6_01_37750.mzXML',
#  'wget -O GCA_010672835.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/PAB18MAY11_9_C_GA10_01_37730.mzXML',
#  'wget -O GCA_010672755.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2239%20cr_GG1_01_37793.mzXML',
#  'wget -O GCA_010672745.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2058%20D_GD8_01_37764.mzXML',
#  'wget -O GCA_010672745.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2058%20H_GD9_01_37765.mzXML',
#  'wget -O GCA_010672795.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2035%20cr_GD1_01_37757.mzXML',
#  'wget -O GCA_010672695.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015E11_RE11_01_13970.mzXML',
#  'wget -O GCA_010672695.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1766_015F11_RF11_01_13982.mzXML',
#  'wget -O GCA_010672695.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015F2_RF2_01_13972.mzXML',
#  'wget -O GCA_010672695.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015F3_RF3_01_13973.mzXML',
#  'wget -O GCA_010672695.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015F4_RF4_01_13974.mzXML',
#  'wget -O GCA_010672695.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015F5_RF5_01_13975.mzXML',
#  'wget -O GCA_010672695.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015F6_RF6_01_13976.mzXML',
#  'wget -O GCA_010672695.mzXML.8 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015F7_RF7_01_13977.mzXML',
#  'wget -O GCA_010672695.mzXML.9 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015F8_RF8_01_13978.mzXML',
#  'wget -O GCA_010672695.mzXML.10 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1765_015F9_RF9_01_13979.mzXML',
#  'wget -O GCA_010672535.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2046%20cr_GD7_01_37763.mzXML',
#  'wget -O GCA_010672505.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1736_013F2_RF2_01_13801.mzXML',
#  'wget -O GCA_010672505.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1736_013F3_RF3_01_13805.mzXML',
#  'wget -O GCA_010672505.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1736_013F4_RF4_01_13806.mzXML',
#  'wget -O GCA_010672505.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1736_013F5_RF5_01_13807.mzXML',
#  'wget -O GCA_010672505.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1736_013F6_RF6_01_13808.mzXML',
#  'wget -O GCA_010672505.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1736_013F7_RF7_01_13809.mzXML',
#  'wget -O GCA_010672505.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1736_013F8_RF8_01_13810.mzXML',
#  'wget -O GCA_010672505.mzXML.8 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1736_013F10_RF10_01_13812.mzXML',
#  'wget -O GCA_010692635.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2080%20cr_GE2_01_37770.mzXML',
#  'wget -O GCA_010672485.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2093%20cr_GE5_01_37773.mzXML',
#  'wget -O GCA_010672455.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1952_028A5_GA5_01_15275.mzXML',
#  'wget -O GCA_010672455.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1952_028A6_GA6_01_15276.mzXML',
#  'wget -O GCA_010672455.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1952_028A7_2_GA7_01_15279.mzXML',
#  'wget -O GCA_010672455.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1952_028A8_GA8_01_15278.mzXML',
#  'wget -O GCA_010672455.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1952_028A9_GA9_01_15281.mzXML',
#  'wget -O GCA_010672455.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1952_028A10_GA10_01_15282.mzXML',
#  'wget -O GCA_010672455.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1952_028A11_GA11_01_15283.mzXML',
#  'wget -O GCA_010672405.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1831_018A6_GA6_01_14226.mzXML',
#  'wget -O GCA_010692645.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1716_012E3_GE3_01_13654.mzXML',
#  'wget -O GCA_010672385.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027E8_RE8_01_15222.mzXML',
#  'wget -O GCA_010672385.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027E9_RE9_01_15223.mzXML',
#  'wget -O GCA_010672385.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027E10_RE10_01_15224.mzXML',
#  'wget -O GCA_010672385.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027E11_RE11_01_15225.mzXML',
#  'wget -O GCA_010672385.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1944_027F10_RF10_01_15236.mzXML',
#  'wget -O GCA_010672385.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027F2_RF2_01_15227.mzXML',
#  'wget -O GCA_010672385.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027F3_RF3_01_15228.mzXML',
#  'wget -O GCA_010672385.mzXML.8 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027F4_RF4_01_15229.mzXML',
#  'wget -O GCA_010672385.mzXML.9 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027F5_RF5_01_15230.mzXML',
#  'wget -O GCA_010672385.mzXML.10 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1943_027F6_RF6_01_15231.mzXML',
#  'wget -O GCA_010692685.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027D9_RD9_01_15211.mzXML',
#  'wget -O GCA_010692685.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027D10_RD10_01_15212.mzXML',
#  'wget -O GCA_010692685.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027D11_RD11_01_15213.mzXML',
#  'wget -O GCA_010692685.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027E2_RE2_01_15215.mzXML',
#  'wget -O GCA_010692685.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027E3_RE3_01_15216.mzXML',
#  'wget -O GCA_010692685.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027E4_RE4_01_15217.mzXML',
#  'wget -O GCA_010692685.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027E5_RE5_01_15218.mzXML',
#  'wget -O GCA_010692685.mzXML.8 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027E6_RE6_01_15219.mzXML',
#  'wget -O GCA_010692685.mzXML.9 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1942_027E7_RE7_01_15220.mzXML',
#  'wget -O GCA_010672365.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024A5_GA5_01_14839.mzXML',
#  'wget -O GCA_010672365.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024A6_GA6_01_14840.mzXML',
#  'wget -O GCA_010672365.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024A7_GA7_01_14841.mzXML',
#  'wget -O GCA_010672365.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024A8_GA8_01_14842.mzXML',
#  'wget -O GCA_010672365.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024A9_GA9_01_14843.mzXML',
#  'wget -O GCA_010672365.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024A10_GA10_01_14844.mzXML',
#  'wget -O GCA_010672365.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024A11_GA11_01_14845.mzXML',
#  'wget -O GCA_010672365.mzXML.8 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/DMSO_1893_024B12_GB12_01_14852.mzXML',
#  'wget -O GCA_010672365.mzXML.9 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024B2_GB2_01_14847.mzXML',
#  'wget -O GCA_010672365.mzXML.10 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1891_024B3_GB3_01_14848.mzXML',
#  'wget -O GCA_010672305.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1872_022F2_GF2_01_14710.mzXML',
#  'wget -O GCA_010672305.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1872_022F3_GF3_01_14711.mzXML',
#  'wget -O GCA_010672305.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1872_022F4_GF4_01_14712.mzXML',
#  'wget -O GCA_010672305.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1872_022F5_GF5_01_14713.mzXML',
#  'wget -O GCA_010672305.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1872_022F6_GF6_01_14714.mzXML',
#  'wget -O GCA_010672305.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1872_022F7_GF7_01_14715.mzXML',
#  'wget -O GCA_010672305.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1872_022F9_GF9_01_14717.mzXML',
#  'wget -O GCA_010672305.mzXML.8 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1872_022F10_GF10_01_14718.mzXML',
#  'wget -O GCA_010672345.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1889_024A3_GA3_01_14835.mzXML',
#  'wget -O GCA_010692575.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1894_024C4_GC4_01_14864.mzXML',
#  'wget -O GCA_010692585.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/PAL24MAY13_5_C_GB5_01_37737.mzXML',
#  'wget -O GCA_010672205.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1902_024H11_GH11_01_14948.mzXML',
#  'wget -O GCA_010672205.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H2_GH2_01_14937.mzXML',
#  'wget -O GCA_010672205.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H3_GH3_01_14938.mzXML',
#  'wget -O GCA_010672205.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H4_GH4_01_14939.mzXML',
#  'wget -O GCA_010672205.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H5_GH5_01_14940.mzXML',
#  'wget -O GCA_010672205.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H6_GH6_01_14941.mzXML',
#  'wget -O GCA_010672205.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H7_GH7_01_14942.mzXML',
#  'wget -O GCA_010672205.mzXML.8 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H8_GH8_01_14944.mzXML',
#  'wget -O GCA_010672205.mzXML.9 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H9_GH9_01_14945.mzXML',
#  'wget -O GCA_010672205.mzXML.10 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/1901_024H10_GH10_01_14946.mzXML',
#  'wget -O GCA_010692525.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1849_020H9_GH9_01_14532.mzXML',
#  'wget -O GCA_010692535.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2098%20cr_GE6_01_37774.mzXML',
#  'wget -O GCA_010692555.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/DMSO_1752_014B12_GB12_01_13869.mzXML',
#  'wget -O GCA_010692465.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2070%20E_GD11_01_37767.mzXML',
#  'wget -O GCA_010672215.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2079%20cr_GE1_01_37769.mzXML',
#  'wget -O GCA_010692425.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1837_020A11_GA11_01_14445.mzXML',
#  'wget -O GCA_010692425.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A2_GA2_01_14435.mzXML',
#  'wget -O GCA_010692425.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A3_GA3_01_14436.mzXML',
#  'wget -O GCA_010692425.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A4_GA4_01_14437.mzXML',
#  'wget -O GCA_010692425.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A5_GA5_01_14438.mzXML',
#  'wget -O GCA_010692425.mzXML.6 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A6_GA6_01_14439.mzXML',
#  'wget -O GCA_010692425.mzXML.7 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A7_GA7_01_14440.mzXML',
#  'wget -O GCA_010692425.mzXML.8 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A8_GA8_01_14441.mzXML',
#  'wget -O GCA_010692425.mzXML.9 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A9_GA9_01_14442.mzXML',
#  'wget -O GCA_010692425.mzXML.10 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1833_020A10_GA10_01_14443.mzXML',
#  'wget -O GCA_010672195.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1688_010E7_GE7_01_13470.mzXML',
#  'wget -O GCA_010672195.mzXML.2 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1688_010E8_GE8_01_13471.mzXML',
#  'wget -O GCA_010672195.mzXML.3 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1688_010E9_GE9_01_13472.mzXML',
#  'wget -O GCA_010672195.mzXML.4 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1688_010E10_GE10_01_13473.mzXML',
#  'wget -O GCA_010672195.mzXML.5 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/A1688_010E11_GE11_01_13474.mzXML',
#  'wget -O GCA_010692445.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2103%20cr_GE7_01_37775.mzXML',
#  'wget -O GCA_010671975.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/Cobble%20down%20cr_GG6_01_37798.mzXML',
#  'wget -O GCA_010692335.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/numC_11_C_GC2_01_37746.mzXML',
#  'wget -O GCA_010671965.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/C15-B%20cr_GG7_01_37799.mzXML',
#  'wget -O GCA_010692345.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2246%20cr_GG3_01_37795.mzXML',
#  'wget -O GCA_010692305.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/2247%20cr_GG4_01_37796.mzXML',
#  'wget -O GCA_010671925.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/ASI16JUL14_2_C_GA3_01_37723.mzXML',
#  'wget -O GCA_010671905.mzXML.1 ftp://massive.ucsd.edu/MSV000085210/raw/iomega/ISB03NOV94_8_C_GA6_01_37726.mzXML']

# %%
### only run once

# with open('./temp_files/PODP_LCMS_list_commands-round5.txt', "w") as output:
#     writer = csv.writer(output, lineterminator='\n')
#     for val in commands:
#         writer.writerow([val])

# !mkdir ./inputs/cyanos_mzML

# %%
# !ls ./inputs/cyanos_mzML/ | wc -l
# Out:
#      118

# %%
#!rm ./temp_files/PODP_LCMS_list_commands-round5.txt
