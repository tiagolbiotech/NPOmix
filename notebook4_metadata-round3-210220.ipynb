# %% [markdown]
# `Last update at 2021-03-16`
#
# # Background
#
# ## Rounds to test
# ```
# Round 1: 60 MAGs; 39 MS/MS-BGC links (1 correct link)
# Round 2: 279 genomes/MAGs; 1 MS/MS-BGC links (0 correct link)
# Round 3: 279 genomes/MAGs and 589 metagenomes; 16 MS/MS-BGC links (8 correct links)
# ```
#
# ## Outline
#
# ```
#     4) Plotting GCF metadata:
#     4.1) Loading Full BiG-SCAPE Network Annotation;
#     4.2) Replacing names for more useful labels;
#     4.3) Obtaining GCFs;
#     4.4) Calculating BGC count per GCF;
#     4.5) Summing GCFs from same type;
#     4.6) Plotting counts;
#     4.7) Plotting GCF clustermap.
#
# ```

# %%
import pandas as pd
import os
import re
import numpy as np
import networkx
from networkx.algorithms.components.connected import connected_components
from collections import defaultdict
from collections import Counter
import seaborn as sns
import glob
sns.set()

# %% [markdown]
# # 4. Plotting GCF metadata

# %% [markdown]
# ## 4.1. Loading full BiG-SCAPE network annotation

# %%
nodes_df = pd.read_csv('./bigscape_outputs_210124/network_files/2021-01-24_15-45-51_hybrids_glocal/Network_Annotations_Full.tsv',sep='\t')

nodes_df = nodes_df.drop('Organism',axis=1)

nodes_df[:5]
# Out:
#                         BGC     Accesion ID  \
# 0  ABCS01000001.1.region001  ABCS01000001.1
# 1  ABCS01000001.1.region002  ABCS01000001.1
# 2  ABCS01000001.1.region003  ABCS01000001.1
# 3  ABCS01000003.1.region001  ABCS01000003.1
# 4  ABCS01000005.1.region001  ABCS01000005.1
#
#                                          Description Product Prediction  \
# 0  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...            terpene
# 1  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...        siderophore
# 2  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...        bacteriocin
# 3  ABCS01000003.1 Plesiocystis pacifica SIR-1 110...          NRPS-like
# 4  ABCS01000005.1 Plesiocystis pacifica SIR-1 110...        transAT-PKS
#
#   BiG-SCAPE class Taxonomy
# 0         Terpene      NaN
# 1          Others      NaN
# 2           RiPPs      NaN
# 3            NRPS      NaN
# 4        PKSother      NaN

# %%
len(nodes_df)
# Out:
# 6696

# %% [markdown]
# ## 4.2. Replacing names for more useful labels

# %%
def parse_gbk_list(folder_list):
    gbk_list,new_name_list = [],[]
    for antismash_folder in folder_list:
        for root, dirs, files in os.walk(antismash_folder):
            count = 1
            for file in sorted(files):
                if file.endswith(".gbk"):
                    if 'region' in file:
                        if 'BGC' in file:
                            new_name = file.rstrip('.gbk')
                            new_name_list.append(new_name)
                            gbk_list.append(file.rstrip('.gbk'))
                        else:
                            strain_name = os.path.basename(os.path.normpath(root)).split('.')[0]
                            gbk_list.append(file.rstrip('.gbk'))
                            new_name = strain_name + '.region' + "{0:0=3d}".format(count)
                            count += 1
                            new_name_list.append(new_name)
    return gbk_list,new_name_list

folder_list = ["/Volumes/TFL190831/ming_output/antismash/"]

gbk_list,new_name_list = parse_gbk_list(folder_list)

# %%
gbk_list
# Out:
# ['._c00017_NODE_17...region001',
#  '._c00219_NODE_21...region001',
#  '._c00533_NODE_53...region001',
#  'c00017_NODE_17...region001',
#  'c00219_NODE_21...region001',
#  'c00533_NODE_53...region001',
#  '._c00003_NODE_3_...region001',
#  '._c00013_NODE_13...region001',
#  '._c00024_NODE_24...region001',
#  '._c00045_NODE_45...region001',
#  '._c00080_NODE_80...region001',
#  '._c00181_NODE_18...region001',
#  '._c00213_NODE_21...region001',
#  '._c00221_NODE_22...region001',
#  '._c00252_NODE_25...region001',
#  '._c00867_NODE_86...region001',
#  '._c01847_NODE_18...region001',
#  '._c02317_NODE_23...region001',
#  '._c04387_NODE_43...region001',
#  '._c04510_NODE_45...region001',
#  '._c05125_NODE_51...region001',
#  '._c06408_NODE_64...region001',
#  '._c07096_NODE_70...region001',
#  'c00003_NODE_3_...region001',
#  'c00013_NODE_13...region001',
#  'c00024_NODE_24...region001',
#  'c00045_NODE_45...region001',
#  'c00080_NODE_80...region001',
#  'c00181_NODE_18...region001',
#  'c00213_NODE_21...region001',
#  'c00221_NODE_22...region001',
#  'c00252_NODE_25...region001',
#  'c00867_NODE_86...region001',
#  'c01847_NODE_18...region001',
#  'c02317_NODE_23...region001',
#  'c04387_NODE_43...region001',
#  'c04510_NODE_45...region001',
#  'c05125_NODE_51...region001',
#  'c06408_NODE_64...region001',
#  'c07096_NODE_70...region001',
#  '._c00008_NODE_8_...region001',
#  '._c00264_NODE_26...region001',
#  '._c00398_NODE_39...region001',
#  'c00008_NODE_8_...region001',
#  'c00264_NODE_26...region001',
#  'c00398_NODE_39...region001',
#  '._c00002_NODE_2_...region001',
#  '._c00007_NODE_7_...region001',
#  '._c00046_NODE_46...region001',
#  '._c00120_NODE_12...region001',
#  '._c00153_NODE_15...region001',
#  'c00002_NODE_2_...region001',
#  'c00007_NODE_7_...region001',
#  'c00046_NODE_46...region001',
#  'c00120_NODE_12...region001',
#  'c00153_NODE_15...region001',
#  '._c00004_NODE_4_...region001',
#  '._c00051_NODE_51...region001',
#  '._c00056_NODE_56...region001',
#  '._c00087_NODE_87...region001',
#  '._c00340_NODE_34...region001',
#  '._c00631_NODE_63...region001',
#  'c00004_NODE_4_...region001',
#  'c00051_NODE_51...region001',
#  'c00056_NODE_56...region001',
#  'c00087_NODE_87...region001',
#  'c00340_NODE_34...region001',
#  'c00631_NODE_63...region001',
#  '._c00020_NODE_20...region001',
#  '._c00304_NODE_30...region001',
#  '._c02009_NODE_20...region001',
#  'c00020_NODE_20...region001',
#  'c00304_NODE_30...region001',
#  'c02009_NODE_20...region001',
#  '._c00362_NODE_36...region001',
#  '._c00491_NODE_49...region001',
#  '._c00526_NODE_52...region001',
#  '._c01828_NODE_18...region001',
#  'c00362_NODE_36...region001',
#  'c00491_NODE_49...region001',
#  'c00526_NODE_52...region001',
#  'c01828_NODE_18...region001',
#  '._c00026_NODE_26...region001',
#  '._c00045_NODE_45...region001',
#  '._c00047_NODE_47...region001',
#  '._c00091_NODE_91...region001',
#  '._c00104_NODE_10...region001',
#  '._c01307_NODE_13...region001',
#  '._c02743_NODE_27...region001',
#  '._c03834_NODE_38...region001',
#  '._c04295_NODE_42...region001',
#  'c00026_NODE_26...region001',
#  'c00045_NODE_45...region001',
#  'c00047_NODE_47...region001',
#  'c00091_NODE_91...region001',
#  'c00104_NODE_10...region001',
#  'c01307_NODE_13...region001',
#  'c02743_NODE_27...region001',
#  'c03834_NODE_38...region001',
#  'c04295_NODE_42...region001',
#  '._c00004_NODE_4_...region001',
#  '._c00018_NODE_18...region001',
#  '._c00022_NODE_22...region001',
#  '._c00034_NODE_34...region001',
#  '._c00095_NODE_95...region001',
#  '._c00174_NODE_17...region001',
#  'c00004_NODE_4_...region001',
#  'c00018_NODE_18...region001',
#  'c00022_NODE_22...region001',
#  'c00034_NODE_34...region001',
#  'c00095_NODE_95...region001',
#  'c00174_NODE_17...region001',
#  '._c00054_NODE_54...region001',
#  '._c00558_NODE_55...region001',
#  '._c01198_NODE_11...region001',
#  '._c01308_NODE_13...region001',
#  '._c04009_NODE_40...region001',
#  'c00054_NODE_54...region001',
#  'c00558_NODE_55...region001',
#  'c01198_NODE_11...region001',
#  'c01308_NODE_13...region001',
#  'c04009_NODE_40...region001',
#  '._c00005_NODE_5_...region001',
#  '._c00007_NODE_7_...region001',
#  '._c00016_NODE_16...region001',
#  '._c00055_NODE_55...region001',
#  '._c00091_NODE_91...region001',
#  '._c00114_NODE_11...region001',
#  '._c03866_NODE_38...region001',
#  'c00005_NODE_5_...region001',
#  'c00007_NODE_7_...region001',
#  'c00016_NODE_16...region001',
#  'c00055_NODE_55...region001',
#  'c00091_NODE_91...region001',
#  'c00114_NODE_11...region001',
#  'c03866_NODE_38...region001',
#  '._c00004_NODE_4_...region001',
#  '._c00053_NODE_53...region001',
#  '._c00154_NODE_15...region001',
#  'c00004_NODE_4_...region001',
#  'c00053_NODE_53...region001',
#  'c00154_NODE_15...region001',
#  '._c00044_NODE_44...region001',
#  '._c00050_NODE_50...region001',
#  '._c00066_NODE_66...region001',
#  '._c00151_NODE_15...region001',
#  '._c00508_NODE_50...region001',
#  '._c00562_NODE_56...region001',
#  '._c01300_NODE_13...region001',
#  '._c01389_NODE_13...region001',
#  '._c01766_NODE_17...region001',
#  '._c01990_NODE_19...region001',
#  '._c02553_NODE_25...region001',
#  '._c02578_NODE_25...region001',
#  '._c02853_NODE_28...region001',
#  '._c06456_NODE_64...region001',
#  '._c07328_NODE_73...region001',
#  'c00044_NODE_44...region001',
#  'c00050_NODE_50...region001',
#  'c00066_NODE_66...region001',
#  'c00151_NODE_15...region001',
#  'c00508_NODE_50...region001',
#  'c00562_NODE_56...region001',
#  'c01300_NODE_13...region001',
#  'c01389_NODE_13...region001',
#  'c01766_NODE_17...region001',
#  'c01990_NODE_19...region001',
#  'c02553_NODE_25...region001',
#  'c02578_NODE_25...region001',
#  'c02853_NODE_28...region001',
#  'c06456_NODE_64...region001',
#  'c07328_NODE_73...region001',
#  '._c00078_NODE_78...region001',
#  '._c00288_NODE_28...region001',
#  '._c00411_NODE_41...region001',
#  '._c00724_NODE_72...region001',
#  '._c01298_NODE_12...region001',
#  '._c01923_NODE_19...region001',
#  '._c05189_NODE_51...region001',
#  '._c05422_NODE_54...region001',
#  '._c05803_NODE_58...region001',
#  'c00078_NODE_78...region001',
#  'c00288_NODE_28...region001',
#  'c00411_NODE_41...region001',
#  'c00724_NODE_72...region001',
#  'c01298_NODE_12...region001',
#  'c01923_NODE_19...region001',
#  'c05189_NODE_51...region001',
#  'c05422_NODE_54...region001',
#  'c05803_NODE_58...region001',
#  '._c00003_NODE_3_...region001',
#  '._c00006_NODE_6_...region001',
#  '._c00232_NODE_23...region001',
#  '._c00290_NODE_29...region001',
#  'c00003_NODE_3_...region001',
#  'c00006_NODE_6_...region001',
#  'c00232_NODE_23...region001',
#  'c00290_NODE_29...region001',
#  '._c00002_NODE_2_...region001',
#  '._c00010_NODE_10...region001',
#  '._c00051_NODE_51...region001',
#  '._c02293_NODE_22...region001',
#  '._c02917_NODE_29...region001',
#  'c00002_NODE_2_...region001',
#  'c00010_NODE_10...region001',
#  'c00051_NODE_51...region001',
#  'c02293_NODE_22...region001',
#  'c02917_NODE_29...region001',
#  '._c00025_NODE_25...region001',
#  '._c00175_NODE_17...region001',
#  '._c00281_NODE_28...region001',
#  'c00025_NODE_25...region001',
#  'c00175_NODE_17...region001',
#  'c00281_NODE_28...region001',
#  '._c00030_NODE_30...region001',
#  '._c00048_NODE_48...region001',
#  '._c02817_NODE_28...region001',
#  'c00030_NODE_30...region001',
#  'c00048_NODE_48...region001',
#  'c02817_NODE_28...region001',
#  '._c00080_NODE_80...region001',
#  '._c00182_NODE_18...region001',
#  '._c00235_NODE_23...region001',
#  '._c00277_NODE_27...region001',
#  '._c00352_NODE_35...region001',
#  '._c00458_NODE_45...region001',
#  '._c00587_NODE_58...region001',
#  '._c00808_NODE_80...region001',
#  '._c01914_NODE_19...region001',
#  'c00080_NODE_80...region001',
#  'c00182_NODE_18...region001',
#  'c00235_NODE_23...region001',
#  'c00277_NODE_27...region001',
#  'c00352_NODE_35...region001',
#  'c00458_NODE_45...region001',
#  'c00587_NODE_58...region001',
#  'c00808_NODE_80...region001',
#  'c01914_NODE_19...region001',
#  '._c00012_NODE_12...region001',
#  '._c00018_NODE_18...region001',
#  '._c00071_NODE_71...region001',
#  '._c00192_NODE_19...region001',
#  '._c00228_NODE_22...region001',
#  '._c00943_NODE_94...region001',
#  '._c01931_NODE_19...region001',
#  '._c02255_NODE_22...region001',
#  'c00012_NODE_12...region001',
#  'c00018_NODE_18...region001',
#  'c00071_NODE_71...region001',
#  'c00192_NODE_19...region001',
#  'c00228_NODE_22...region001',
#  'c00943_NODE_94...region001',
#  'c01931_NODE_19...region001',
#  'c02255_NODE_22...region001',
#  '._c00097_NODE_97...region001',
#  '._c00142_NODE_14...region001',
#  '._c00191_NODE_19...region001',
#  '._c00243_NODE_24...region001',
#  '._c00829_NODE_82...region001',
#  '._c01768_NODE_17...region001',
#  'c00097_NODE_97...region001',
#  'c00142_NODE_14...region001',
#  'c00191_NODE_19...region001',
#  'c00243_NODE_24...region001',
#  'c00829_NODE_82...region001',
#  'c01768_NODE_17...region001',
#  '._c00027_NODE_27...region001',
#  '._c00195_NODE_19...region001',
#  '._c00791_NODE_79...region001',
#  '._c00930_NODE_93...region001',
#  '._c01563_NODE_15...region001',
#  '._c01741_NODE_17...region001',
#  '._c02491_NODE_24...region001',
#  '._c02828_NODE_28...region001',
#  'c00027_NODE_27...region001',
#  'c00195_NODE_19...region001',
#  'c00791_NODE_79...region001',
#  'c00930_NODE_93...region001',
#  'c01563_NODE_15...region001',
#  'c01741_NODE_17...region001',
#  'c02491_NODE_24...region001',
#  'c02828_NODE_28...region001',
#  '._c00007_NODE_7_...region001',
#  '._c00012_NODE_12...region001',
#  '._c00045_NODE_45...region001',
#  '._c00183_NODE_18...region001',
#  '._c00281_NODE_28...region001',
#  '._c00369_NODE_36...region001',
#  '._c00423_NODE_42...region001',
#  '._c00457_NODE_45...region001',
#  '._c00685_NODE_68...region001',
#  '._c00688_NODE_68...region001',
#  '._c01972_NODE_19...region001',
#  '._c02155_NODE_21...region001',
#  'c00007_NODE_7_...region001',
#  'c00012_NODE_12...region001',
#  'c00045_NODE_45...region001',
#  'c00183_NODE_18...region001',
#  'c00281_NODE_28...region001',
#  'c00369_NODE_36...region001',
#  'c00423_NODE_42...region001',
#  'c00457_NODE_45...region001',
#  'c00685_NODE_68...region001',
#  'c00688_NODE_68...region001',
#  'c01972_NODE_19...region001',
#  'c02155_NODE_21...region001',
#  '._c00002_NODE_2_...region001',
#  '._c00053_NODE_53...region001',
#  '._c00295_NODE_29...region001',
#  '._c00964_NODE_96...region001',
#  'c00002_NODE_2_...region001',
#  'c00053_NODE_53...region001',
#  'c00295_NODE_29...region001',
#  'c00964_NODE_96...region001',
#  '._c00039_NODE_39...region001',
#  '._c00043_NODE_43...region001',
#  '._c00101_NODE_10...region001',
#  '._c00272_NODE_27...region001',
#  '._c00279_NODE_27...region001',
#  '._c01544_NODE_15...region001',
#  '._c01555_NODE_15...region001',
#  '._c01823_NODE_18...region001',
#  '._c04291_NODE_42...region001',
#  'c00039_NODE_39...region001',
#  'c00043_NODE_43...region001',
#  'c00101_NODE_10...region001',
#  'c00272_NODE_27...region001',
#  'c00279_NODE_27...region001',
#  'c01544_NODE_15...region001',
#  'c01555_NODE_15...region001',
#  'c01823_NODE_18...region001',
#  'c04291_NODE_42...region001',
#  '._c00098_NODE_98...region001',
#  '._c00314_NODE_31...region001',
#  '._c00578_NODE_57...region001',
#  '._c00939_NODE_93...region001',
#  '._c01322_NODE_13...region001',
#  '._c01350_NODE_13...region001',
#  '._c02919_NODE_29...region001',
#  'c00098_NODE_98...region001',
#  'c00314_NODE_31...region001',
#  'c00578_NODE_57...region001',
#  'c00939_NODE_93...region001',
#  'c01322_NODE_13...region001',
#  'c01350_NODE_13...region001',
#  'c02919_NODE_29...region001',
#  '._c00058_NODE_58...region001',
#  '._c00113_NODE_11...region001',
#  '._c00130_NODE_13...region001',
#  '._c00163_NODE_16...region001',
#  '._c00479_NODE_47...region001',
#  '._c00790_NODE_79...region001',
#  '._c01217_NODE_12...region001',
#  'c00058_NODE_58...region001',
#  'c00113_NODE_11...region001',
#  'c00130_NODE_13...region001',
#  'c00163_NODE_16...region001',
#  'c00479_NODE_47...region001',
#  'c00790_NODE_79...region001',
#  'c01217_NODE_12...region001',
#  '._c00050_NODE_50...region001',
#  '._c00100_NODE_10...region001',
#  '._c00198_NODE_19...region001',
#  '._c01110_NODE_11...region001',
#  '._c01435_NODE_14...region001',
#  'c00050_NODE_50...region001',
#  'c00100_NODE_10...region001',
#  'c00198_NODE_19...region001',
#  'c01110_NODE_11...region001',
#  'c01435_NODE_14...region001',
#  '._c00026_NODE_26...region001',
#  '._c00179_NODE_17...region001',
#  '._c00438_NODE_43...region001',
#  'c00026_NODE_26...region001',
#  'c00179_NODE_17...region001',
#  'c00438_NODE_43...region001',
#  '._c00022_NODE_22...region001',
#  '._c00113_NODE_11...region001',
#  '._c00205_NODE_20...region001',
#  '._c00301_NODE_30...region001',
#  '._c00601_NODE_60...region001',
#  '._c00847_NODE_84...region001',
#  '._c00890_NODE_89...region001',
#  '._c01619_NODE_16...region001',
#  '._c02955_NODE_29...region001',
#  '._c04437_NODE_44...region001',
#  '._c05475_NODE_54...region001',
#  '._c05966_NODE_59...region001',
#  'c00022_NODE_22...region001',
#  'c00113_NODE_11...region001',
#  'c00205_NODE_20...region001',
#  'c00301_NODE_30...region001',
#  'c00601_NODE_60...region001',
#  'c00847_NODE_84...region001',
#  'c00890_NODE_89...region001',
#  'c01619_NODE_16...region001',
#  'c02955_NODE_29...region001',
#  'c04437_NODE_44...region001',
#  'c05475_NODE_54...region001',
#  'c05966_NODE_59...region001',
#  '._c00002_NODE_2_...region001',
#  '._c00107_NODE_10...region001',
#  '._c00444_NODE_44...region001',
#  '._c00762_NODE_76...region001',
#  '._c01137_NODE_11...region001',
#  '._c01793_NODE_17...region001',
#  '._c02624_NODE_26...region001',
#  '._c03553_NODE_35...region001',
#  '._c03630_NODE_36...region001',
#  '._c05531_NODE_55...region001',
#  'c00002_NODE_2_...region001',
#  'c00107_NODE_10...region001',
#  'c00444_NODE_44...region001',
#  'c00762_NODE_76...region001',
#  'c01137_NODE_11...region001',
#  'c01793_NODE_17...region001',
#  'c02624_NODE_26...region001',
#  'c03553_NODE_35...region001',
#  'c03630_NODE_36...region001',
#  'c05531_NODE_55...region001',
#  '._c00009_NODE_9_...region001',
#  '._c00022_NODE_22...region001',
#  '._c00175_NODE_17...region001',
#  '._c00184_NODE_18...region001',
#  '._c00216_NODE_21...region001',
#  '._c00257_NODE_25...region001',
#  '._c00354_NODE_35...region001',
#  '._c00487_NODE_48...region001',
#  '._c00796_NODE_79...region001',
#  '._c01598_NODE_15...region001',
#  'c00009_NODE_9_...region001',
#  'c00022_NODE_22...region001',
#  'c00175_NODE_17...region001',
#  'c00184_NODE_18...region001',
#  'c00216_NODE_21...region001',
#  'c00257_NODE_25...region001',
#  'c00354_NODE_35...region001',
#  'c00487_NODE_48...region001',
#  'c00796_NODE_79...region001',
#  'c01598_NODE_15...region001',
#  '._c00014_NODE_14...region001',
#  '._c00026_NODE_26...region001',
#  '._c00076_NODE_76...region001',
#  '._c00225_NODE_22...region001',
#  '._c00234_NODE_23...region001',
#  '._c00536_NODE_53...region001',
#  '._c00606_NODE_60...region001',
#  'c00014_NODE_14...region001',
#  'c00026_NODE_26...region001',
#  'c00076_NODE_76...region001',
#  'c00225_NODE_22...region001',
#  'c00234_NODE_23...region001',
#  'c00536_NODE_53...region001',
#  'c00606_NODE_60...region001',
#  '._c00002_NODE_2_...region001',
#  '._c00181_NODE_18...region001',
#  '._c00221_NODE_22...region001',
#  '._c00272_NODE_27...region001',
#  '._c00905_NODE_90...region001',
#  '._c01659_NODE_16...region001',
#  'c00002_NODE_2_...region001',
#  'c00181_NODE_18...region001',
#  'c00221_NODE_22...region001',
#  'c00272_NODE_27...region001',
#  'c00905_NODE_90...region001',
#  'c01659_NODE_16...region001',
#  '._c00083_NODE_83...region001',
#  '._c00175_NODE_17...region001',
#  '._c00182_NODE_18...region001',
#  '._c00306_NODE_30...region001',
#  '._c00652_NODE_65...region001',
#  '._c00772_NODE_77...region001',
#  '._c00809_NODE_80...region001',
#  '._c01105_NODE_11...region001',
#  '._c03510_NODE_35...region001',
#  '._c04359_NODE_43...region001',
#  'c00083_NODE_83...region001',
#  'c00175_NODE_17...region001',
#  'c00182_NODE_18...region001',
#  'c00306_NODE_30...region001',
#  'c00652_NODE_65...region001',
#  'c00772_NODE_77...region001',
#  'c00809_NODE_80...region001',
#  'c01105_NODE_11...region001',
#  'c03510_NODE_35...region001',
#  'c04359_NODE_43...region001',
#  '._c00039_NODE_39...region001',
#  '._c00079_NODE_79...region001',
#  '._c00090_NODE_90...region001',
#  '._c00215_NODE_21...region001',
#  '._c00256_NODE_25...region001',
#  '._c00356_NODE_35...region001',
#  '._c00374_NODE_37...region001',
#  '._c01624_NODE_16...region001',
#  '._c01941_NODE_19...region001',
#  '._c02321_NODE_23...region001',
#  'c00039_NODE_39...region001',
#  'c00079_NODE_79...region001',
#  'c00090_NODE_90...region001',
#  'c00215_NODE_21...region001',
#  'c00256_NODE_25...region001',
#  'c00356_NODE_35...region001',
#  'c00374_NODE_37...region001',
#  'c01624_NODE_16...region001',
#  'c01941_NODE_19...region001',
#  'c02321_NODE_23...region001',
#  '._c00057_NODE_57...region001',
#  '._c00080_NODE_80...region001',
#  '._c00094_NODE_94...region001',
#  '._c00104_NODE_10...region001',
#  '._c00264_NODE_26...region001',
#  '._c00752_NODE_75...region001',
#  '._c00829_NODE_82...region001',
#  '._c00945_NODE_94...region001',
#  '._c01092_NODE_10...region001',
#  '._c02509_NODE_25...region001',
#  '._c02621_NODE_26...region001',
#  '._c05093_NODE_50...region001',
#  '._c07557_NODE_75...region001',
#  '._c09491_NODE_94...region001',
#  '._c12283_NODE_12...region001',
#  '._c12354_NODE_12...region001',
#  'c00057_NODE_57...region001',
#  'c00080_NODE_80...region001',
#  'c00094_NODE_94...region001',
#  'c00104_NODE_10...region001',
#  'c00264_NODE_26...region001',
#  'c00752_NODE_75...region001',
#  'c00829_NODE_82...region001',
#  'c00945_NODE_94...region001',
#  'c01092_NODE_10...region001',
#  'c02509_NODE_25...region001',
#  'c02621_NODE_26...region001',
#  'c05093_NODE_50...region001',
#  'c07557_NODE_75...region001',
#  'c09491_NODE_94...region001',
#  'c12283_NODE_12...region001',
#  'c12354_NODE_12...region001',
#  '._c00009_NODE_9_...region001',
#  '._c00062_NODE_62...region001',
#  '._c00075_NODE_75...region001',
#  '._c00546_NODE_54...region001',
#  '._c00711_NODE_71...region001',
#  '._c00778_NODE_77...region001',
#  '._c01232_NODE_12...region001',
#  '._c01386_NODE_13...region001',
#  '._c04161_NODE_41...region001',
#  'c00009_NODE_9_...region001',
#  'c00062_NODE_62...region001',
#  'c00075_NODE_75...region001',
#  'c00546_NODE_54...region001',
#  'c00711_NODE_71...region001',
#  'c00778_NODE_77...region001',
#  'c01232_NODE_12...region001',
#  'c01386_NODE_13...region001',
#  'c04161_NODE_41...region001',
#  '._c00009_NODE_9_...region001',
#  '._c00022_NODE_22...region001',
#  '._c00023_NODE_23...region001',
#  '._c00025_NODE_25...region001',
#  '._c00067_NODE_67...region001',
#  '._c00070_NODE_70...region001',
#  '._c00078_NODE_78...region001',
#  '._c00154_NODE_15...region001',
#  '._c00256_NODE_25...region001',
#  '._c00301_NODE_30...region001',
#  'c00009_NODE_9_...region001',
#  'c00022_NODE_22...region001',
#  'c00023_NODE_23...region001',
#  'c00025_NODE_25...region001',
#  'c00067_NODE_67...region001',
#  'c00070_NODE_70...region001',
#  'c00078_NODE_78...region001',
#  'c00154_NODE_15...region001',
#  'c00256_NODE_25...region001',
#  'c00301_NODE_30...region001',
#  '._c00006_NODE_6_...region001',
#  '._c00015_NODE_15...region001',
#  '._c00032_NODE_32...region001',
#  '._c00098_NODE_98...region001',
#  '._c00238_NODE_23...region001',
#  '._c00814_NODE_81...region001',
#  '._c00893_NODE_89...region001',
#  'c00006_NODE_6_...region001',
#  'c00015_NODE_15...region001',
#  'c00032_NODE_32...region001',
#  'c00098_NODE_98...region001',
#  'c00238_NODE_23...region001',
#  'c00814_NODE_81...region001',
#  'c00893_NODE_89...region001',
#  '._c00112_NODE_11...region001',
#  '._c00893_NODE_89...region001',
#  '._c01003_NODE_10...region001',
#  '._c05101_NODE_51...region001',
#  '._c05241_NODE_52...region001',
#  '._c06320_NODE_63...region001',
#  'c00112_NODE_11...region001',
#  'c00893_NODE_89...region001',
#  'c01003_NODE_10...region001',
#  'c05101_NODE_51...region001',
#  'c05241_NODE_52...region001',
#  'c06320_NODE_63...region001',
#  '._c00007_NODE_7_...region001',
#  '._c00017_NODE_17...region001',
#  '._c00056_NODE_56...region001',
#  '._c00130_NODE_13...region001',
#  '._c00170_NODE_17...region001',
#  '._c00664_NODE_66...region001',
#  '._c00947_NODE_94...region001',
#  'c00007_NODE_7_...region001',
#  'c00017_NODE_17...region001',
#  'c00056_NODE_56...region001',
#  'c00130_NODE_13...region001',
#  'c00170_NODE_17...region001',
#  'c00664_NODE_66...region001',
#  'c00947_NODE_94...region001',
#  '._c00037_NODE_37...region001',
#  '._c00046_NODE_46...region001',
#  '._c00097_NODE_97...region001',
#  '._c00107_NODE_10...region001',
#  '._c00115_NODE_11...region001',
#  '._c00459_NODE_45...region001',
#  '._c00777_NODE_77...region001',
#  '._c01719_NODE_17...region001',
#  '._c02157_NODE_21...region001',
#  '._c02850_NODE_28...region001',
#  '._c02966_NODE_29...region001',
#  '._c03694_NODE_36...region001',
#  '._c08475_NODE_84...region001',
#  'c00037_NODE_37...region001',
#  'c00046_NODE_46...region001',
#  'c00097_NODE_97...region001',
#  'c00107_NODE_10...region001',
#  'c00115_NODE_11...region001',
#  'c00459_NODE_45...region001',
#  'c00777_NODE_77...region001',
#  'c01719_NODE_17...region001',
#  'c02157_NODE_21...region001',
#  'c02850_NODE_28...region001',
#  'c02966_NODE_29...region001',
#  'c03694_NODE_36...region001',
#  'c08475_NODE_84...region001',
#  '._c00140_NODE_14...region001',
#  '._c00733_NODE_73...region001',
#  '._c01819_NODE_18...region001',
#  '._c02251_NODE_22...region001',
#  '._c02649_NODE_26...region001',
#  '._c02991_NODE_29...region001',
#  '._c03062_NODE_30...region001',
#  '._c03263_NODE_32...region001',
#  'c00140_NODE_14...region001',
#  'c00733_NODE_73...region001',
#  'c01819_NODE_18...region001',
#  'c02251_NODE_22...region001',
#  'c02649_NODE_26...region001',
#  'c02991_NODE_29...region001',
#  'c03062_NODE_30...region001',
#  'c03263_NODE_32...region001',
#  '._c00011_NODE_11...region001',
#  '._c00226_NODE_22...region001',
#  '._c00416_NODE_41...region001',
#  '._c01935_NODE_19...region001',
#  '._c02259_NODE_22...region001',
#  '._c02894_NODE_28...region001',
#  'c00011_NODE_11...region001',
#  'c00226_NODE_22...region001',
#  'c00416_NODE_41...region001',
#  'c01935_NODE_19...region001',
#  'c02259_NODE_22...region001',
#  'c02894_NODE_28...region001',
#  '._c00001_NODE_1_...region001',
#  '._c00005_NODE_5_...region001',
#  '._c00022_NODE_22...region001',
#  '._c00247_NODE_24...region001',
#  '._c00458_NODE_45...region001',
#  'c00001_NODE_1_...region001',
#  'c00005_NODE_5_...region001',
#  'c00022_NODE_22...region001',
#  'c00247_NODE_24...region001',
#  'c00458_NODE_45...region001',
#  '._c00030_NODE_30...region001',
#  '._c00060_NODE_60...region001',
#  '._c00082_NODE_82...region001',
#  '._c00088_NODE_88...region001',
#  '._c00099_NODE_99...region001',
#  '._c00107_NODE_10...region001',
#  '._c00149_NODE_14...region001',
#  '._c00772_NODE_77...region001',
#  '._c01043_NODE_10...region001',
#  '._c01053_NODE_10...region001',
#  'c00030_NODE_30...region001',
#  'c00060_NODE_60...region001',
#  'c00082_NODE_82...region001',
#  'c00088_NODE_88...region001',
#  'c00099_NODE_99...region001',
#  'c00107_NODE_10...region001',
#  'c00149_NODE_14...region001',
#  'c00772_NODE_77...region001',
#  'c01043_NODE_10...region001',
#  'c01053_NODE_10...region001',
#  '._c00014_NODE_14...region001',
#  '._c00022_NODE_22...region001',
#  '._c00109_NODE_10...region001',
#  '._c00443_NODE_44...region001',
#  '._c04747_NODE_47...region001',
#  'c00014_NODE_14...region001',
#  'c00022_NODE_22...region001',
#  'c00109_NODE_10...region001',
#  'c00443_NODE_44...region001',
#  'c04747_NODE_47...region001',
#  '._c00003_NODE_3_...region001',
#  '._c00085_NODE_85...region001',
#  '._c00134_NODE_13...region001',
#  'c00003_NODE_3_...region001',
#  'c00085_NODE_85...region001',
#  'c00134_NODE_13...region001',
#  '._c00048_NODE_48...region001',
#  '._c00181_NODE_18...region001',
#  '._c00257_NODE_25...region001',
#  '._c00296_NODE_29...region001',
#  '._c00565_NODE_56...region001',
#  'c00048_NODE_48...region001',
#  'c00181_NODE_18...region001',
#  'c00257_NODE_25...region001',
#  'c00296_NODE_29...region001',
#  'c00565_NODE_56...region001',
#  '._c00011_NODE_11...region001',
#  '._c00082_NODE_82...region001',
#  '._c00388_NODE_38...region001',
#  '._c00968_NODE_96...region001',
#  'c00011_NODE_11...region001',
#  'c00082_NODE_82...region001',
#  'c00388_NODE_38...region001',
#  'c00968_NODE_96...region001',
#  '._c00003_NODE_3_...region001',
#  '._c00024_NODE_24...region001',
#  '._c00026_NODE_26...region001',
#  '._c00031_NODE_31...region001',
#  '._c00042_NODE_42...region001',
#  '._c00051_NODE_51...region001',
#  '._c00054_NODE_54...region001',
#  '._c00058_NODE_58...region001',
#  '._c00164_NODE_16...region001',
#  '._c00168_NODE_16...region001',
#  '._c00263_NODE_26...region001',
#  '._c00308_NODE_30...region001',
#  '._c01341_NODE_13...region001',
#  'c00003_NODE_3_...region001',
#  'c00024_NODE_24...region001',
#  'c00026_NODE_26...region001',
#  'c00031_NODE_31...region001',
#  'c00042_NODE_42...region001',
#  'c00051_NODE_51...region001',
#  'c00054_NODE_54...region001',
#  'c00058_NODE_58...region001',
#  'c00164_NODE_16...region001',
#  'c00168_NODE_16...region001',
#  'c00263_NODE_26...region001',
#  'c00308_NODE_30...region001',
#  'c01341_NODE_13...region001',
#  '._c00006_NODE_6_...region001',
#  '._c00041_NODE_41...region001',
#  '._c00042_NODE_42...region001',
#  '._c00044_NODE_44...region001',
#  '._c00067_NODE_67...region001',
#  '._c00099_NODE_99...region001',
#  '._c00235_NODE_23...region001',
#  '._c00394_NODE_39...region001',
#  '._c00783_NODE_78...region001',
#  '._c00925_NODE_92...region001',
#  '._c00993_NODE_99...region001',
#  '._c01549_NODE_15...region001',
#  'c00006_NODE_6_...region001',
#  'c00041_NODE_41...region001',
#  'c00042_NODE_42...region001',
#  'c00044_NODE_44...region001',
#  'c00067_NODE_67...region001',
#  'c00099_NODE_99...region001',
#  'c00235_NODE_23...region001',
#  'c00394_NODE_39...region001',
#  'c00783_NODE_78...region001',
#  'c00925_NODE_92...region001',
#  'c00993_NODE_99...region001',
#  'c01549_NODE_15...region001',
#  '._c00005_NODE_5_...region001',
#  '._c00022_NODE_22...region001',
#  '._c00082_NODE_82...region001',
#  '._c00298_NODE_29...region001',
#  '._c00550_NODE_55...region001',
#  '._c00590_NODE_59...region001',
#  '._c01952_NODE_19...region001',
#  '._c02030_NODE_20...region001',
#  '._c02199_NODE_21...region001',
#  '._c02343_NODE_23...region001',
#  '._c02530_NODE_25...region001',
#  '._c06231_NODE_62...region001',
#  '._c06321_NODE_63...region001',
#  '._c06819_NODE_68...region001',
#  'c00005_NODE_5_...region001',
#  'c00022_NODE_22...region001',
#  'c00082_NODE_82...region001',
#  'c00298_NODE_29...region001',
#  'c00550_NODE_55...region001',
#  'c00590_NODE_59...region001',
#  'c01952_NODE_19...region001',
#  'c02030_NODE_20...region001',
#  'c02199_NODE_21...region001',
#  'c02343_NODE_23...region001',
#  'c02530_NODE_25...region001',
#  'c06231_NODE_62...region001',
#  'c06321_NODE_63...region001',
#  'c06819_NODE_68...region001',
#  '._c00004_NODE_4_...region001',
#  '._c00058_NODE_58...region001',
#  '._c00304_NODE_30...region001',
#  '._c01145_NODE_11...region001',
#  '._c01501_NODE_15...region001',
#  'c00004_NODE_4_...region001',
#  'c00058_NODE_58...region001',
#  'c00304_NODE_30...region001',
#  'c01145_NODE_11...region001',
#  'c01501_NODE_15...region001',
#  '._c00002_NODE_2_...region001',
#  '._c00006_NODE_6_...region001',
#  '._c00025_NODE_25...region001',
#  '._c00281_NODE_28...region001',
#  '._c00604_NODE_60...region001',
#  '._c03423_NODE_34...region001',
#  '._c03666_NODE_36...region001',
#  '._c06021_NODE_60...region001',
#  '._c06023_NODE_60...region001',
#  '._c06222_NODE_62...region001',
#  '._c06690_NODE_66...region001',
#  '._c07426_NODE_74...region001',
#  'c00002_NODE_2_...region001',
#  'c00006_NODE_6_...region001',
#  'c00025_NODE_25...region001',
#  'c00281_NODE_28...region001',
#  'c00604_NODE_60...region001',
#  'c03423_NODE_34...region001',
#  'c03666_NODE_36...region001',
#  'c06021_NODE_60...region001',
#  'c06023_NODE_60...region001',
#  'c06222_NODE_62...region001',
#  'c06690_NODE_66...region001',
#  'c07426_NODE_74...region001',
#  '._c00007_NODE_7_...region001',
#  '._c00200_NODE_20...region001',
#  '._c01877_NODE_18...region001',
#  '._c06808_NODE_68...region001',
#  'c00007_NODE_7_...region001',
#  'c00200_NODE_20...region001',
#  'c01877_NODE_18...region001',
#  'c06808_NODE_68...region001',
#  '._c00004_NODE_4_...region001',
#  '._c00007_NODE_7_...region001',
#  '._c00008_NODE_8_...region001',
#  '._c00438_NODE_43...region001',
#  '._c00511_NODE_51...region001',
#  '._c00632_NODE_63...region001',
#  '._c00757_NODE_75...region001',
#  '._c01071_NODE_10...region001',
#  '._c01333_NODE_13...region001',
#  '._c01567_NODE_15...region001',
#  'c00004_NODE_4_...region001',
#  'c00007_NODE_7_...region001',
#  'c00008_NODE_8_...region001',
#  'c00438_NODE_43...region001',
#  'c00511_NODE_51...region001',
#  'c00632_NODE_63...region001',
#  'c00757_NODE_75...region001',
#  'c01071_NODE_10...region001',
#  'c01333_NODE_13...region001',
#  'c01567_NODE_15...region001',
#  '._c00003_NODE_3_...region001',
#  '._c00010_NODE_10...region001',
#  '._c00025_NODE_25...region001',
#  '._c00054_NODE_54...region001',
#  '._c00140_NODE_14...region001',
#  '._c00286_NODE_28...region001',
#  '._c00412_NODE_41...region001',
#  '._c00474_NODE_47...region001',
#  '._c00484_NODE_48...region001',
#  'c00003_NODE_3_...region001',
#  'c00010_NODE_10...region001',
#  'c00025_NODE_25...region001',
#  'c00054_NODE_54...region001',
#  'c00140_NODE_14...region001',
#  'c00286_NODE_28...region001',
#  'c00412_NODE_41...region001',
#  'c00474_NODE_47...region001',
#  'c00484_NODE_48...region001',
#  '._c00128_NODE_12...region001',
#  '._c02168_NODE_21...region001',
#  '._c03917_NODE_39...region001',
#  'c00128_NODE_12...region001',
#  'c02168_NODE_21...region001',
#  'c03917_NODE_39...region001',
#  '._c00007_NODE_7_...region001',
#  '._c00025_NODE_25...region001',
#  '._c00043_NODE_43...region001',
#  '._c00069_NODE_69...region001',
#  '._c00100_NODE_10...region001',
#  '._c00134_NODE_13...region001',
#  '._c00384_NODE_38...region001',
#  '._c00859_NODE_85...region001',
#  '._c01919_NODE_19...region001',
#  '._c03706_NODE_37...region001',
#  '._c04016_NODE_40...region001',
#  '._c04655_NODE_46...region001',
#  'c00007_NODE_7_...region001',
#  'c00025_NODE_25...region001',
#  'c00043_NODE_43...region001',
#  'c00069_NODE_69...region001',
#  'c00100_NODE_10...region001',
#  'c00134_NODE_13...region001',
#  'c00384_NODE_38...region001',
#  'c00859_NODE_85...region001',
#  'c01919_NODE_19...region001',
#  'c03706_NODE_37...region001',
#  'c04016_NODE_40...region001',
#  'c04655_NODE_46...region001',
#  '._c00041_NODE_41...region001',
#  '._c00127_NODE_12...region001',
#  '._c00129_NODE_12...region001',
#  '._c00157_NODE_15...region001',
#  '._c00294_NODE_29...region001',
#  '._c00489_NODE_48...region001',
#  '._c02244_NODE_22...region001',
#  'c00041_NODE_41...region001',
#  'c00127_NODE_12...region001',
#  'c00129_NODE_12...region001',
#  'c00157_NODE_15...region001',
#  'c00294_NODE_29...region001',
#  'c00489_NODE_48...region001',
#  'c02244_NODE_22...region001',
#  '._c00060_NODE_60...region001',
#  '._c00109_NODE_10...region001',
#  '._c00180_NODE_18...region001',
#  '._c00318_NODE_31...region001',
#  '._c00465_NODE_46...region001',
#  '._c02089_NODE_20...region001',
#  '._c02684_NODE_26...region001',
#  '._c03090_NODE_30...region001',
#  '._c04324_NODE_43...region001',
#  'c00060_NODE_60...region001',
#  'c00109_NODE_10...region001',
#  'c00180_NODE_18...region001',
#  'c00318_NODE_31...region001',
#  'c00465_NODE_46...region001',
#  'c02089_NODE_20...region001',
#  'c02684_NODE_26...region001',
#  'c03090_NODE_30...region001',
#  'c04324_NODE_43...region001',
#  '._c00049_NODE_49...region001',
#  '._c00074_NODE_74...region001',
#  '._c00313_NODE_31...region001',
#  '._c00356_NODE_35...region001',
#  '._c00982_NODE_98...region001',
#  '._c01057_NODE_10...region001',
#  '._c02535_NODE_25...region001',
#  '._c02990_NODE_29...region001',
#  'c00049_NODE_49...region001',
#  'c00074_NODE_74...region001',
#  'c00313_NODE_31...region001',
#  'c00356_NODE_35...region001',
#  'c00982_NODE_98...region001',
#  'c01057_NODE_10...region001',
#  'c02535_NODE_25...region001',
#  'c02990_NODE_29...region001',
#  '._c00002_NODE_2_...region001',
#  '._c00019_NODE_19...region001',
#  '._c00113_NODE_11...region001',
#  '._c00709_NODE_70...region001',
#  '._c00726_NODE_72...region001',
#  '._c01053_NODE_10...region001',
#  '._c04596_NODE_45...region001',
#  'c00002_NODE_2_...region001',
#  'c00019_NODE_19...region001',
#  'c00113_NODE_11...region001',
#  'c00709_NODE_70...region001',
#  'c00726_NODE_72...region001',
#  'c01053_NODE_10...region001',
#  'c04596_NODE_45...region001',
#  '._c00001_NODE_1_...region001',
#  '._c00215_NODE_21...region001',
#  'c00001_NODE_1_...region001',
#  'c00215_NODE_21...region001',
#  '._c00033_NODE_33...region001',
#  '._c00045_NODE_45...region001',
#  '._c00125_NODE_12...region001',
#  '._c00333_NODE_33...region001',
#  '._c00371_NODE_37...region001',
#  '._c00573_NODE_57...region001',
#  '._c00650_NODE_65...region001',
#  '._c01154_NODE_11...region001',
#  '._c01248_NODE_12...region001',
#  '._c01368_NODE_13...region001',
#  '._c01470_NODE_14...region001',
#  '._c01691_NODE_16...region001',
#  ...]

# %%
name_dict = dict(zip(gbk_list, new_name_list))
new_col1 = []

for i,r in nodes_df.iterrows():
    if 'BGC' not in nodes_df['BGC'].loc[i]:
        new_col1.append(name_dict[nodes_df['BGC'].loc[i]])
    else:
        new_col1.append(nodes_df['BGC'].loc[i])
    
nodes_df['BGC'] = new_col1

nodes_df[:5]
# Out:
#                        BGC     Accesion ID  \
# 0  GCA_000170895.region033  ABCS01000001.1
# 1  GCA_000170895.region034  ABCS01000001.1
# 2  GCA_000170895.region035  ABCS01000001.1
# 3  GCA_000170895.region036  ABCS01000003.1
# 4  GCA_000170895.region037  ABCS01000005.1
#
#                                          Description Product Prediction  \
# 0  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...            terpene
# 1  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...        siderophore
# 2  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...        bacteriocin
# 3  ABCS01000003.1 Plesiocystis pacifica SIR-1 110...          NRPS-like
# 4  ABCS01000005.1 Plesiocystis pacifica SIR-1 110...        transAT-PKS
#
#   BiG-SCAPE class Taxonomy
# 0         Terpene      NaN
# 1          Others      NaN
# 2           RiPPs      NaN
# 3            NRPS      NaN
# 4        PKSother      NaN

# %%
taxa_list = []

for i,r in nodes_df.iterrows():
    taxa_line = nodes_df['Description'].loc[i]
    if 'biosynthetic gene cluster' in str(taxa_line):
        taxa = 'NaN'
    else:
        if ' ' in taxa_line:
            taxa = taxa_line.split(' ')[1]
        else:
            taxa = 'NaN'
    taxa_list.append(taxa)
    
nodes_df['Taxonomy'] = taxa_list

nodes_df[:5]
# Out:
#                        BGC     Accesion ID  \
# 0  GCA_000170895.region033  ABCS01000001.1
# 1  GCA_000170895.region034  ABCS01000001.1
# 2  GCA_000170895.region035  ABCS01000001.1
# 3  GCA_000170895.region036  ABCS01000003.1
# 4  GCA_000170895.region037  ABCS01000005.1
#
#                                          Description Product Prediction  \
# 0  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...            terpene
# 1  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...        siderophore
# 2  ABCS01000001.1 Plesiocystis pacifica SIR-1 110...        bacteriocin
# 3  ABCS01000003.1 Plesiocystis pacifica SIR-1 110...          NRPS-like
# 4  ABCS01000005.1 Plesiocystis pacifica SIR-1 110...        transAT-PKS
#
#   BiG-SCAPE class      Taxonomy
# 0         Terpene  Plesiocystis
# 1          Others  Plesiocystis
# 2           RiPPs  Plesiocystis
# 3            NRPS  Plesiocystis
# 4        PKSother  Plesiocystis

# %%
c_dict = Counter(nodes_df['Taxonomy'])

c_dict
# Out:
# Counter({'Plesiocystis': 32,
#          'Streptomyces': 1423,
#          'Acidaminococcus': 1,
#          'Propionibacterium': 122,
#          'Cylindrospermopsis': 8,
#          'Fusobacterium': 6,
#          'Prevotella': 19,
#          'Peptoniphilus': 5,
#          'Gardnerella': 1,
#          'Parvimonas': 1,
#          'Cutibacterium': 2,
#          'Pseudoalteromonas': 28,
#          'Bacteroides': 21,
#          'Clostridium': 7,
#          'Peptostreptococcaceae': 2,
#          'Synechocystis': 7,
#          'Xenococcus': 14,
#          'Pseudanabaena': 13,
#          'Synechococcus': 9,
#          'Microcystis': 55,
#          'Sphaerospermopsis': 7,
#          'Pseudomonas': 73,
#          'Nostoc': 70,
#          'NaN': 3901,
#          'Oscillatoria': 33,
#          'Arthrospira': 3,
#          'Algoriphagus': 3,
#          'Geminocystis': 5,
#          'Treponema': 4,
#          'Anabaena': 61,
#          'Cyanothece': 36,
#          'Saccharomonospora': 10,
#          'Rivularia': 14,
#          'Chroococcidiopsis': 12,
#          'Chamaesiphon': 16,
#          'Calothrix': 61,
#          'Microcoleus': 9,
#          'Cylindrospermum': 24,
#          'Gloeocapsa': 11,
#          'Dactylococcopsis': 2,
#          'Halothece': 3,
#          'Leptolyngbya': 26,
#          'Nodularia': 11,
#          'Dolichospermum': 91,
#          'Bifidobacterium': 3,
#          'Xanthomonas': 8,
#          'Maribacter': 4,
#          'Oribacterium': 1,
#          'Veillonella': 1,
#          'Enterococcus': 16,
#          'Lachnospiraceae': 3,
#          'Mangrovimonas': 2,
#          'Kitasatospora': 42,
#          'Selenomonas': 1,
#          'Lachnoanaerobaculum': 2,
#          'Nodosilinea': 6,
#          'Spirulina': 11,
#          'Fischerella': 58,
#          'Mastigocladopsis': 14,
#          'Enhygromyxa': 118,
#          'Amycolatopsis': 23,
#          'Zobellia': 7,
#          'Pleurocapsa': 22,
#          'Microchaete': 10,
#          'Prochlorothrix': 6,
#          'Sutterella': 1,
#          'Clostridiales': 2,
#          'Actinomyces': 5,
#          'Aphanizomenon': 24,
#          'Nocardia': 38,
#          'Colwellia': 1,
#          'Labrenzia': 5})

# %% [markdown]
# ## 4.3. Obtaining GCFs

# %%
def get_neighbors(target,dataframe,column1,column2):
    subset1 = dataframe[(dataframe[column1]==target)]
    subcat = subset1.append(dataframe[(dataframe[column2]==target)])
    temp_list = []
    for index,row in subcat.iterrows():
        temp_list.append(subcat[column1][index])
        temp_list.append(subcat[column2][index])
    temp_list = list(np.unique(temp_list))
    return temp_list

def to_edges(l):
    it = iter(l)
    last = next(it)
    for current in it:
        yield last, current
        last = current

def to_graph(l):
    G = networkx.Graph()
    for part in l:
        G.add_nodes_from(part)
        G.add_edges_from(to_edges(part))
    return G

def get_family_dict(components_list,dataframe,dictionary):
    count = 0
    for family in list(components_list):
        count += 1
        for fam_member in family:
            dictionary['GCF%s'%count].append(fam_member)
    return dictionary

def main_get_families(input_file,bigscape_df):
    targets_list = np.unique([bigscape_df.Clustername_1,bigscape_df.Clustername_2])
    neighbors_list = []
    for target in targets_list:
        neighbors_list.append(get_neighbors(target,bigscape_df,'Clustername_1','Clustername_2'))
    G = to_graph(neighbors_list)
    C = connected_components(G)
    gcf_dict = defaultdict(list)
    gcf_dict = get_family_dict(C,bigscape_df,gcf_dict)
    return gcf_dict

# %%
def get_bigscape_df(input_file):
    bigscape_df = pd.read_csv(input_file,sep='\t')
    bigscape_df.rename(columns=lambda x: re.sub(' ','_',x), inplace=True)
    bigscape_df = bigscape_df[bigscape_df.Clustername_1 != bigscape_df.Clustername_2]
    bigscape_df.reset_index(inplace=True,drop=True)
    return bigscape_df

bigscape_df = get_bigscape_df("./bigscape_outputs_210124/bigscape_all_c030.txt")

name_dict = dict(zip(gbk_list, new_name_list))
new_col1, new_col2 = [],[]

for i,r in bigscape_df.iterrows():
    if 'BGC' not in bigscape_df['Clustername_1'].loc[i]:
        new_col1.append(name_dict[bigscape_df['Clustername_1'].loc[i]])
    else:
        new_col1.append(bigscape_df['Clustername_1'].loc[i])
    if 'BGC' not in bigscape_df['Clustername_2'].loc[i]:
        new_col2.append(name_dict[bigscape_df['Clustername_2'].loc[i]])
    else:
        new_col2.append(bigscape_df['Clustername_2'].loc[i])
    
bigscape_df['Clustername_1'] = new_col1
bigscape_df['Clustername_2'] = new_col2

gcf_dict = main_get_families('./bigscape_outputs_210124/bigscape_all_c030.txt',bigscape_df)

# %%
gcf_dict
# Out:
# defaultdict(list,
#             {'GCF1': ['BGC0000017.1',
#               'VILF01.region013',
#               'GCA_000180455.region032'],
#              'GCF2': ['GCA_000710405.region066',
#               'BGC0000028.1',
#               'GCA_000377965.region080',
#               'BGC0001232.1',
#               'BGC0001348.1'],
#              'GCF3': ['BGC0000047.1',
#               'GCA_000412265.region053',
#               'BGC0001396.1',
#               'BGC0000035.1'],
#              'GCF4': ['BGC0000849.1',
#               'GCA_000203835.region050',
#               'BGC0000038.1',
#               'GCA_000739105.region035'],
#              'GCF5': ['GCA_000424805.region075',
#               'GCA_000377125.region047',
#               'GCA_000377165.region050',
#               'GCA_000377105.region087',
#               'GCA_000482585.region047',
#               'GCA_000514995.region068',
#               'GCA_000514715.region069',
#               'GCA_000701285.region059',
#               'BGC0000050.1'],
#              'GCF6': ['BGC0001581.1',
#               'GCA_000412265.region040',
#               'BGC0001662.1',
#               'BGC0000052.1'],
#              'GCF7': ['GCA_000012265.region020', 'BGC0000127.1'],
#              'GCF8': ['GCA_000701285.region047',
#               'GCA_000377105.region068',
#               'BGC0000164.1'],
#              'GCF9': ['BGC0000171.1', 'GCA_000158915.region052'],
#              'GCF10': ['BGC0000194.1',
#               'GCA_000203835.region042',
#               'BGC0000228.1',
#               'GCA_000739105.region043',
#               'BGC0000227.1'],
#              'GCF11': ['BGC0000236.1',
#               'BGC0001384.1',
#               'BGC0000231.1',
#               'BGC0001596.1',
#               'BGC0000201.1',
#               'BGC0001769.1',
#               'GCA_000377965.region070',
#               'GCA_000377125.region079',
#               'BGC0000262.1',
#               'BGC0001308.1',
#               'BGC0000239.1',
#               'BGC0000234.1',
#               'BGC0000267.1',
#               'BGC0000226.1',
#               'BGC0000253.1',
#               'BGC0000223.1',
#               'GCA_000377105.region080',
#               'BGC0000229.1',
#               'BGC0000235.1',
#               'BGC0000276.1',
#               'BGC0000270.1',
#               'GCA_000415505.region085',
#               'GCA_000424825.region050',
#               'BGC0001661.1',
#               'GCA_000514995.region073',
#               'BGC0001723.1',
#               'BGC0001438.1',
#               'BGC0000203.1',
#               'GCA_002941025.region047',
#               'BGC0001072.1',
#               'GCA_000514715.region064',
#               'GCA_000424805.region079'],
#              'GCF12': ['BGC0000210.1', 'GCA_003610995.region038'],
#              'GCF13': ['BGC0001558.1',
#               'GCA_000377525.region051',
#               'BGC0001568.1',
#               'GCA_000365385.region054',
#               'BGC0000214.1',
#               'BGC0001074.1'],
#              'GCF14': ['GCA_000203835.region044',
#               'GCA_000415505.region096',
#               'GCA_000482585.region063',
#               'BGC0000215.1',
#               'GCA_002941025.region067',
#               'BGC0000271.1',
#               'GCA_000377145.region039',
#               'GCA_000710405.region070',
#               'GCA_000739105.region041',
#               'BGC0001512.1',
#               'BGC0001366.1',
#               'GCA_000721595.region038'],
#              'GCF15': ['GCA_000424765.region063', 'BGC0000220.1'],
#              'GCF16': ['GCA_000377525.region047',
#               'GCA_000158915.region051',
#               'GCA_000240165.region057',
#               'GCA_000424805.region064',
#               'GCA_000721595.region042',
#               'GCA_002899455.region028',
#               'GCA_000377145.region043',
#               'GCA_000415505.region068',
#               'GCA_000482585.region042',
#               'GCA_000156435.region047',
#               'GCA_000739105.region032',
#               'GCA_000424965.region040',
#               'BGC0000663.1',
#               'GCA_000213055.region025',
#               'GCA_000377105.region073',
#               'GCA_000377165.region065',
#               'GCA_000365385.region040',
#               'GCA_002941025.region042',
#               'GCA_000365385.region061',
#               'GCA_002899455.region037',
#               'GCA_000156695.region053',
#               'GCA_000514715.region045',
#               'GCA_011751035.region043',
#               'GCA_000377125.region069',
#               'GCA_000424785.region037',
#               'GCA_000426325.region032',
#               'BGC0001513.1',
#               'GCA_007363395.region068',
#               'GCA_000514995.region069',
#               'GCA_003610995.region054',
#               'GCA_000158915.region053',
#               'BGC0000272.1',
#               'GCA_000156435.region034',
#               'GCA_000426165.region025',
#               'GCA_000702365.region052',
#               'GCA_000701285.region069',
#               'GCA_000377525.region037',
#               'GCA_000424825.region029',
#               'GCA_000527195.region044',
#               'GCA_001445655.region067',
#               'GCA_000412265.region051',
#               'GCA_000158975.region028',
#               'GCA_011290345.region049',
#               'GCA_000527195.region032',
#               'GCA_000203835.region053',
#               'GCA_011290345.region035',
#               'GCA_000515055.region057',
#               'GCA_000412265.region057',
#               'GCA_000424765.region038',
#               'GCA_000377965.region043',
#               'GCA_000377545.region034',
#               'GCA_000515055.region045'],
#              'GCF17': ['GCA_000012265.region029',
#               'BGC0000281.1',
#               'BGC0000280.1'],
#              'GCF18': ['BGC0000287.1', 'GCA_003324555.region023'],
#              'GCF19': ['VIKY01.region022',
#               'GCA_002095975.region015',
#               'BGC0001705.1',
#               'GCA_000315585.region032',
#               'VIKY01.region024',
#               'GCA_008121535.region019',
#               'GCA_003945305.region014',
#               'VIKV01.region017',
#               'BGC0001667.1',
#               'GCA_003054475.region022',
#               'BGC0001016.1',
#               'GCA_000010625.region020',
#               'BGC0000302.1',
#               'GCA_001578075.region012',
#               'GCA_008121535.region023',
#               'BGC0001015.1',
#               'VIKZ01.region020',
#               'GCA_000312705.region015',
#               'GCA_002897315.region016',
#               'VIKZ01.region021',
#               'BGC0001017.1'],
#              'GCF20': ['GCA_000012445.region016',
#               'BGC0001509.1',
#               'BGC0000305.1'],
#              'GCF21': ['GCA_000156695.region050', 'BGC0000306.1'],
#              'GCF22': ['BGC0001370.1',
#               'BGC0000315.1',
#               'GCA_000203835.region041',
#               'GCA_000739105.region044'],
#              'GCF23': ['GCA_000203835.region058',
#               'GCA_000739105.region029',
#               'BGC0000324.1',
#               'GCA_000424765.region061'],
#              'GCF24': ['GCA_002941025.region036',
#               'GCA_000415505.region075',
#               'GCA_000721595.region046',
#               'GCA_000739105.region050',
#               'BGC0000325.1',
#               'GCA_000203835.region035',
#               'GCA_007363395.region080',
#               'GCA_011751035.region046',
#               'GCA_000158915.region041'],
#              'GCF25': ['BGC0000332.1',
#               'GCA_002897315.region025',
#               'GCA_001578075.region010',
#               'BGC0001018.1',
#               'GCA_003945305.region018',
#               'GCA_000010625.region024',
#               'GCA_002095975.region017',
#               'BGC0000331.1'],
#              'GCF26': ['BGC0000336.1', 'GCA_000156695.region032'],
#              'GCF27': ['GCA_000702365.region065',
#               'GCA_003610995.region033',
#               'BGC0000368.1',
#               'GCA_000377965.region057'],
#              'GCF28': ['VIKY01.region021',
#               'BGC0000369.1',
#               'VIKV01.region024',
#               'GCA_000312705.region020'],
#              'GCF29': ['GCA_000158975.region043', 'BGC0000374.1'],
#              'GCF30': ['BGC0000398.1',
#               'GCA_000012265.region019',
#               'BGC0000399.1'],
#              'GCF31': ['GCA_003324555.region021',
#               'BGC0000936.1',
#               'GCA_003324555.region026',
#               'GCA_000506385.region028',
#               'BGC0000412.1'],
#              'GCF32': ['GCA_000506385.region025',
#               'GCA_000012265.region026',
#               'GCA_000012265.region025',
#               'BGC0000413.1',
#               'GCA_000012445.region019'],
#              'GCF33': ['GCA_000515055.region060',
#               'BGC0000423.1',
#               'GCA_000365385.region063'],
#              'GCF34': ['BGC0000431.1', 'GCA_000156695.region035'],
#              'GCF35': ['BGC0000473.1',
#               'GCA_002095975.region014',
#               'BGC0000471.1',
#               'BGC0000475.1',
#               'BGC0000474.1',
#               'BGC0000480.1',
#               'BGC0000483.1'],
#              'GCF36': ['BGC0001505.1',
#               'VIKZ01.region017',
#               'VILF01.region023',
#               'VIKY01.region013',
#               'GCA_008121535.region017',
#               'GCA_000312705.region023',
#               'BGC0000472.1',
#               'VILC01.region018',
#               'VIKV01.region015'],
#              'GCF37': ['GCA_000702365.region054',
#               'GCA_003610995.region048',
#               'GCA_000377965.region054',
#               'GCA_000156695.region045',
#               'BGC0000496.1'],
#              'GCF38': ['GCA_000426165.region039', 'BGC0000544.1'],
#              'GCF39': ['BGC0000551.1',
#               'GCA_000739105.region033',
#               'GCA_000203835.region052'],
#              'GCF40': ['BGC0000610.1', 'GCA_000415505.region083'],
#              'GCF41': ['GCA_000295415.region003',
#               'GCA_000295235.region006',
#               'ERR3941300_contigs.region028',
#               'BGC0000618.1',
#               'GCA_000295355.region003',
#               'GCA_000295235.region005',
#               'GCA_000295175.region005',
#               'GCA_000295575.region003',
#               'GCA_000295055.region005'],
#              'GCF42': ['GCA_001625105.region069', 'BGC0000632.1'],
#              'GCF43': ['GCA_000377525.region035',
#               'BGC0001359.1',
#               'GCA_000377965.region056',
#               'GCA_000377145.region052',
#               'GCA_000426325.region036',
#               'GCA_000739105.region052',
#               'GCA_000721595.region045',
#               'GCA_000203835.region033',
#               'GCA_000424825.region035',
#               'GCA_000412265.region034',
#               'BGC0000649.1',
#               'GCA_000515055.region052',
#               'GCA_011290345.region028',
#               'GCA_002941025.region037',
#               'BGC0000664.1',
#               'GCA_000365385.region042'],
#              'GCF44': ['BGC0000650.1', 'GCA_000166275.region005'],
#              'GCF45': ['GCA_000482585.region066',
#               'GCA_000377165.region079',
#               'GCA_000424845.region029',
#               'BGC0001079.1',
#               'GCA_000377125.region088',
#               'GCA_000377125.region086',
#               'GCA_000377105.region089',
#               'GCA_000514995.region078',
#               'BGC0000652.1',
#               'GCA_000377105.region093',
#               'GCA_000377125.region085',
#               'GCA_000377165.region075',
#               'GCA_000527195.region043',
#               'BGC0001083.1',
#               'GCA_000482585.region064',
#               'GCA_000514995.region080',
#               'GCA_000701285.region072',
#               'GCA_000527195.region042',
#               'GCA_000377165.region076',
#               'GCA_000424805.region077'],
#              'GCF46': ['BGC0000654.1', 'GCA_000213055.region029'],
#              'GCF47': ['BGC0000658.1',
#               'GCA_000721595.region057',
#               'GCA_000702365.region072'],
#              'GCF48': ['GCA_000415505.region080',
#               'GCA_000739105.region042',
#               'BGC0000660.1',
#               'GCA_000158975.region036',
#               'GCA_000156435.region042',
#               'GCA_000527195.region026',
#               'GCA_007363395.region062',
#               'GCA_000203835.region043',
#               'GCA_002899455.region033'],
#              'GCF49': ['GCA_000020025.region029', 'BGC0000661.1'],
#              'GCF50': ['BGC0001501.1',
#               'BGC0001594.1',
#               'BGC0001126.1',
#               'BGC0001612.1',
#               'GCA_000447295.region030',
#               'BGC0000668.1',
#               'BGC0001595.1'],
#              'GCF51': ['BGC0000709.1',
#               'BGC0000710.1',
#               'BGC0000712.1',
#               'BGC0000711.1',
#               'BGC0000713.1',
#               'GCA_000377965.region064'],
#              'GCF52': ['GCA_007363395.region074', 'BGC0000715.1'],
#              'GCF53': ['BGC0000847.1', 'GCA_000240165.region069'],
#              'GCF54': ['GCA_000377965.region055',
#               'BGC0000848.1',
#               'GCA_000702365.region078'],
#              'GCF55': ['GCA_000739105.region047',
#               'GCA_000377105.region060',
#               'GCA_007363395.region056',
#               'GCA_000424825.region044',
#               'GCA_000415505.region101',
#               'GCA_000377965.region061',
#               'GCA_000213055.region037',
#               'GCA_003248315.region036',
#               'GCA_000377125.region060',
#               'GCA_002899455.region041',
#               'GCA_000424805.region073',
#               'GCA_000702365.region049',
#               'GCA_000156695.region036',
#               'GCA_000701285.region061',
#               'GCA_000426325.region034',
#               'GCA_000482585.region051',
#               'GCA_002941025.region059',
#               'GCA_000158915.region065',
#               'GCA_001445655.region086',
#               'GCA_000424965.region045',
#               'GCA_000156435.region046',
#               'GCA_000426165.region028',
#               'GCA_000424845.region024',
#               'GCA_003610995.region037',
#               'GCA_000240165.region044',
#               'GCA_000377145.region044',
#               'GCA_011751035.region049',
#               'GCA_000514715.region055',
#               'GCA_000377525.region041',
#               'GCA_000365385.region060',
#               'GCA_000158975.region041',
#               'GCA_000203835.region038',
#               'GCA_000424785.region024',
#               'BGC0000853.1',
#               'GCA_000721595.region064',
#               'GCA_000377165.region053',
#               'GCA_000515055.region042',
#               'GCA_000514995.region054',
#               'GCA_000424765.region041',
#               'GCA_011290345.region045',
#               'GCA_000527195.region035',
#               'GCA_000377545.region051',
#               'GCA_002899455.region036'],
#              'GCF56': ['GCA_000175835.region012',
#               'VILF01.region015',
#               'GCA_000332295.region012',
#               'GCA_003054475.region017',
#               'VIKX01.region022',
#               'VILD01.region011',
#               'GCA_000315585.region036',
#               'GCA_000317535.region036',
#               'VILB01.region013',
#               'VIKZ01.region029',
#               'GCA_000009705.region027',
#               'GCA_000315565.region024',
#               'VIKV01.region022',
#               'BGC0000869.1',
#               'VILC01.region014',
#               'GCA_000020025.region024',
#               'GCA_000204075.region021',
#               'GCA_000316575.region021',
#               'GCA_008121535.region026',
#               'VILE01.region025',
#               'GCA_002368075.region013',
#               'VIKY01.region015',
#               'GCA_000331305.region037',
#               'GCA_000521175.region021',
#               'GCA_000312705.region022',
#               'GCA_003326215.region047',
#               'VIKW01.region015'],
#              'GCF57': ['GCA_000156695.region040', 'BGC0000904.1'],
#              'GCF58': ['GCA_000203835.region039',
#               'GCA_003248315.region035',
#               'BGC0000910.1',
#               'GCA_000739105.region046'],
#              'GCF59': ['GCA_000377965.region049',
#               'GCA_003610995.region059',
#               'GCA_000156695.region057',
#               'GCA_000702365.region061',
#               'BGC0000911.1'],
#              'GCF60': ['GCA_000377965.region053', 'BGC0000912.1'],
#              'GCF61': ['GCA_000203835.region031', 'BGC0000914.1'],
#              'GCF62': ['GCA_000012265.region023', 'BGC0000924.1'],
#              'GCF63': ['GCA_000710405.region053',
#               'BGC0001080.1',
#               'BGC0001078.1',
#               'BGC0000934.1'],
#              'GCF64': ['GCA_000701285.region080',
#               'GCA_000527195.region030',
#               'GCA_000702365.region058',
#               'GCA_000156695.region038',
#               'GCA_000426165.region031',
#               'GCA_003248315.region034',
#               'GCA_000482585.region040',
#               'GCA_000515055.region041',
#               'GCA_000377105.region052',
#               'GCA_000203835.region040',
#               'GCA_000424805.region052',
#               'GCA_000156435.region043',
#               'GCA_000514715.region066',
#               'GCA_000514995.region049',
#               'GCA_000158975.region039',
#               'GCA_000377165.region045',
#               'GCA_000377145.region035',
#               'GCA_000240165.region065',
#               'GCA_002899455.region035',
#               'BGC0000940.1',
#               'GCA_000424765.region054',
#               'GCA_000721595.region037',
#               'BGC0001478.1',
#               'GCA_000415505.region077',
#               'GCA_000377965.region068',
#               'GCA_000377545.region048',
#               'GCA_011290345.region046',
#               'GCA_002941025.region049',
#               'BGC0000941.1',
#               'GCA_003610995.region040',
#               'GCA_000424965.region050',
#               'GCA_000739105.region045',
#               'GCA_000377525.region040',
#               'GCA_000412265.region044',
#               'GCA_000424785.region027',
#               'GCA_000377125.region050',
#               'GCA_000158915.region059',
#               'GCA_000365385.region068'],
#              'GCF65': ['BGC0000950.1', 'GCA_000156695.region039'],
#              'GCF66': ['BGC0001216.1',
#               'GCA_000377545.region054',
#               'BGC0000958.1',
#               'GCA_002899455.region025'],
#              'GCF67': ['GCA_000702365.region075',
#               'GCA_000156695.region051',
#               'BGC0000973.1'],
#              'GCF68': ['GCA_000377545.region035',
#               'GCA_000213055.region032',
#               'BGC0000996.1'],
#              'GCF69': ['GCA_000020025.region027', 'BGC0001028.1'],
#              'GCF70': ['GCA_003610995.region057',
#               'GCA_000156695.region054',
#               'GCA_000702365.region051',
#               'BGC0001043.1',
#               'GCA_000377965.region046',
#               'GCA_000721595.region047',
#               'GCA_003610995.region056',
#               'GCA_000156695.region055'],
#              'GCF71': ['BGC0001064.1',
#               'BGC0001357.1',
#               'GCA_000317535.region033',
#               'BGC0001566.1'],
#              'GCF72': ['BGC0001088.1', 'GCA_000087965.region015'],
#              'GCF73': ['BGC0001112.1', 'GCA_000012265.region021'],
#              'GCF74': ['GCA_000158915.region071', 'BGC0001117.1'],
#              'GCF75': ['BGC0001172.1', 'GCA_000424825.region028'],
#              'GCF76': ['BGC0001221.1',
#               'GCA_000482585.region071',
#               'GCA_000377125.region064',
#               'GCA_000424805.region092',
#               'GCA_000377105.region064',
#               'GCA_000514995.region055',
#               'GCA_000701285.region050',
#               'GCA_000377165.region048',
#               'GCA_000377125.region063',
#               'GCA_000377165.region047',
#               'GCA_000424805.region091',
#               'GCA_000377105.region065',
#               'GCA_000482585.region072',
#               'GCA_000514715.region046'],
#              'GCF77': ['GCA_000377965.region072',
#               'BGC0001230.1',
#               'BGC0001766.1'],
#              'GCF78': ['BGC0001236.1',
#               'BGC0001355.1',
#               'BGC0001354.1',
#               'GCA_000415505.region091'],
#              'GCF79': ['BGC0001283.1', 'GCA_000514995.region056'],
#              'GCF80': ['GCA_001562525.region018', 'BGC0001285.1'],
#              'GCF81': ['BGC0001297.1', 'GCA_000158975.region040'],
#              'GCF82': ['BGC0001298.1', 'GCA_002899455.region027'],
#              'GCF83': ['BGC0001350.1', 'GCA_000316115.region014'],
#              'GCF84': ['BGC0001452.1',
#               'GCA_000156695.region049',
#               'BGC0001522.1'],
#              'GCF85': ['BGC0001467.1', 'GCA_000447295.region029'],
#              'GCF86': ['GCA_011290345.region033', 'BGC0001476.1'],
#              'GCF87': ['BGC0001477.1',
#               'GCA_011290345.region048',
#               'GCA_002941025.region040'],
#              'GCF88': ['GCA_011290345.region039', 'BGC0001507.1'],
#              'GCF89': ['BGC0001673.1',
#               'BGC0001539.1',
#               'GCA_000240165.region039'],
#              'GCF90': ['BGC0001553.1', 'GCA_000710405.region051'],
#              'GCF91': ['GCA_011290345.region029', 'BGC0001570.1'],
#              'GCF92': ['BGC0001726.1', 'GCA_002941025.region041'],
#              'GCF93': ['BGC0001745.1', 'GCA_000332195.region028'],
#              'GCF94': ['GCA_001445655.region074', 'BGC0001752.1'],
#              'GCF95': ['GCA_001445655.region057', 'BGC0001770.1'],
#              'GCF96': ['BGC0001792.1', 'GCA_000377545.region053'],
#              'GCF97': ['BGC0001819.1',
#               'GCA_000702365.region071',
#               'BGC0001801.1'],
#              'GCF98': ['GCA_000412265.region038', 'BGC0001823.1'],
#              'GCF99': ['ERR3946792_contigs.region014',
#               'ERR3946746_contigs.region011',
#               'ERR3946823_contigs.region019',
#               'ERR3946882_contigs.region015',
#               'ERR3958077_contigs.region012',
#               'ERR3941172_contigs.region029',
#               'ERR3941051_contigs.region027',
#               'ERR3946853_contigs.region008',
#               'ERR3941312_contigs.region019',
#               'ERR3941228_contigs.region014',
#               'ERR3941200_contigs.region014',
#               'ERR3941269_contigs.region009',
#               'ERR3946847_contigs.region008',
#               'ERR3958119_contigs.region009',
#               'ERR3941178_contigs.region011',
#               'ERR3941327_contigs.region004',
#               'ERR3941182_contigs.region011',
#               'ERR3946885_contigs.region029',
#               'ERR3941388_contigs.region008',
#               'ERR3946874_contigs.region016',
#               'ERR3941295_contigs.region014',
#               'ERR3946853_contigs.region009',
#               'ERR3941288_contigs.region009',
#               'ERR3946866_contigs.region017',
#               'ERR3946873_contigs.region022'],
#              'GCF100': ['ERR3941051_contigs.region034',
#               'ERR3941317_contigs.region008',
#               'ERR3946701_contigs.region020',
#               'ERR3941104_contigs.region026',
#               'ERR3941343_contigs.region032',
#               'GCA_000269545.region002',
#               'ERR3946874_contigs.region023',
#               'ERR3941051_contigs.region029',
#               'ERR3941249_contigs.region010',
#               'ERR3941094_contigs.region012',
#               'ERR3941187_contigs.region015',
#               'ERR3941176_contigs.region007',
#               'ERR3946882_contigs.region026',
#               'ERR3941150_contigs.region024',
#               'ERR3941378_contigs.region028',
#               'ERR3941389_contigs.region017',
#               'ERR3941220_contigs.region015',
#               'ERR3941209_contigs.region010',
#               'ERR3941107_contigs.region008',
#               'ERR3946732_contigs.region014',
#               'ERR3946736_contigs.region021',
#               'ERR3941341_contigs.region018',
#               'ERR3946722_contigs.region012',
#               'ERR3941075_contigs.region009',
#               'ERR3941356_contigs.region015',
#               'GCA_000158335.region003',
#               'ERR3941229_contigs.region017',
#               'ERR3941351_contigs.region024',
#               'ERR3946874_contigs.region020',
#               'GCA_000218325.region002',
#               'ERR3941319_contigs.region013',
#               'ERR3946727_contigs.region015',
#               'ERR3941079_contigs.region023',
#               'ERR3946885_contigs.region042',
#               'ERR3941271_contigs.region019',
#               'ERR3941394_contigs.region021',
#               'ERR3941075_contigs.region012',
#               'ERR3941150_contigs.region019',
#               'GCA_000159075.region002',
#               'ERR3941374_contigs.region017',
#               'ERR3941247_contigs.region017',
#               'ERR3946789_contigs.region042',
#               'ERR3946874_contigs.region022',
#               'ERR3941374_contigs.region016',
#               'ERR3946868_contigs.region019',
#               'ERR3941360_contigs.region018',
#               'ERR3941351_contigs.region025',
#               'ERR3941379_contigs.region010',
#               'GCA_000273015.region003',
#               'ERR3946693_contigs.region018',
#               'ERR3941146_contigs.region023',
#               'ERR3946860_contigs.region022',
#               'ERR3941062_contigs.region020',
#               'ERR3941177_contigs.region009',
#               'ERR3941051_contigs.region028',
#               'ERR3946744_contigs.region023',
#               'ERR3946868_contigs.region020',
#               'ERR3946864_contigs.region036',
#               'ERR3941091_contigs.region010',
#               'ERR3941219_contigs.region020',
#               'ERR3946797_contigs.region012',
#               'ERR3941374_contigs.region019',
#               'ERR3941074_contigs.region015',
#               'ERR3958041_contigs.region016',
#               'ERR3941306_contigs.region012',
#               'ERR3941230_contigs.region010',
#               'GCA_000273055.region004',
#               'ERR3941273_contigs.region017',
#               'ERR3946890_contigs.region022',
#               'ERR3941071_contigs.region013',
#               'ERR3941301_contigs.region011',
#               'ERR3941206_contigs.region008',
#               'ERR3946740_contigs.region014',
#               'ERR3946744_contigs.region024',
#               'ERR3946885_contigs.region033',
#               'ERR3941071_contigs.region014',
#               'ERR3946713_contigs.region012',
#               'ERR3941063_contigs.region017',
#               'ERR3946789_contigs.region040',
#               'ERR3946885_contigs.region039',
#               'ERR3941094_contigs.region014',
#               'ERR3946860_contigs.region020',
#               'ERR3946789_contigs.region034',
#               'ERR3941113_contigs.region014',
#               'ERR3941218_contigs.region013',
#               'ERR3941204_contigs.region013',
#               'ERR3946744_contigs.region025',
#               'ERR3941398_contigs.region011',
#               'ERR3941187_contigs.region011',
#               'ERR3941184_contigs.region022',
#               'ERR3941387_contigs.region003',
#               'ERR3946797_contigs.region011',
#               'ERR3941297_contigs.region021',
#               'ERR3941104_contigs.region025',
#               'ERR3946847_contigs.region010',
#               'ERR3946721_contigs.region016',
#               'ERR3958037_contigs.region008',
#               'ERR3941271_contigs.region022',
#               'ERR3941219_contigs.region017',
#               'ERR3941374_contigs.region020',
#               'ERR3941366_contigs.region016',
#               'GCA_000273295.region002',
#               'ERR3946885_contigs.region030',
#               'ERR3941051_contigs.region030',
#               'GCA_000273035.region004',
#               'ERR3941134_contigs.region013',
#               'ERR3946709_contigs.region012',
#               'ERR3941273_contigs.region015',
#               'ERR3946862_contigs.region020',
#               'ERR3941379_contigs.region011',
#               'ERR3941297_contigs.region020',
#               'GCA_000157075.region003',
#               'ERR3946890_contigs.region024'],
#              'GCF101': ['ERR3946830_contigs.region036',
#               'ERR3946808_contigs.region036',
#               'ERR3946736_contigs.region027',
#               'ERR3946783_contigs.region026',
#               'ERR3941051_contigs.region032'],
#              'GCF102': ['ERR3941188_contigs.region020',
#               'ERR3941351_contigs.region026',
#               'ERR3946855_contigs.region014',
#               'ERR3941213_contigs.region018',
#               'ERR3946812_contigs.region015',
#               'ERR3946745_contigs.region036',
#               'ERR3946833_contigs.region015',
#               'ERR3941051_contigs.region033',
#               'ERR3946718_contigs.region018',
#               'ERR3946808_contigs.region038',
#               'ERR3946736_contigs.region028',
#               'ERR3946815_contigs.region028',
#               'ERR3941205_contigs.region012',
#               'ERR3941127_contigs.region018',
#               'ERR3941246_contigs.region017',
#               'ERR3946745_contigs.region032',
#               'ERR3941122_contigs.region021',
#               'ERR3941254_contigs.region005',
#               'ERR3941333_contigs.region010',
#               'ERR3941162_contigs.region036',
#               'ERR3941188_contigs.region024',
#               'ERR3946829_contigs.region020',
#               'ERR3946804_contigs.region022',
#               'ERR3946781_contigs.region014',
#               'ERR3941181_contigs.region013',
#               'ERR3946756_contigs.region020',
#               'ERR3941175_contigs.region010',
#               'ERR3946758_contigs.region014',
#               'ERR3946807_contigs.region014',
#               'ERR3941181_contigs.region012',
#               'ERR3946792_contigs.region018',
#               'ERR3941177_contigs.region011',
#               'ERR3946808_contigs.region037',
#               'ERR3941133_contigs.region009'],
#              'GCF103': ['ERR3946842_contigs.region013',
#               'ERR3946808_contigs.region033',
#               'ERR3946757_contigs.region012',
#               'ERR3941378_contigs.region027',
#               'ERR3941126_contigs.region011',
#               'ERR3946830_contigs.region025',
#               'ERR3946802_contigs.region013',
#               'ERR3946759_contigs.region011',
#               'ERR3946750_contigs.region004',
#               'ERR3946820_contigs.region020',
#               'ERR3946768_contigs.region007',
#               'ERR3946886_contigs.region027',
#               'ERR3941325_contigs.region016',
#               'ERR3946804_contigs.region021',
#               'ERR3941118_contigs.region006',
#               'ERR3946759_contigs.region012',
#               'ERR3946707_contigs.region026',
#               'ERR3941249_contigs.region011',
#               'ERR3941257_contigs.region008',
#               'ERR3946820_contigs.region017',
#               'ERR3941293_contigs.region011',
#               'ERR3946863_contigs.region019',
#               'ERR3941118_contigs.region009',
#               'ERR3946819_contigs.region016',
#               'ERR3941188_contigs.region023',
#               'ERR3946819_contigs.region010',
#               'ERR3946831_contigs.region015',
#               'ERR3946809_contigs.region020',
#               'ERR3957990_contigs.region008',
#               'ERR3941236_contigs.region017',
#               'ERR3946731_contigs.region013',
#               'ERR3941305_contigs.region026',
#               'ERR3941120_contigs.region007',
#               'ERR3941350_contigs.region011',
#               'ERR3941137_contigs.region006',
#               'ERR3946701_contigs.region017',
#               'ERR3941110_contigs.region005',
#               'ERR3946777_contigs.region010',
#               'ERR3941205_contigs.region011',
#               'ERR3946713_contigs.region011',
#               'ERR3941147_contigs.region004',
#               'ERR3946718_contigs.region019',
#               'ERR3946765_contigs.region016',
#               'ERR3946886_contigs.region034',
#               'ERR3941084_contigs.region014',
#               'ERR3941181_contigs.region010',
#               'ERR3941138_contigs.region016',
#               'ERR3946723_contigs.region014',
#               'ERR3941131_contigs.region006',
#               'ERR3941232_contigs.region006',
#               'ERR3941207_contigs.region006',
#               'ERR3941165_contigs.region016',
#               'ERR3941249_contigs.region009',
#               'ERR3946860_contigs.region023',
#               'ERR3946842_contigs.region018',
#               'ERR3946793_contigs.region014',
#               'ERR3946893_contigs.region012',
#               'ERR3946835_contigs.region022',
#               'ERR3941151_contigs.region015',
#               'ERR3946883_contigs.region021',
#               'ERR3946832_contigs.region025',
#               'ERR3946805_contigs.region018',
#               'ERR3941187_contigs.region014',
#               'ERR3958077_contigs.region011',
#               'ERR3946882_contigs.region022',
#               'ERR3941106_contigs.region021',
#               'ERR3941126_contigs.region012',
#               'ERR3946778_contigs.region018',
#               'ERR3941210_contigs.region013',
#               'ERR3946862_contigs.region018',
#               'ERR3946873_contigs.region025',
#               'ERR3946860_contigs.region021',
#               'ERR3941098_contigs.region010',
#               'ERR3946835_contigs.region031',
#               'ERR3946860_contigs.region013',
#               'ERR3946707_contigs.region021',
#               'ERR3941333_contigs.region009',
#               'ERR3941347_contigs.region010',
#               'ERR3941289_contigs.region021',
#               'ERR3946798_contigs.region012',
#               'ERR3941365_contigs.region009',
#               'ERR3946723_contigs.region017',
#               'ERR3941174_contigs.region019',
#               'ERR3946767_contigs.region013',
#               'ERR3941095_contigs.region012',
#               'ERR3941181_contigs.region011',
#               'ERR3946832_contigs.region030',
#               'ERR3941308_contigs.region024',
#               'ERR3946792_contigs.region011',
#               'ERR3946862_contigs.region022',
#               'ERR3946880_contigs.region009',
#               'ERR3941094_contigs.region015',
#               'ERR3946856_contigs.region004',
#               'ERR3941113_contigs.region016',
#               'ERR3941225_contigs.region012',
#               'ERR3941172_contigs.region034',
#               'ERR3941341_contigs.region017',
#               'ERR3941121_contigs.region007',
#               'ERR3946893_contigs.region007',
#               'ERR3946807_contigs.region012',
#               'ERR3946807_contigs.region010',
#               'ERR3941232_contigs.region009',
#               'ERR3946738_contigs.region006',
#               'ERR3946810_contigs.region021',
#               'ERR3941273_contigs.region020',
#               'ERR3946817_contigs.region011',
#               'ERR3941401_contigs.region017',
#               'ERR3941123_contigs.region008',
#               'ERR3941153_contigs.region020',
#               'ERR3941217_contigs.region009',
#               'ERR3946766_contigs.region013',
#               'ERR3941104_contigs.region024',
#               'ERR3946796_contigs.region018',
#               'ERR3941246_contigs.region015',
#               'ERR3946804_contigs.region019',
#               'ERR3941309_contigs.region010',
#               'ERR3941255_contigs.region015',
#               'ERR3941122_contigs.region018',
#               'ERR3941141_contigs.region008',
#               'ERR3941308_contigs.region027',
#               'ERR3941286_contigs.region016',
#               'ERR3941169_contigs.region020',
#               'ERR3941260_contigs.region008',
#               'ERR3941212_contigs.region015',
#               'ERR3941237_contigs.region006',
#               'ERR3941368_contigs.region022',
#               'ERR3941335_contigs.region010',
#               'ERR3941387_contigs.region004',
#               'ERR3946794_contigs.region012',
#               'ERR3946770_contigs.region015',
#               'ERR3941185_contigs.region012',
#               'ERR3941200_contigs.region017',
#               'ERR3946885_contigs.region024',
#               'ERR3941232_contigs.region007',
#               'ERR3946805_contigs.region017',
#               'ERR3941109_contigs.region018',
#               'ERR3941304_contigs.region007',
#               'ERR3941223_contigs.region021',
#               'ERR3946819_contigs.region018',
#               'ERR3946868_contigs.region016',
#               'ERR3958045_contigs.region008',
#               'ERR3946759_contigs.region013',
#               'ERR3946761_contigs.region009',
#               'ERR3946809_contigs.region028',
#               'ERR3941356_contigs.region017',
#               'ERR3958041_contigs.region014',
#               'ERR3946887_contigs.region028',
#               'ERR3941320_contigs.region011',
#               'ERR3941328_contigs.region010',
#               'ERR3946768_contigs.region006',
#               'ERR3941173_contigs.region009',
#               'ERR3941122_contigs.region015',
#               'ERR3946800_contigs.region016',
#               'ERR3946835_contigs.region030',
#               'ERR3941363_contigs.region016',
#               'ERR3946808_contigs.region023',
#               'ERR3941357_contigs.region011',
#               'ERR3941206_contigs.region007',
#               'ERR3941315_contigs.region027',
#               'ERR3941213_contigs.region020',
#               'ERR3941381_contigs.region012',
#               'ERR3946809_contigs.region029',
#               'ERR3946804_contigs.region017',
#               'ERR3941182_contigs.region009',
#               'ERR3946854_contigs.region011',
#               'ERR3946709_contigs.region010',
#               'ERR3946810_contigs.region027',
#               'ERR3946799_contigs.region008',
#               'ERR3941283_contigs.region012',
#               'ERR3941292_contigs.region011',
#               'ERR3958084_contigs.region004',
#               'ERR3946792_contigs.region015',
#               'ERR3941331_contigs.region010',
#               'ERR3941057_contigs.region017',
#               'ERR3941178_contigs.region014',
#               'ERR3941276_contigs.region013',
#               'ERR3946848_contigs.region027',
#               'ERR3946823_contigs.region016',
#               'ERR3946772_contigs.region006',
#               'ERR3946740_contigs.region015',
#               'ERR3941273_contigs.region019',
#               'ERR3941185_contigs.region010',
#               'ERR3946886_contigs.region022',
#               'ERR3941396_contigs.region010',
#               'ERR3946707_contigs.region024',
#               'ERR3946873_contigs.region023',
#               'ERR3941197_contigs.region012',
#               'ERR3946864_contigs.region028',
#               'ERR3941251_contigs.region013',
#               'ERR3946741_contigs.region035',
#               'ERR3946798_contigs.region014',
#               'ERR3941135_contigs.region012',
#               'ERR3946798_contigs.region013',
#               'ERR3941185_contigs.region008',
#               'ERR3946883_contigs.region020',
#               'ERR3941129_contigs.region011',
#               'ERR3946756_contigs.region021',
#               'ERR3941381_contigs.region014',
#               'ERR3941232_contigs.region010',
#               'ERR3941134_contigs.region012',
#               'ERR3941236_contigs.region024',
#               'ERR3946874_contigs.region018',
#               'ERR3941324_contigs.region008',
#               'ERR3946829_contigs.region017',
#               'ERR3946809_contigs.region024',
#               'ERR3941375_contigs.region021',
#               'ERR3941327_contigs.region005',
#               'ERR3946848_contigs.region030',
#               'ERR3941063_contigs.region016',
#               'ERR3941369_contigs.region013',
#               'ERR3941073_contigs.region008',
#               'ERR3946838_contigs.region012',
#               'ERR3946851_contigs.region024',
#               'ERR3946828_contigs.region008',
#               'ERR3941139_contigs.region008',
#               'ERR3946842_contigs.region015',
#               'ERR3941238_contigs.region008',
#               'ERR3946884_contigs.region015',
#               'ERR3941135_contigs.region009',
#               'ERR3941243_contigs.region009',
#               'ERR3941108_contigs.region020',
#               'ERR3958026_contigs.region006',
#               'ERR3941188_contigs.region018',
#               'ERR3941385_contigs.region012',
#               'ERR3946830_contigs.region026',
#               'ERR3946761_contigs.region007',
#               'ERR3946727_contigs.region016',
#               'ERR3946811_contigs.region022',
#               'ERR3941329_contigs.region012',
#               'ERR3946830_contigs.region031',
#               'ERR3946767_contigs.region014',
#               'ERR3946882_contigs.region020',
#               'ERR3946859_contigs.region012',
#               'ERR3941127_contigs.region015',
#               'ERR3941265_contigs.region008',
#               'ERR3946805_contigs.region021',
#               'ERR3946862_contigs.region017',
#               'ERR3941191_contigs.region008',
#               'ERR3941312_contigs.region016',
#               'ERR3946889_contigs.region015',
#               'ERR3946838_contigs.region010',
#               'ERR3946801_contigs.region025',
#               'ERR3941204_contigs.region012',
#               'ERR3946736_contigs.region025',
#               'ERR3941136_contigs.region010',
#               'ERR3946701_contigs.region018',
#               'ERR3946831_contigs.region020',
#               'ERR3946872_contigs.region012',
#               'ERR3941213_contigs.region016',
#               'ERR3946756_contigs.region015',
#               'ERR3941304_contigs.region008',
#               'ERR3946698_contigs.region023',
#               'ERR3941148_contigs.region021',
#               'ERR3946802_contigs.region015',
#               'ERR3941160_contigs.region005',
#               'ERR3941149_contigs.region007',
#               'ERR3941325_contigs.region017',
#               'ERR3946846_contigs.region022',
#               'ERR3941265_contigs.region012',
#               'ERR3941274_contigs.region015',
#               'ERR3941375_contigs.region020',
#               'ERR3941313_contigs.region004',
#               'ERR3941211_contigs.region008',
#               'ERR3941341_contigs.region020',
#               'ERR3946832_contigs.region027',
#               'ERR3946851_contigs.region028',
#               'ERR3941122_contigs.region013',
#               'ERR3946783_contigs.region024',
#               'ERR3941085_contigs.region018',
#               'ERR3958101_contigs.region002',
#               'ERR3941316_contigs.region018',
#               'ERR3946754_contigs.region006',
#               'ERR3941293_contigs.region009',
#               'ERR3946867_contigs.region008',
#               'ERR3946763_contigs.region016',
#               'ERR3946777_contigs.region015',
#               'ERR3941253_contigs.region006',
#               'ERR3941351_contigs.region021',
#               'ERR3941129_contigs.region009',
#               'ERR3946873_contigs.region017',
#               'ERR3946863_contigs.region022',
#               'ERR3941213_contigs.region015',
#               'ERR3958060_contigs.region002',
#               'ERR3946762_contigs.region012',
#               'ERR3941071_contigs.region016',
#               'ERR3946842_contigs.region014',
#               'ERR3941360_contigs.region016',
#               'ERR3946879_contigs.region013',
#               'ERR3941359_contigs.region009',
#               'ERR3941210_contigs.region011',
#               'ERR3941256_contigs.region012',
#               'ERR3946796_contigs.region016',
#               'ERR3946744_contigs.region016',
#               'ERR3941087_contigs.region028',
#               'ERR3946892_contigs.region024',
#               'ERR3946767_contigs.region011',
#               'ERR3941095_contigs.region011',
#               'ERR3941117_contigs.region020',
#               'ERR3946768_contigs.region008',
#               'ERR3946789_contigs.region029',
#               'ERR3946718_contigs.region016',
#               'ERR3946737_contigs.region010',
#               'ERR3946892_contigs.region015',
#               'ERR3946716_contigs.region008',
#               'ERR3941062_contigs.region022',
#               'ERR3941265_contigs.region011',
#               'ERR3946855_contigs.region012',
#               'ERR3941366_contigs.region010',
#               'ERR3941063_contigs.region011',
#               'ERR3946787_contigs.region010',
#               'ERR3946712_contigs.region027',
#               'ERR3941183_contigs.region021',
#               'ERR3941308_contigs.region026',
#               'ERR3941131_contigs.region008',
#               'ERR3946830_contigs.region035',
#               'ERR3941074_contigs.region018',
#               'ERR3946888_contigs.region025',
#               'ERR3941328_contigs.region013',
#               'ERR3941263_contigs.region019',
#               'ERR3941177_contigs.region008',
#               'ERR3941200_contigs.region019',
#               'ERR3941298_contigs.region008',
#               'ERR3946741_contigs.region025',
#               'ERR3946893_contigs.region010',
#               'ERR3946766_contigs.region016',
#               'ERR3941183_contigs.region023',
#               'ERR3941251_contigs.region012',
#               'ERR3946841_contigs.region014',
#               'ERR3946815_contigs.region019',
#               'ERR3941094_contigs.region013',
#               'ERR3941084_contigs.region020',
#               'ERR3941368_contigs.region020',
#               'ERR3941129_contigs.region010',
#               'ERR3946865_contigs.region014',
#               'ERR3946864_contigs.region025',
#               'ERR3946858_contigs.region028',
#               'ERR3941135_contigs.region011',
#               'ERR3946805_contigs.region020',
#               'ERR3941359_contigs.region010',
#               'ERR3941186_contigs.region012',
#               'ERR3941184_contigs.region020',
#               'ERR3941390_contigs.region019',
#               'ERR3941121_contigs.region008',
#               'ERR3946782_contigs.region021',
#               'ERR3941055_contigs.region006',
#               'ERR3946872_contigs.region016',
#               'ERR3941187_contigs.region016',
#               'ERR3941178_contigs.region013',
#               'ERR3941143_contigs.region012',
#               'ERR3946758_contigs.region012',
#               'ERR3941136_contigs.region009',
#               'ERR3946889_contigs.region019',
#               'ERR3941095_contigs.region010',
#               'ERR3941125_contigs.region016',
#               'ERR3946778_contigs.region022',
#               'ERR3946852_contigs.region007',
#               'ERR3946707_contigs.region025'],
#              'GCF104': ['ERR3941169_contigs.region018',
#               'ERR3941093_contigs.region022',
#               'ERR3946849_contigs.region010',
#               'ERR3941057_contigs.region016',
#               'ERR3946862_contigs.region021',
#               'ERR3941281_contigs.region009',
#               'ERR3941079_contigs.region022',
#               'ERR3941310_contigs.region018',
#               'ERR3941172_contigs.region021',
#               'ERR3941108_contigs.region017',
#               'ERR3941080_contigs.region015',
#               'ERR3946892_contigs.region017',
#               'ERR3941378_contigs.region023',
#               'ERR3941125_contigs.region014',
#               'ERR3941375_contigs.region018',
#               'ERR3941163_contigs.region005',
#               'ERR3941373_contigs.region017',
#               'ERR3941224_contigs.region018',
#               'ERR3941277_contigs.region014',
#               'ERR3941273_contigs.region016',
#               'ERR3941104_contigs.region021',
#               'ERR3946723_contigs.region015',
#               'ERR3941175_contigs.region009'],
#              'GCF105': ['ERR3941361_contigs.region016',
#               'ERR3946882_contigs.region023',
#               'ERR3941062_contigs.region027',
#               'ERR3941174_contigs.region023',
#               'ERR3941224_contigs.region015',
#               'ERR3946745_contigs.region033',
#               'ERR3941319_contigs.region015',
#               'ERR3946875_contigs.region024',
#               'ERR3946743_contigs.region013',
#               'ERR3946880_contigs.region010',
#               'ERR3946883_contigs.region022',
#               'ERR3946831_contigs.region025',
# ...
#              'GCF346': ['GCA_000317125.region023', 'GCA_000317555.region015'],
#              'GCF347': ['GCA_000317145.region026', 'GCA_000332215.region008'],
#              'GCF348': ['GCA_000340725.region002', 'GCA_000338635.region005'],
#              'GCF349': ['GCA_000515055.region056',
#               'GCA_000365385.region041',
#               'GCA_000377525.region036'],
#              'GCF350': ['GCA_000515055.region053',
#               'GCA_000377525.region034',
#               'GCA_000365385.region043'],
#              'GCF351': ['GCA_000365385.region044',
#               'GCA_000377525.region033',
#               'GCA_000515055.region054'],
#              'GCF352': ['GCA_000377525.region032',
#               'GCA_000365385.region045',
#               'GCA_000515055.region055'],
#              'GCF353': ['GCA_000365385.region046',
#               'GCA_000515055.region040',
#               'GCA_000377525.region039'],
#              'GCF354': ['GCA_000515055.region050', 'GCA_000365385.region048'],
#              'GCF355': ['GCA_000365385.region050',
#               'GCA_000377525.region052',
#               'GCA_000515055.region077'],
#              'GCF356': ['GCA_000377525.region043',
#               'GCA_000515055.region047',
#               'GCA_000365385.region052'],
#              'GCF357': ['GCA_000515055.region063',
#               'GCA_000377525.region050',
#               'GCA_000365385.region053',
#               'GCA_000377145.region041'],
#              'GCF358': ['GCA_002941025.region058',
#               'GCA_003610995.region045',
#               'GCA_000515055.region059',
#               'GCA_000365385.region055'],
#              'GCF359': ['GCA_000365385.region056',
#               'GCA_000515055.region069',
#               'GCA_000377525.region049'],
#              'GCF360': ['GCA_000365385.region057', 'GCA_000515055.region046'],
#              'GCF361': ['GCA_000515055.region070',
#               'GCA_000365385.region058',
#               'GCA_000515055.region064',
#               'GCA_000377525.region042'],
#              'GCF362': ['GCA_000365385.region059',
#               'GCA_000377525.region038',
#               'GCA_000515055.region043'],
#              'GCF363': ['GCA_000365385.region062', 'GCA_000515055.region061'],
#              'GCF364': ['GCA_000365385.region066', 'GCA_000515055.region065'],
#              'GCF365': ['GCA_000365385.region069', 'GCA_000515055.region072'],
#              'GCF366': ['GCA_000365385.region076', 'GCA_000515055.region075'],
#              'GCF367': ['GCA_000514715.region063',
#               'GCA_000514995.region065',
#               'GCA_000701285.region065',
#               'GCA_000482585.region056',
#               'GCA_000377105.region053',
#               'GCA_000377165.region069',
#               'GCA_000377125.region051',
#               'GCA_000424805.region061'],
#              'GCF368': ['GCA_000701285.region045',
#               'GCA_000377105.region054',
#               'GCA_000424805.region071',
#               'GCA_000377125.region059',
#               'GCA_000377165.region072',
#               'GCA_000514995.region058'],
#              'GCF369': ['GCA_000377105.region055',
#               'GCA_000701285.region044',
#               'GCA_000377125.region058',
#               'GCA_000377165.region049',
#               'GCA_000424805.region056'],
#              'GCF370': ['GCA_000377165.region059',
#               'GCA_000701285.region084',
#               'GCA_000377125.region055',
#               'GCA_000377105.region056',
#               'GCA_000424805.region050'],
#              'GCF371': ['GCA_000377125.region054',
#               'GCA_000377105.region057',
#               'GCA_000424805.region049'],
#              'GCF372': ['GCA_000424805.region057',
#               'GCA_000514995.region051',
#               'GCA_000377125.region056',
#               'GCA_000701285.region054',
#               'GCA_000377105.region058',
#               'GCA_000377165.region051'],
#              'GCF373': ['GCA_000377165.region052',
#               'GCA_000701285.region055',
#               'GCA_000424805.region058',
#               'GCA_000377105.region059',
#               'GCA_000482585.region041',
#               'GCA_000514995.region052',
#               'GCA_000377125.region057'],
#              'GCF374': ['GCA_000377125.region049',
#               'GCA_000377105.region061',
#               'GCA_000377165.region042',
#               'GCA_000514995.region046',
#               'GCA_000424805.region069',
#               'GCA_000514715.region053',
#               'GCA_000701285.region082'],
#              'GCF375': ['GCA_000377165.region054',
#               'GCA_000701285.region048',
#               'GCA_000424805.region054',
#               'GCA_000514995.region086',
#               'GCA_000377105.region062',
#               'GCA_000377125.region061'],
#              'GCF376': ['GCA_000377125.region048',
#               'GCA_000701285.region081',
#               'GCA_000424805.region068',
#               'GCA_000377165.region043',
#               'GCA_000514995.region047',
#               'GCA_000377105.region063'],
#              'GCF377': ['GCA_000377165.region058',
#               'GCA_000514995.region066',
#               'GCA_000377105.region066',
#               'GCA_000701285.region060',
#               'GCA_000377125.region074',
#               'GCA_000424805.region059'],
#              'GCF378': ['GCA_000377125.region073',
#               'GCA_000701285.region063',
#               'GCA_000424805.region055',
#               'GCA_000377105.region067',
#               'GCA_000377165.region055'],
#              'GCF379': ['GCA_000701285.region056',
#               'GCA_000377125.region065',
#               'GCA_000514995.region044',
#               'GCA_000377105.region069',
#               'GCA_000377165.region061'],
#              'GCF380': ['GCA_000377165.region063',
#               'GCA_000514995.region070',
#               'GCA_000377105.region070',
#               'GCA_000377125.region067',
#               'GCA_000514715.region051',
#               'GCA_000424805.region051',
#               'GCA_000701285.region057',
#               'GCA_000482585.region044'],
#              'GCF381': ['GCA_000377165.region062',
#               'GCA_000377125.region066',
#               'GCA_000377105.region071'],
#              'GCF382': ['GCA_000424805.region080',
#               'GCA_000377125.region072',
#               'GCA_000701285.region085',
#               'GCA_000482585.region046',
#               'GCA_000424805.region063',
#               'GCA_000377105.region072',
#               'GCA_000377165.region064',
#               'GCA_000514995.region061',
#               'GCA_000514995.region076'],
#              'GCF383': ['GCA_000377105.region074',
#               'GCA_000514715.region052',
#               'GCA_000424805.region053',
#               'GCA_000514995.region048',
#               'GCA_000482585.region057',
#               'GCA_000701285.region062'],
#              'GCF384': ['GCA_000377125.region077',
#               'GCA_000514995.region062',
#               'GCA_000424805.region065',
#               'GCA_000377105.region075',
#               'GCA_000377165.region066',
#               'GCA_000701285.region067'],
#              'GCF385': ['GCA_000424805.region074',
#               'GCA_000377165.region056',
#               'GCA_000701285.region058',
#               'GCA_000377125.region052',
#               'GCA_000377105.region076',
#               'GCA_000514995.region064'],
#              'GCF386': ['GCA_000377105.region077',
#               'GCA_000377125.region075',
#               'GCA_000424805.region072',
#               'GCA_000514995.region075',
#               'GCA_000377165.region070',
#               'GCA_000701285.region051'],
#              'GCF387': ['GCA_000377105.region078',
#               'GCA_000377125.region062',
#               'GCA_000377165.region071',
#               'GCA_000514715.region049',
#               'GCA_000424805.region047',
#               'GCA_000514995.region045',
#               'GCA_000701285.region064'],
#              'GCF388': ['GCA_000377165.region067',
#               'GCA_000377105.region079',
#               'GCA_000424805.region066',
#               'GCA_000377125.region071'],
#              'GCF389': ['GCA_000377105.region081',
#               'GCA_000701285.region049',
#               'GCA_000377125.region076',
#               'GCA_000424805.region070',
#               'GCA_000377165.region046'],
#              'GCF390': ['GCA_000424805.region062',
#               'GCA_000377165.region060',
#               'GCA_000377105.region092',
#               'GCA_000701285.region083',
#               'GCA_000377165.region044',
#               'GCA_000377125.region053',
#               'GCA_000377105.region082'],
#              'GCF391': ['GCA_000377125.region070',
#               'GCA_000482585.region052',
#               'GCA_000514995.region059',
#               'GCA_000701285.region052',
#               'GCA_000377165.region068',
#               'GCA_000424805.region067',
#               'GCA_000377105.region083',
#               'GCA_000514715.region058'],
#              'GCF392': ['GCA_000377105.region084',
#               'GCA_000701285.region070',
#               'GCA_000377125.region078',
#               'GCA_000514995.region074',
#               'GCA_000424805.region076',
#               'GCA_000377165.region073'],
#              'GCF393': ['GCA_000701285.region074',
#               'GCA_000377165.region074',
#               'GCA_000514715.region070',
#               'GCA_000377105.region086',
#               'GCA_000377125.region082',
#               'GCA_000514995.region077',
#               'GCA_000424805.region078'],
#              'GCF394': ['GCA_000377105.region090',
#               'GCA_000514715.region072',
#               'GCA_000514995.region079',
#               'GCA_000424805.region081',
#               'GCA_000482585.region059',
#               'GCA_000701285.region073'],
#              'GCF395': ['GCA_000377105.region094', 'GCA_000377125.region081'],
#              'GCF396': ['GCA_000424805.region085',
#               'GCA_000701285.region075',
#               'GCA_000377105.region095',
#               'GCA_000514715.region074'],
#              'GCF397': ['GCA_000514995.region082',
#               'GCA_000424805.region084',
#               'GCA_000377125.region084',
#               'GCA_000377105.region096'],
#              'GCF398': ['GCA_000377105.region097',
#               'GCA_000377125.region087',
#               'GCA_000514995.region083',
#               'GCA_000377165.region078'],
#              'GCF399': ['GCA_000514715.region077',
#               'GCA_000377105.region098',
#               'GCA_000377125.region089'],
#              'GCF400': ['GCA_000701285.region079',
#               'GCA_000377105.region102',
#               'GCA_000424805.region089'],
#              'GCF401': ['GCA_000377125.region068',
#               'GCA_000482585.region038',
#               'GCA_000514715.region082',
#               'GCA_000377165.region057',
#               'GCA_000514995.region071',
#               'GCA_000424805.region060',
#               'GCA_000377125.region080'],
#              'GCF402': ['GCA_000377125.region090', 'GCA_000514715.region076'],
#              'GCF403': ['GCA_000514995.region081',
#               'GCA_000482585.region062',
#               'GCA_000377165.region077',
#               'GCA_000514715.region073'],
#              'GCF404': ['GCA_000514995.region084',
#               'GCA_000377165.region080',
#               'GCA_000701285.region076',
#               'GCA_000701285.region077',
#               'GCA_000514715.region075'],
#              'GCF405': ['GCA_000377525.region044', 'GCA_000515055.region078'],
#              'GCF406': ['GCA_000515055.region068', 'GCA_000377525.region045'],
#              'GCF407': ['GCA_000515055.region058', 'GCA_000377525.region053'],
#              'GCF408': ['GCA_000424845.region042', 'GCA_000377965.region083'],
#              'GCF409': ['GCA_000527195.region024',
#               'GCA_000415505.region061',
#               'GCA_003248315.region024'],
#              'GCF410': ['GCA_000424805.region083', 'GCA_000701285.region086'],
#              'GCF411': ['GCA_000426165.region029', 'GCA_000424965.region046'],
#              'GCF412': ['GCA_000424965.region066', 'GCA_000426165.region036'],
#              'GCF413': ['GCA_000507825.region007', 'GCA_000759045.region004'],
#              'GCF414': ['GCA_000517705.region004', 'GCA_000524395.region004'],
#              'GCF415': ['VIKV01.region013',
#               'VILF01.region018',
#               'VIKY01.region017',
#               'GCA_000521175.region013',
#               'VIKZ01.region022',
#               'GCA_008121535.region022',
#               'VILC01.region021',
#               'VIKX01.region014'],
#              'GCF416': ['VILC01.region013',
#               'VILF01.region022',
#               'GCA_000521175.region014'],
#              'GCF417': ['VILC01.region023',
#               'VILB01.region021',
#               'GCA_000521175.region017'],
#              'GCF418': ['VILF01.region017', 'GCA_000521175.region020'],
#              'GCF419': ['VILF01.region024', 'GCA_000521175.region022'],
#              'GCF420': ['GCA_002899455.region038', 'GCA_000527195.region036'],
#              'GCF421': ['GCA_002899455.region042', 'GCA_000527195.region040'],
#              'GCF422': ['GCA_000702365.region077', 'GCA_003610995.region032'],
#              'GCF423': ['GCA_000702365.region085',
#               'GCA_000702365.region087',
#               'GCA_000702365.region090'],
#              'GCF424': ['GCA_000721595.region034', 'GCA_002941025.region060'],
#              'GCF425': ['GCA_000721595.region039', 'GCA_002941025.region066'],
#              'GCF426': ['GCA_002941025.region063', 'GCA_000721595.region041'],
#              'GCF427': ['GCA_002941025.region052', 'GCA_000721595.region058'],
#              'GCF428': ['GCA_002994635.region081', 'GCA_000737335.region045'],
#              'GCF429': ['GCA_000737335.region047', 'GCA_002994635.region077'],
#              'GCF430': ['GCA_002994635.region083', 'GCA_000737335.region048'],
#              'GCF431': ['GCA_002994635.region080', 'GCA_000737335.region053'],
#              'GCF432': ['GCA_002994635.region058', 'GCA_000737335.region055'],
#              'GCF433': ['GCA_000737335.region056', 'GCA_002994635.region057'],
#              'GCF434': ['GCA_000737335.region059', 'GCA_002994635.region056'],
#              'GCF435': ['GCA_000737335.region061', 'GCA_002994635.region059'],
#              'GCF436': ['GCA_002994635.region064', 'GCA_000737335.region068'],
#              'GCF437': ['GCA_000737335.region070', 'GCA_002994635.region072'],
#              'GCF438': ['GCA_002994635.region050', 'GCA_000737335.region072'],
#              'GCF439': ['GCA_002994635.region043',
#               'GCA_002994615.region045',
#               'GCA_000737335.region073'],
#              'GCF440': ['GCA_002994635.region078', 'GCA_000737335.region079'],
#              'GCF441': ['GCA_002897315.region024', 'GCA_002095975.region011'],
#              'GCF442': ['GCA_002095975.region013', 'GCA_002897315.region019'],
#              'GCF443': ['GCA_002095975.region019', 'GCA_002897315.region022'],
#              'GCF444': ['GCA_002368075.region012', 'GCA_003054475.region014'],
#              'GCF445': ['GCA_003945305.region022', 'GCA_002897315.region017'],
#              'GCF446': ['GCA_002994635.region046', 'GCA_002994615.region044'],
#              'GCF447': ['VILC01.region015', 'GCA_008121535.region016'],
#              'GCF448': ['VILD01.region019', 'VIKW01.region014'],
#              'GCF449': ['VILD01.region012', 'VIKW01.region016'],
#              'GCF450': ['VIKW01.region017', 'VILD01.region015'],
#              'GCF451': ['VILD01.region013', 'VIKW01.region018'],
#              'GCF452': ['VIKW01.region019', 'VILD01.region017'],
#              'GCF453': ['VILD01.region014', 'VIKW01.region020'],
#              'GCF454': ['VIKW01.region022',
#               'VIKW01.region023',
#               'VILD01.region016'],
#              'GCF455': ['VILD01.region018', 'VIKW01.region024'],
#              'GCF456': ['VIKX01.region016', 'VILB01.region022'],
#              'GCF457': ['VILE01.region015', 'VILB01.region014'],
#              'GCF458': ['VILE01.region017', 'VILC01.region016']})

# %% [markdown]
# ## 4.4 Calculating BGC count per GCF

# %%
col1,col2,col3 = [],[],[]

type_dict = dict(zip(nodes_df['BGC'],nodes_df['Product Prediction'])) ### also try BiG-SCAPE prediction

def most_frequent(List): 
    return max(set(List), key = List.count) 

for gcf in gcf_dict:
    col1.append(gcf)
    temp_type_list = []
    for item in gcf_dict[gcf]:
        if item in type_dict:
            temp_type_list.append(type_dict[item])
    consensus_taxa = most_frequent(temp_type_list)
    col2.append(consensus_taxa)
    col3.append(len(temp_type_list))
    
frames = {'GCF':col1,'Type':col2,'BGC_count':col3}

gcf_metadata = pd.DataFrame(frames)

gcf_metadata
# Out:
#         GCF                     Type  BGC_count
# 0      GCF1                    T1PKS          3
# 1      GCF2                    t1pks          5
# 2      GCF3                    t1pks          4
# 3      GCF4      butyrolactone.T1PKS          4
# 4      GCF5                    T1PKS          9
# ..      ...                      ...        ...
# 453  GCF454               NRPS.T1PKS          3
# 454  GCF455          NRPS-like.T1PKS          2
# 455  GCF456  ectoine.NRPS-like.T1PKS          2
# 456  GCF457                  terpene          2
# 457  GCF458                NRPS-like          2
#
# [458 rows x 3 columns]

# %% [markdown]
# ## 4.5. Summing GCFs from same type

# %%
sum_col1,sum_col2 = [],[]

for item in np.unique(gcf_metadata['Type']):
    temp_df = gcf_metadata[gcf_metadata['Type'] == item]
    sum_col1.append(item)
    sum_col2.append(len(temp_df))

frames = {'Type':sum_col1,'Count':sum_col2}

metadata_sum = pd.DataFrame(frames)

metadata_sum = metadata_sum.sort_values(by='Count',)

# metadata_sum = metadata_sum[metadata_sum['Count'] > 9]

metadata_sum
# Out:
#                   Type  Count
# 78          transatpks      1
# 48  hglE-KS.resorcinol      1
# 25          amglyccycl      1
# 26     amglyccycl.NRPS      1
# 66         t1pks.t3pks      1
# ..                 ...    ...
# 27         arylpolyene     30
# 30         bacteriocin     43
# 71             terpene     44
# 5            NRPS-like     50
# 4                 NRPS     64
#
# [79 rows x 2 columns]

# %% [markdown]
# ## 4.6. Plotting counts

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(18,5))

plt.bar(metadata_sum['Type'],metadata_sum['Count'])
plt.xticks(rotation=90,fontsize=20)
plt.yticks(fontsize=20)
# metadata_sum.plot.bar(x='Type')
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60., 70.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## 4.7. Plotting GCF clustermap

# %%
cluster_list = []
strains = []

for item in gcf_dict.values():
    cluster_list = cluster_list + item

for item in cluster_list:
    if 'BGC' in item:
        strains.append('MIBiG')
    else:
        strains.append(item.split('.')[0])

col_names = list(np.unique(strains))

col_names
# Out:
# ['ERR3941051_contigs',
#  'ERR3941055_contigs',
#  'ERR3941057_contigs',
#  'ERR3941059_contigs',
#  'ERR3941060_contigs',
#  'ERR3941062_contigs',
#  'ERR3941063_contigs',
#  'ERR3941065_contigs',
#  'ERR3941067_contigs',
#  'ERR3941069_contigs',
#  'ERR3941071_contigs',
#  'ERR3941072_contigs',
#  'ERR3941073_contigs',
#  'ERR3941074_contigs',
#  'ERR3941075_contigs',
#  'ERR3941076_contigs',
#  'ERR3941077_contigs',
#  'ERR3941079_contigs',
#  'ERR3941080_contigs',
#  'ERR3941082_contigs',
#  'ERR3941083_contigs',
#  'ERR3941084_contigs',
#  'ERR3941085_contigs',
#  'ERR3941087_contigs',
#  'ERR3941088_contigs',
#  'ERR3941090_contigs',
#  'ERR3941091_contigs',
#  'ERR3941092_contigs',
#  'ERR3941093_contigs',
#  'ERR3941094_contigs',
#  'ERR3941095_contigs',
#  'ERR3941097_contigs',
#  'ERR3941098_contigs',
#  'ERR3941100_contigs',
#  'ERR3941101_contigs',
#  'ERR3941102_contigs',
#  'ERR3941103_contigs',
#  'ERR3941104_contigs',
#  'ERR3941106_contigs',
#  'ERR3941107_contigs',
#  'ERR3941108_contigs',
#  'ERR3941109_contigs',
#  'ERR3941110_contigs',
#  'ERR3941111_contigs',
#  'ERR3941112_contigs',
#  'ERR3941113_contigs',
#  'ERR3941114_contigs',
#  'ERR3941115_contigs',
#  'ERR3941117_contigs',
#  'ERR3941118_contigs',
#  'ERR3941119_contigs',
#  'ERR3941120_contigs',
#  'ERR3941121_contigs',
#  'ERR3941122_contigs',
#  'ERR3941123_contigs',
#  'ERR3941125_contigs',
#  'ERR3941126_contigs',
#  'ERR3941127_contigs',
#  'ERR3941129_contigs',
#  'ERR3941131_contigs',
#  'ERR3941133_contigs',
#  'ERR3941134_contigs',
#  'ERR3941135_contigs',
#  'ERR3941136_contigs',
#  'ERR3941137_contigs',
#  'ERR3941138_contigs',
#  'ERR3941139_contigs',
#  'ERR3941140_contigs',
#  'ERR3941141_contigs',
#  'ERR3941142_contigs',
#  'ERR3941143_contigs',
#  'ERR3941144_contigs',
#  'ERR3941146_contigs',
#  'ERR3941147_contigs',
#  'ERR3941148_contigs',
#  'ERR3941149_contigs',
#  'ERR3941150_contigs',
#  'ERR3941151_contigs',
#  'ERR3941152_contigs',
#  'ERR3941153_contigs',
#  'ERR3941155_contigs',
#  'ERR3941157_contigs',
#  'ERR3941158_contigs',
#  'ERR3941160_contigs',
#  'ERR3941162_contigs',
#  'ERR3941163_contigs',
#  'ERR3941164_contigs',
#  'ERR3941165_contigs',
#  'ERR3941166_contigs',
#  'ERR3941167_contigs',
#  'ERR3941168_contigs',
#  'ERR3941169_contigs',
#  'ERR3941170_contigs',
#  'ERR3941172_contigs',
#  'ERR3941173_contigs',
#  'ERR3941174_contigs',
#  'ERR3941175_contigs',
#  'ERR3941176_contigs',
#  'ERR3941177_contigs',
#  'ERR3941178_contigs',
#  'ERR3941179_contigs',
#  'ERR3941181_contigs',
#  'ERR3941182_contigs',
#  'ERR3941183_contigs',
#  'ERR3941184_contigs',
#  'ERR3941185_contigs',
#  'ERR3941186_contigs',
#  'ERR3941187_contigs',
#  'ERR3941188_contigs',
#  'ERR3941189_contigs',
#  'ERR3941190_contigs',
#  'ERR3941191_contigs',
#  'ERR3941193_contigs',
#  'ERR3941195_contigs',
#  'ERR3941196_contigs',
#  'ERR3941197_contigs',
#  'ERR3941200_contigs',
#  'ERR3941203_contigs',
#  'ERR3941204_contigs',
#  'ERR3941205_contigs',
#  'ERR3941206_contigs',
#  'ERR3941207_contigs',
#  'ERR3941209_contigs',
#  'ERR3941210_contigs',
#  'ERR3941211_contigs',
#  'ERR3941212_contigs',
#  'ERR3941213_contigs',
#  'ERR3941215_contigs',
#  'ERR3941216_contigs',
#  'ERR3941217_contigs',
#  'ERR3941218_contigs',
#  'ERR3941219_contigs',
#  'ERR3941220_contigs',
#  'ERR3941221_contigs',
#  'ERR3941222_contigs',
#  'ERR3941223_contigs',
#  'ERR3941224_contigs',
#  'ERR3941225_contigs',
#  'ERR3941227_contigs',
#  'ERR3941228_contigs',
#  'ERR3941229_contigs',
#  'ERR3941230_contigs',
#  'ERR3941231_contigs',
#  'ERR3941232_contigs',
#  'ERR3941234_contigs',
#  'ERR3941236_contigs',
#  'ERR3941237_contigs',
#  'ERR3941238_contigs',
#  'ERR3941240_contigs',
#  'ERR3941241_contigs',
#  'ERR3941243_contigs',
#  'ERR3941246_contigs',
#  'ERR3941247_contigs',
#  'ERR3941249_contigs',
#  'ERR3941251_contigs',
#  'ERR3941253_contigs',
#  'ERR3941254_contigs',
#  'ERR3941255_contigs',
#  'ERR3941256_contigs',
#  'ERR3941257_contigs',
#  'ERR3941259_contigs',
#  'ERR3941260_contigs',
#  'ERR3941262_contigs',
#  'ERR3941263_contigs',
#  'ERR3941265_contigs',
#  'ERR3941267_contigs',
#  'ERR3941269_contigs',
#  'ERR3941270_contigs',
#  'ERR3941271_contigs',
#  'ERR3941272_contigs',
#  'ERR3941273_contigs',
#  'ERR3941274_contigs',
#  'ERR3941275_contigs',
#  'ERR3941276_contigs',
#  'ERR3941277_contigs',
#  'ERR3941278_contigs',
#  'ERR3941279_contigs',
#  'ERR3941280_contigs',
#  'ERR3941281_contigs',
#  'ERR3941282_contigs',
#  'ERR3941283_contigs',
#  'ERR3941284_contigs',
#  'ERR3941285_contigs',
#  'ERR3941286_contigs',
#  'ERR3941288_contigs',
#  'ERR3941289_contigs',
#  'ERR3941290_contigs',
#  'ERR3941291_contigs',
#  'ERR3941292_contigs',
#  'ERR3941293_contigs',
#  'ERR3941295_contigs',
#  'ERR3941296_contigs',
#  'ERR3941297_contigs',
#  'ERR3941298_contigs',
#  'ERR3941299_contigs',
#  'ERR3941300_contigs',
#  'ERR3941301_contigs',
#  'ERR3941303_contigs',
#  'ERR3941304_contigs',
#  'ERR3941305_contigs',
#  'ERR3941306_contigs',
#  'ERR3941308_contigs',
#  'ERR3941309_contigs',
#  'ERR3941310_contigs',
#  'ERR3941312_contigs',
#  'ERR3941313_contigs',
#  'ERR3941314_contigs',
#  'ERR3941315_contigs',
#  'ERR3941316_contigs',
#  'ERR3941317_contigs',
#  'ERR3941318_contigs',
#  'ERR3941319_contigs',
#  'ERR3941320_contigs',
#  'ERR3941324_contigs',
#  'ERR3941325_contigs',
#  'ERR3941326_contigs',
#  'ERR3941327_contigs',
#  'ERR3941328_contigs',
#  'ERR3941329_contigs',
#  'ERR3941330_contigs',
#  'ERR3941331_contigs',
#  'ERR3941332_contigs',
#  'ERR3941333_contigs',
#  'ERR3941334_contigs',
#  'ERR3941335_contigs',
#  'ERR3941339_contigs',
#  'ERR3941340_contigs',
#  'ERR3941341_contigs',
#  'ERR3941343_contigs',
#  'ERR3941345_contigs',
#  'ERR3941347_contigs',
#  'ERR3941348_contigs',
#  'ERR3941350_contigs',
#  'ERR3941351_contigs',
#  'ERR3941354_contigs',
#  'ERR3941355_contigs',
#  'ERR3941356_contigs',
#  'ERR3941357_contigs',
#  'ERR3941359_contigs',
#  'ERR3941360_contigs',
#  'ERR3941361_contigs',
#  'ERR3941362_contigs',
#  'ERR3941363_contigs',
#  'ERR3941365_contigs',
#  'ERR3941366_contigs',
#  'ERR3941367_contigs',
#  'ERR3941368_contigs',
#  'ERR3941369_contigs',
#  'ERR3941372_contigs',
#  'ERR3941373_contigs',
#  'ERR3941374_contigs',
#  'ERR3941375_contigs',
#  'ERR3941377_contigs',
#  'ERR3941378_contigs',
#  'ERR3941379_contigs',
#  'ERR3941381_contigs',
#  'ERR3941385_contigs',
#  'ERR3941387_contigs',
#  'ERR3941388_contigs',
#  'ERR3941389_contigs',
#  'ERR3941390_contigs',
#  'ERR3941391_contigs',
#  'ERR3941393_contigs',
#  'ERR3941394_contigs',
#  'ERR3941395_contigs',
#  'ERR3941396_contigs',
#  'ERR3941398_contigs',
#  'ERR3941400_contigs',
#  'ERR3941401_contigs',
#  'ERR3946693_contigs',
#  'ERR3946695_contigs',
#  'ERR3946697_contigs',
#  'ERR3946698_contigs',
#  'ERR3946699_contigs',
#  'ERR3946701_contigs',
#  'ERR3946704_contigs',
#  'ERR3946705_contigs',
#  'ERR3946706_contigs',
#  'ERR3946707_contigs',
#  'ERR3946708_contigs',
#  'ERR3946709_contigs',
#  'ERR3946710_contigs',
#  'ERR3946712_contigs',
#  'ERR3946713_contigs',
#  'ERR3946714_contigs',
#  'ERR3946715_contigs',
#  'ERR3946716_contigs',
#  'ERR3946717_contigs',
#  'ERR3946718_contigs',
#  'ERR3946719_contigs',
#  'ERR3946721_contigs',
#  'ERR3946722_contigs',
#  'ERR3946723_contigs',
#  'ERR3946724_contigs',
#  'ERR3946727_contigs',
#  'ERR3946728_contigs',
#  'ERR3946729_contigs',
#  'ERR3946730_contigs',
#  'ERR3946731_contigs',
#  'ERR3946732_contigs',
#  'ERR3946733_contigs',
#  'ERR3946735_contigs',
#  'ERR3946736_contigs',
#  'ERR3946737_contigs',
#  'ERR3946738_contigs',
#  'ERR3946740_contigs',
#  'ERR3946741_contigs',
#  'ERR3946743_contigs',
#  'ERR3946744_contigs',
#  'ERR3946745_contigs',
#  'ERR3946746_contigs',
#  'ERR3946747_contigs',
#  'ERR3946750_contigs',
#  'ERR3946751_contigs',
#  'ERR3946753_contigs',
#  'ERR3946754_contigs',
#  'ERR3946756_contigs',
#  'ERR3946757_contigs',
#  'ERR3946758_contigs',
#  'ERR3946759_contigs',
#  'ERR3946760_contigs',
#  'ERR3946761_contigs',
#  'ERR3946762_contigs',
#  'ERR3946763_contigs',
#  'ERR3946765_contigs',
#  'ERR3946766_contigs',
#  'ERR3946767_contigs',
#  'ERR3946768_contigs',
#  'ERR3946769_contigs',
#  'ERR3946770_contigs',
#  'ERR3946771_contigs',
#  'ERR3946772_contigs',
#  'ERR3946773_contigs',
#  'ERR3946774_contigs',
#  'ERR3946776_contigs',
#  'ERR3946777_contigs',
#  'ERR3946778_contigs',
#  'ERR3946781_contigs',
#  'ERR3946782_contigs',
#  'ERR3946783_contigs',
#  'ERR3946787_contigs',
#  'ERR3946788_contigs',
#  'ERR3946789_contigs',
#  'ERR3946792_contigs',
#  'ERR3946793_contigs',
#  'ERR3946794_contigs',
#  'ERR3946796_contigs',
#  'ERR3946797_contigs',
#  'ERR3946798_contigs',
#  'ERR3946799_contigs',
#  'ERR3946800_contigs',
#  'ERR3946801_contigs',
#  'ERR3946802_contigs',
#  'ERR3946804_contigs',
#  'ERR3946805_contigs',
#  'ERR3946807_contigs',
#  'ERR3946808_contigs',
#  'ERR3946809_contigs',
#  'ERR3946810_contigs',
#  'ERR3946811_contigs',
#  'ERR3946812_contigs',
#  'ERR3946815_contigs',
#  'ERR3946817_contigs',
#  'ERR3946818_contigs',
#  'ERR3946819_contigs',
#  'ERR3946820_contigs',
#  'ERR3946823_contigs',
#  'ERR3946824_contigs',
#  'ERR3946825_contigs',
#  'ERR3946826_contigs',
#  'ERR3946828_contigs',
#  'ERR3946829_contigs',
#  'ERR3946830_contigs',
#  'ERR3946831_contigs',
#  'ERR3946832_contigs',
#  'ERR3946833_contigs',
#  'ERR3946834_contigs',
#  'ERR3946835_contigs',
#  'ERR3946837_contigs',
#  'ERR3946838_contigs',
#  'ERR3946841_contigs',
#  'ERR3946842_contigs',
#  'ERR3946846_contigs',
#  'ERR3946847_contigs',
#  'ERR3946848_contigs',
#  'ERR3946849_contigs',
#  'ERR3946850_contigs',
#  'ERR3946851_contigs',
#  'ERR3946852_contigs',
#  'ERR3946853_contigs',
#  'ERR3946854_contigs',
#  'ERR3946855_contigs',
#  'ERR3946856_contigs',
#  'ERR3946857_contigs',
#  'ERR3946858_contigs',
#  'ERR3946859_contigs',
#  'ERR3946860_contigs',
#  'ERR3946861_contigs',
#  'ERR3946862_contigs',
#  'ERR3946863_contigs',
#  'ERR3946864_contigs',
#  'ERR3946865_contigs',
#  'ERR3946866_contigs',
#  'ERR3946867_contigs',
#  'ERR3946868_contigs',
#  'ERR3946869_contigs',
#  'ERR3946872_contigs',
#  'ERR3946873_contigs',
#  'ERR3946874_contigs',
#  'ERR3946875_contigs',
#  'ERR3946877_contigs',
#  'ERR3946878_contigs',
#  'ERR3946879_contigs',
#  'ERR3946880_contigs',
#  'ERR3946881_contigs',
#  'ERR3946882_contigs',
#  'ERR3946883_contigs',
#  'ERR3946884_contigs',
#  'ERR3946885_contigs',
#  'ERR3946886_contigs',
#  'ERR3946887_contigs',
#  'ERR3946888_contigs',
#  'ERR3946889_contigs',
#  'ERR3946890_contigs',
#  'ERR3946892_contigs',
#  'ERR3946893_contigs',
#  'ERR3957990_contigs',
#  'ERR3958009_contigs',
#  'ERR3958021_contigs',
#  'ERR3958026_contigs',
#  'ERR3958030_contigs',
#  'ERR3958037_contigs',
#  'ERR3958041_contigs',
#  'ERR3958045_contigs',
#  'ERR3958053_contigs',
#  'ERR3958060_contigs',
#  'ERR3958077_contigs',
#  'ERR3958083_contigs',
#  'ERR3958084_contigs',
#  'ERR3958086_contigs',
#  'ERR3958097_contigs',
#  'ERR3958101_contigs',
#  'ERR3958103_contigs',
#  'ERR3958105_contigs',
#  'ERR3958107_contigs',
#  'ERR3958108_contigs',
#  'ERR3958111_contigs',
#  'ERR3958115_contigs',
#  'ERR3958119_contigs',
#  'ERR3958123_contigs',
#  'ERR3958147_contigs',
#  'ERR3958149_contigs',
#  'GCA_000009705',
#  'GCA_000010625',
#  'GCA_000012265',
#  'GCA_000012445',
#  'GCA_000020025',
#  'GCA_000025765',
#  'GCA_000087965',
#  'GCA_000144005',
#  'GCA_000144025',
#  'GCA_000144045',
#  'GCA_000144065',
#  'GCA_000144085',
#  'GCA_000144105',
#  'GCA_000144125',
#  'GCA_000144145',
#  'GCA_000144165',
#  'GCA_000144185',
#  'GCA_000144205',
#  'GCA_000144245',
#  'GCA_000144265',
#  'GCA_000144305',
#  'GCA_000144325',
#  'GCA_000144345',
#  'GCA_000144365',
#  'GCA_000144385',
#  'GCA_000144425',
#  'GCA_000144445',
#  'GCA_000144465',
#  'GCA_000144505',
#  'GCA_000144525',
#  'GCA_000144545',
#  'GCA_000144565',
#  'GCA_000144585',
#  'GCA_000144715',
#  'GCA_000144735',
#  'GCA_000144755',
#  'GCA_000144775',
#  'GCA_000144795',
#  'GCA_000144855',
#  'GCA_000144875',
#  'GCA_000144895',
#  'GCA_000145055',
#  'GCA_000145075',
#  'GCA_000145095',
#  'GCA_000145115',
#  'GCA_000145175',
#  'GCA_000145195',
#  'GCA_000145355',
#  'GCA_000145455',
#  'GCA_000145475',
#  'GCA_000145495',
#  'GCA_000145515',
#  'GCA_000145535',
#  'GCA_000145555',
#  'GCA_000145575',
#  'GCA_000147235',
#  'GCA_000156435',
#  'GCA_000156695',
#  'GCA_000157015',
#  'GCA_000157075',
#  'GCA_000158335',
#  'GCA_000158915',
#  'GCA_000158975',
#  'GCA_000159075',
#  'GCA_000162135',
#  'GCA_000162455',
#  'GCA_000166275',
#  'GCA_000170895',
#  'GCA_000175835',
#  'GCA_000180455',
#  'GCA_000203835',
#  'GCA_000204075',
#  'GCA_000209465',
#  'GCA_000213055',
#  'GCA_000218325',
#  'GCA_000221125',
#  'GCA_000234075',
#  'GCA_000238295',
#  'GCA_000240165',
#  'GCA_000263115',
#  'GCA_000269545',
#  'GCA_000273015',
#  'GCA_000273035',
#  'GCA_000273055',
#  'GCA_000273115',
#  'GCA_000273155',
#  'GCA_000273295',
#  'GCA_000273605',
#  'GCA_000273725',
#  'GCA_000295055',
#  'GCA_000295175',
#  'GCA_000295235',
#  'GCA_000295355',
#  'GCA_000295415',
#  'GCA_000295575',
#  'GCA_000296385',
#  'GCA_000312705',
#  'GCA_000315565',
#  'GCA_000315585',
#  'GCA_000316115',
#  'GCA_000316575',
#  'GCA_000317125',
#  'GCA_000317145',
#  'GCA_000317535',
#  'GCA_000317555',
#  'GCA_000331305',
#  'GCA_000332195',
#  'GCA_000332215',
#  'GCA_000332295',
#  'GCA_000338635',
#  'GCA_000340725',
#  'GCA_000365385',
#  'GCA_000377105',
#  'GCA_000377125',
#  'GCA_000377145',
#  'GCA_000377165',
#  'GCA_000377525',
#  'GCA_000377545',
#  'GCA_000377965',
#  'GCA_000412265',
#  'GCA_000415505',
#  'GCA_000424765',
#  'GCA_000424785',
#  'GCA_000424805',
#  'GCA_000424825',
#  'GCA_000424845',
#  'GCA_000424965',
#  'GCA_000426165',
#  'GCA_000426325',
#  'GCA_000447295',
#  'GCA_000482585',
#  'GCA_000506385',
#  'GCA_000507825',
#  'GCA_000514715',
#  'GCA_000514995',
#  'GCA_000515055',
#  'GCA_000517105',
#  'GCA_000517705',
#  'GCA_000521175',
#  'GCA_000524395',
#  'GCA_000527195',
#  'GCA_000701285',
#  'GCA_000702365',
#  'GCA_000710405',
#  'GCA_000721595',
#  'GCA_000737335',
#  'GCA_000739105',
#  'GCA_000759045',
#  'GCA_001445655',
#  'GCA_001562525',
#  'GCA_001578075',
#  'GCA_001625105',
#  'GCA_002095975',
#  'GCA_002368075',
#  'GCA_002897315',
#  'GCA_002899455',
#  'GCA_002941025',
#  'GCA_002994615',
#  'GCA_002994635',
#  'GCA_003054475',
#  'GCA_003248315',
#  'GCA_003324555',
#  'GCA_003326215',
#  'GCA_003610995',
#  'GCA_003945305',
#  'GCA_007363395',
#  'GCA_008121535',
#  'GCA_011290345',
#  'GCA_011751035',
#  'MIBiG',
#  'VIKV01',
#  'VIKW01',
#  'VIKX01',
#  'VIKY01',
#  'VIKZ01',
#  'VILB01',
#  'VILC01',
#  'VILD01',
#  'VILE01',
#  'VILF01']

# %%
family_rows = []
indexes = []

for key,value in gcf_dict.items():
    indexes.append(key)
    row = []
    for strain in col_names:
        if strain == "MIBiG":
            find_substring_in_list = [s for s in value if "BGC" in s]
            sublist = filter(lambda x: "BGC" in x, value)
        else:
            find_substring_in_list = [s for s in value if strain.lower() in s.lower()] # .lower() for case insensitive
            sublist = filter(lambda x: strain in x, value)
            for item in find_substring_in_list:
                if 'BGC' in item:
                    find_substring_in_list.remove(item)
                    sublist.remove(item)
        if find_substring_in_list:
            row.append(sublist)
        else:
            row.append(0)
    family_rows.append(row)
    
gcf_patterns = pd.DataFrame(family_rows,columns=col_names,index=indexes)

# %%
family_counts = []

for i,r in gcf_patterns.iterrows():
    new_row = []
    for item in r:
        if item == 0:
            new_row.append(0)
        else:
            new_row.append(1)
    family_counts.append(new_row)
    
gcf_binary = pd.DataFrame(family_counts,columns=col_names,index=indexes)

gcf_binary[:5]
# Out:
#       ERR3941051_contigs  ERR3941055_contigs  ERR3941057_contigs  \
# GCF1                   0                   0                   0
# GCF2                   0                   0                   0
# GCF3                   0                   0                   0
# GCF4                   0                   0                   0
# GCF5                   0                   0                   0
#
#       ERR3941059_contigs  ERR3941060_contigs  ERR3941062_contigs  \
# GCF1                   0                   0                   0
# GCF2                   0                   0                   0
# GCF3                   0                   0                   0
# GCF4                   0                   0                   0
# GCF5                   0                   0                   0
#
#       ERR3941063_contigs  ERR3941065_contigs  ERR3941067_contigs  \
# GCF1                   0                   0                   0
# GCF2                   0                   0                   0
# GCF3                   0                   0                   0
# GCF4                   0                   0                   0
# GCF5                   0                   0                   0
#
#       ERR3941069_contigs  ...  VIKV01  VIKW01  VIKX01  VIKY01  VIKZ01  VILB01  \
# GCF1                   0  ...       0       0       0       0       0       0
# GCF2                   0  ...       0       0       0       0       0       0
# GCF3                   0  ...       0       0       0       0       0       0
# GCF4                   0  ...       0       0       0       0       0       0
# GCF5                   0  ...       0       0       0       0       0       0
#
#       VILC01  VILD01  VILE01  VILF01
# GCF1       0       0       0       1
# GCF2       0       0       0       0
# GCF3       0       0       0       0
# GCF4       0       0       0       0
# GCF5       0       0       0       0
#
# [5 rows x 632 columns]

# %%
gcf_noMIBiG = gcf_binary[(gcf_binary.T != 0).any()].drop(columns='MIBiG')

sns.clustermap(gcf_noMIBiG)
# Out:
# /Users/tiagoferreiraleao/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py:659: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
metabgc_glob = glob.glob('/Volumes/TFL190831/ming_output/antismash/ERR*/c*.gbk')
meta_count = glob.glob('/Volumes/TFL190831/ming_output/antismash/ERR*/')

len(metabgc_glob)/len(meta_count)
# Out:
# 6.758913412563667

# %%
genomes_glob = glob.glob('/Volumes/TFL190831/nf_output-iomega/*/*region*.gbk')
genomes_count = glob.glob('/Volumes/TFL190831/nf_output-iomega/*/')

len(genomes_glob)/len(genomes_count)
# Out:
# 10.021505376344086
